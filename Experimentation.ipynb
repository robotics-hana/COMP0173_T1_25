# %% [markdown]
# # Load Packages

# %%
# Install extra packages needed for this notebook
# !pip install -q --upgrade pip
# !pip install -q pyunpack patool rarfile rioxarray rasterio xarray

import os
import sys
import glob
import pathlib
import requests

import numpy as np
import pandas as pd

import rasterio
from rasterio.warp import reproject, Resampling
from rasterio.windows import Window

from PIL import Image
import matplotlib.pyplot as plt

import tensorflow as tf
from tensorflow.keras import backend as K
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.optimizers import Adam

from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score, confusion_matrix

import PIL
import pyunpack
from rarfile import RarFile
import rioxarray as rxr

from tensorflow.keras.models import Model
from tensorflow.keras.layers import (
    Input, Conv2D, Conv2DTranspose, MaxPooling2D,
    Dropout, BatchNormalization, Activation,
    concatenate,
)

from tensorflow.keras.optimizers import Adam
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 82.0 MB/s eta 0:00:00

# %%
# --- Imports ---

import os
import sys
import pathlib
import requests

import numpy as np
import pandas as pd
import glob
import numpy as np
import rasterio
from rasterio.warp import reproject, Resampling
from rasterio.windows import Window
import PIL
from PIL import Image

import matplotlib.pyplot as plt

import tensorflow as tf
from tensorflow.keras.models import *
from tensorflow.keras.layers import *
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.losses import *
from tensorflow.keras import backend as K
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.preprocessing.image import ImageDataGenerator

import pyunpack
from rarfile import RarFile
import rioxarray as rxr

from sklearn.metrics import *

from tensorflow.keras.models import Model
from tensorflow.keras.layers import (
    Input, Conv2D, Conv2DTranspose, MaxPooling2D,
    Dropout, BatchNormalization, Activation, UpSampling2D,
    concatenate, add, multiply,
)
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.losses import binary_crossentropy
from tensorflow.keras import backend as K

# %%
import random
SEED = 42
random.seed(SEED)
np.random.seed(SEED)
tf.random.set_seed(SEED)

# %%
# Specify whether to download data or read in
download = True
base_dir = r"./Amazon Forest Dataset/"

# %%
# Download data

if download:
    url = 'https://zenodo.org/record/3233081/files/Amazon%20Forest%20Dataset.rar?download=1'
    r = requests.get(url, allow_redirects=True)
    open('data.rar', 'wb').write(r.content)

    if sys.platform != 'darwin':
        pyunpack.Archive('data.rar').extractall('')

    else:
        with RarFile('data.rar') as rf:
            rf.extractall()

base_dir = r"./Amazon Forest Dataset/"

# %%
# Show example image from training data
PIL.Image.open(r"{}Training/images/Amazon_1110.tiff_25.tiff".format(base_dir))
# Out:
# <PIL.TiffImagePlugin.TiffImageFile image mode=RGB size=512x512>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Functions

# %%
'''
  Returns an image plot of mask prediction
'''

def reconstruct_image(model, image, rounded=False):

  # Find model prediction
  reconstruction = model.predict(image).reshape(image.shape[1], image.shape[2])
  # Standardise between 0-1
  reconstruction = reconstruction/np.max(reconstruction)

  # Round to 0-1, binary pixel-by-pixel classification
  if rounded:
    reconstruction = np.round(reconstruction)

  # Plot reconstructed mask (prediction)
  plt.imshow(reconstruction)

# %%
'''
  Returns array of mask prediction, given model and image
'''
def reconstruct_array(model, image, rounded=False):

  # Find model prediction
  reconstruction = model.predict(image).reshape(image.shape[1], image.shape[2])

  if rounded:
    reconstruction = np.round(reconstruction)

  return reconstruction # Returns array

# %%
'''
  Metric functions for evaluation
'''

def score_eval(model, image, mask): # Gives score of mask vs prediction
  if type(image) != list:
    reconstruction = model.predict(image).reshape(mask.shape[1], mask.shape[2])
    reconstruction = np.round(reconstruction).flatten()

    return accuracy_score(mask.flatten(), reconstruction)

  else: # If a list of images input, find accuracy for each
    scores = []
    for i in range(len(image)):
      reconstruction = model.predict(image[i].reshape(1, 512, 512, 3))
      reconstruction = np.round(reconstruction).flatten()

      scores.append(accuracy_score(mask[i].flatten(), reconstruction))

    return scores

def score_eval2(model, image, mask): # Gives score of mask vs prediction
  if type(image) != list:
    reconstruction = model.predict(image).reshape(mask.shape[1], mask.shape[2])
    reconstruction = np.round(reconstruction).flatten()

    return accuracy_score(mask.flatten(), reconstruction)

  else: # If a list of images input, find accuracy for each
    scores = []
    for i in range(len(image)):
      reconstruction = model.predict(image[i].reshape(1, 512, 512, 4))
      reconstruction = np.round(reconstruction).flatten()

      scores.append(accuracy_score(mask[i].flatten(), reconstruction))

    return scores

def recall_eval(model, image, mask): # Find recall score
  if type(image) != list:
    reconstruction = model.predict(image).reshape(mask.shape[1], mask.shape[2])
    reconstruction = np.round(reconstruction).flatten()

    return recall_score(mask.flatten(), reconstruction, average='weighted')

  else: # If a list of images input, find accuracy for each
    recall = []
    for i in range(len(image)):
        reconstruction = model.predict(image[i]).reshape(mask[i].shape[1], mask[i].shape[2])
        reconstruction = np.round(reconstruction).flatten()

        recall.append(recall_score(mask[i].flatten(), reconstruction, average='weighted'))

    return recall

def precision_eval(model, image, mask): # Find precision score
  if type(image) != list:
    reconstruction = model.predict(image).reshape(mask.shape[1], mask.shape[2])
    reconstruction = np.round(reconstruction).flatten()

    return precision_score(mask.flatten(), reconstruction, average='weighted')

  else: # If a list of images input, find accuracy for each
    precision = []
    for i in range(len(image)):
        reconstruction = model.predict(image[i]).reshape(mask[i].shape[1], mask[i].shape[2])
        reconstruction = np.round(reconstruction).flatten()

        precision.append(precision_score(mask[i].flatten(), reconstruction, average='weighted'))

    return precision

def f1_score_eval(model, image, mask): # Find F1-score
    prec = np.mean(precision_eval(model, image, mask))
    rec = np.mean(recall_eval(model, image, mask))

    if prec + rec == 0:
        return 0

    return 2 * (prec * rec) / (prec + rec)

def f1_score_eval_basic(precision, recall):
    prec = np.mean(precision)
    rec = np.mean(recall)

    if prec + rec == 0:
        return 0

    return 2 * (prec * rec) / (prec + rec)

def produce_mask(image): # Outputs rounded image (binary)
  return np.round(image)

# %% [markdown]
# # Ingest and Process RGB Dataset

# %%
# Ingest images

## Training images
training_images_list = os.listdir(r"{}Training/images/".format(base_dir))
training_masks_list = []
training_images = []
for n in training_images_list:
  im = PIL.Image.open(r"{}Training/images/{}".format(base_dir,n))
  training_images.append(im)
  training_masks_list.append(n[:-5]+'.png')

## Training masks
training_masks = []
for n in training_masks_list:
  im = PIL.Image.open(r"{}Training/masks/{}".format(base_dir,n))
  training_masks.append(im)

## Test images
test_images_list = os.listdir(r"{}Test/".format(base_dir))
test_images = []
for n in test_images_list:
  im = PIL.Image.open(r"{}Test/{}".format(base_dir,n))
  test_images.append(im)

## Validation images
validation_images_list = os.listdir(r"{}Validation/images/".format(base_dir))
validation_masks_list = []
validation_images = []
for n in validation_images_list:
  im = PIL.Image.open(r"{}Validation/images/{}".format(base_dir,n))
  validation_images.append(im)
  validation_masks_list.append(n[:-5]+'.png')

## Validation masks
validation_masks = []
for n in validation_masks_list:
  im = PIL.Image.open(r"{}Validation/masks/{}".format(base_dir,n))
  validation_masks.append(im)

# %%
# Pre-process data, normalise and reshape
for i in range(len(training_images)):
  training_images[i] = np.array(training_images[i])/255
  training_images[i] = training_images[i].reshape(512,512,3)
  training_images[i] = training_images[i].astype('float32')

for i in range(len(training_masks)):
  training_masks[i] = (np.array(training_masks[i])-1)
  training_masks[i] = training_masks[i][:512,:512]
  training_masks[i] = training_masks[i].reshape(512,512,1)
  training_masks[i] = training_masks[i].astype('int')

for i in range(len(validation_images)):
  validation_images[i] = np.array(validation_images[i])/255
  validation_images[i] = validation_images[i].reshape(1,512,512,3)
  validation_images[i] = validation_images[i].astype('float32')

for i in range(len(validation_masks)):
  validation_masks[i] = np.array(validation_masks[i])-1
  validation_masks[i] = validation_masks[i][:512,:512]
  validation_masks[i] = validation_masks[i].reshape(1,512,512,1)
  validation_masks[i] = validation_masks[i].astype('int')

for i in range(len(test_images)):
  test_images[i] = np.array(test_images[i])/255
  test_images[i] = test_images[i].reshape(1,512,512,3)
  test_images[i] = test_images[i].astype('float32')

# Add some training images to validation data to increase size of validation set
for i in range(25,30):
  validation_images.append(training_images[i].reshape(1,512,512,3))
  validation_masks.append(training_masks[i].reshape(1,512,512,1))

# Remove five images from training data, which has been added to validation data
training_images = training_images[0:25]
training_masks = training_masks[0:25]

# %%
# Create TensorFlow datasets for validation sets
validation_df = tf.data.Dataset.from_tensor_slices((validation_images, validation_masks))

# %%
#
# Data loader/generator from: https://github.com/bragagnololu/UNet-defmapping.git
#

def adjustData(img, mask, num_class):

    mask[mask > 0.5] = 1 # FOREST
    mask[mask <= 0.5] = 0 # NON-FOREST

    return (img,mask)

def trainGenerator(batch_size,
                   image_array,
                   mask_array,
                   aug_dict,
                   image_save_prefix  = "image",
                   mask_save_prefix  = "mask",
                   num_class = 2,
                   save_to_dir = None,
                   target_size = (512,512),
                   seed = 1):

    image_datagen = ImageDataGenerator(**aug_dict)
    mask_datagen = ImageDataGenerator(**aug_dict)

    image_generator = image_datagen.flow(image_array,
                                           batch_size = batch_size,
                                           save_to_dir = save_to_dir,
                                           save_prefix = image_save_prefix,
                                           seed = seed)

    mask_generator = mask_datagen.flow(mask_array,
                                           batch_size = batch_size,
                                           save_to_dir = save_to_dir,
                                           save_prefix = mask_save_prefix,
                                           seed = seed)

    train_generator = zip(image_generator, mask_generator)

    for (img,mask) in train_generator:
        img, mask = adjustData(img, mask, num_class)
        yield (img, mask)

# %%
#
# Produce generators for training images
#

t_images = np.stack(training_images)
t_masks = np.stack(training_masks)

v_images = np.stack(validation_images)
v_masks = np.stack(validation_masks)

# Set parameters for data augmentation
data_gen_args = dict(rotation_range=180,
                    width_shift_range=0.25,
                    height_shift_range=0.25,
                    shear_range=0.25,
                    zoom_range=0.25,
                    horizontal_flip=True,
                    vertical_flip = True,
                    fill_mode='reflect',
                    )

train = trainGenerator(1, t_images, t_masks, data_gen_args, save_to_dir=None)

# %% [markdown]
# # Ingest and Process 4-band Datasets

# %% [markdown]
# ## 4-band Amazon dataset

# %%
download = True # True, if files don't already exist in same directory
base_dir2 = r"./AMAZON/"

# %%
# Download data (Amazon)

if download:
    url = 'https://zenodo.org/record/4498086/files/AMAZON.rar?download=1'
    r = requests.get(url, allow_redirects=True)
    open('data2.rar', 'wb').write(r.content)

    if sys.platform != 'darwin':
        pyunpack.Archive('data2.rar').extractall('')

    else:
        with RarFile('data2.rar') as rf:
            rf.extractall()

# %%
# Ingest images and normalise

## Training images
training_images_list2 = os.listdir(r"{}Training/image/".format(base_dir2))[0:250]
training_masks_list2 = []
training_images2 = []
for n in training_images_list2:
  training_masks_list2.append(n)
  a = (np.array(rxr.open_rasterio(r"{}Training/image/{}".format(base_dir2,n))))
  a = (a-np.min(a)) / (np.max(a)-np.min(a))
  training_images2.append(a)

## Training masks
training_masks2 = []
for n in training_masks_list2:
  a = (np.array(rxr.open_rasterio(r"{}Training/label/{}".format(base_dir2,n))))
  training_masks2.append(a)

## Test images
test_images_list2 = os.listdir(r"{}Test/image/".format(base_dir2))
test_masks_list2 = []
test_images2 = []
for n in test_images_list2:
  test_masks_list2.append(n)
  a = (np.array(rxr.open_rasterio(r"{}Test/image/{}".format(base_dir2,n))))
  a = (a-np.min(a)) / (np.max(a)-np.min(a))
  test_images2.append(a)

## Test masks
test_masks2 = []
for n in test_masks_list2:
  a = (np.array(rxr.open_rasterio(r"{}Test/mask/{}".format(base_dir2,n))))
  test_masks2.append(a)

## Validation images
validation_images_list2 = os.listdir(r"{}Validation/images/".format(base_dir2))
validation_masks_list2 = []
validation_images2 = []
for n in validation_images_list2:
  validation_masks_list2.append(n)
  a = (np.array(rxr.open_rasterio(r"{}Validation/images/{}".format(base_dir2,n))))
  a = (a-np.min(a)) / (np.max(a)-np.min(a))
  validation_images2.append(a)

## Validation masks
validation_masks2 = []
for n in validation_masks_list2:
  a = (np.array(rxr.open_rasterio(r"{}Validation/masks/{}".format(base_dir2,n))))
  validation_masks2.append(a)

# %%
# Show example train image
plt.imshow((np.array(rxr.open_rasterio(r"{}Training/image/{}".format(base_dir2,training_images_list2[20])))[0,:,:]))

# %%
# Pre-process data, reshaping and transposing
for i in range(len(training_images2)):
  training_images2[i] = training_images2[i].astype('float32')
  training_images2[i] = training_images2[i].T

for i in range(len(training_masks2)):
  training_masks2[i] = training_masks2[i].reshape(1,512,512,1)
  training_masks2[i] = training_masks2[i].T

for i in range(len(validation_images2)):
  validation_images2[i] = validation_images2[i].astype('float32')
  validation_images2[i] = validation_images2[i].T

for i in range(len(validation_masks2)):
  validation_masks2[i] = validation_masks2[i].reshape(1,512,512,1)
  validation_masks2[i] = validation_masks2[i].T

for i in range(len(test_images2)):
  test_images2[i] = test_images2[i].astype('float32')
  test_images2[i] = test_images2[i].T

for i in range(len(test_masks2)):
  test_masks2[i] = test_masks2[i].reshape(1,512,512,1)
  test_masks2[i] = test_masks2[i].T

for i in range(len(training_images2)):
  training_images2[i] = training_images2[i].reshape(-1,512,512,4)

for i in range(len(validation_images2)):
  validation_images2[i] = validation_images2[i].reshape(-1,512,512,4)

for i in range(len(test_images2)):
  test_images2[i] = test_images2[i].reshape(-1,512,512,4)

# %%
# Create TensorFlow datasets for training and validation sets
train_df_4band_amazon = tf.data.Dataset.from_tensor_slices((training_images2[0:250], training_masks2[0:250]))
validation_df_4band_amazon = tf.data.Dataset.from_tensor_slices((validation_images2, validation_masks2))

# %% [markdown]
# ## 4-band Atlantic Forest dataset

# %%
download = True # True if files don't already exist in same directory
base_dir3 = r"./ATLANTIC FOREST/"

# %%
# Download data (Atlantic Forest)
if download:
    url = 'https://zenodo.org/record/4498086/files/ATLANTIC%20FOREST.rar?download=1'
    r = requests.get(url, allow_redirects=True)
    open('data3.rar', 'wb').write(r.content)

    if sys.platform != 'darwin':
        pyunpack.Archive('data3.rar').extractall('')

    else:
        with RarFile('data3.rar') as rf:
            rf.extractall()

# %%
# Ingest images and normalise

## Training images
training_images_list3 = os.listdir(r"{}Training/image/".format(base_dir3))[0:250]
training_masks_list3 = []
training_images3 = []
for n in training_images_list3:
  training_masks_list3.append(n)
  a = (np.array(rxr.open_rasterio(r"{}Training/image/{}".format(base_dir3,n))))
  a = (a-np.min(a)) / (np.max(a)-np.min(a))
  training_images3.append(a)

## Training masks
training_masks3 = []
for n in training_masks_list3:
  a = (np.array(rxr.open_rasterio(r"{}Training/label/{}".format(base_dir3,n))))
  training_masks3.append(a)

## Test images
test_images_list3 = os.listdir(r"{}Test/image/".format(base_dir3))
test_masks_list3 = []
test_images3 = []
for n in test_images_list3:
  test_masks_list3.append(n)
  a = (np.array(rxr.open_rasterio(r"{}Test/image/{}".format(base_dir3,n))))
  a = (a-np.min(a)) / (np.max(a)-np.min(a))
  test_images3.append(a)

## Test masks
test_masks3 = []
for n in test_masks_list3:
  a = (np.array(rxr.open_rasterio(r"{}Test/mask/{}".format(base_dir3,n))))
  test_masks3.append(a)

## Validation images
validation_images_list3 = os.listdir(r"{}Validation/images/".format(base_dir3))
validation_masks_list3 = []
validation_images3 = []
for n in validation_images_list3:
  validation_masks_list3.append(n)
  a = (np.array(rxr.open_rasterio(r"{}Validation/images/{}".format(base_dir3,n))))
  a = (a-np.min(a)) / (np.max(a)-np.min(a))
  validation_images3.append(a)

## Validation masks
validation_masks3 = []
for n in validation_masks_list3:
  a = (np.array(rxr.open_rasterio(r"{}Validation/masks/{}".format(base_dir3,n))))
  validation_masks3.append(a)

# %%
# Pre-process data, reshaping and transposing
for i in range(len(training_images3)):
  training_images3[i] = training_images3[i].astype('float32')
  training_images3[i] = training_images3[i].T

for i in range(len(training_masks3)):
  training_masks3[i] = training_masks3[i].reshape(1,512,512,1)
  training_masks3[i] = training_masks3[i].T

for i in range(len(validation_images3)):
  validation_images3[i] = validation_images3[i].astype('float32')
  validation_images3[i] = validation_images3[i].T

for i in range(len(validation_masks3)):
  validation_masks3[i] = validation_masks3[i].reshape(1,512,512,1)
  validation_masks3[i] = validation_masks3[i].T

for i in range(len(test_images3)):
  test_images3[i] = test_images3[i].astype('float32')
  test_images3[i] = test_images3[i].T

for i in range(len(test_masks3)):
  test_masks3[i] = test_masks3[i].reshape(1,512,512,1)
  test_masks3[i] = test_masks3[i].T


for i in range(len(training_images3)):
  training_images3[i] = training_images3[i].reshape(-1,512,512,4)

for i in range(len(validation_images3)):
  validation_images3[i] = validation_images3[i].reshape(-1,512,512,4)

for i in range(len(test_images3)):
  test_images3[i] = test_images3[i].reshape(-1,512,512,4)

# %%
# Plot example training image first band
plt.imshow(training_images3[0].reshape(512,512,4)[:,:,0])

# %%
# Create TensorFlow datasets for training and validation sets
train_df_4band_atlantic = tf.data.Dataset.from_tensor_slices((training_images3[0:250], training_masks3[0:250]))
validation_df_4band_atlantic = tf.data.Dataset.from_tensor_slices((validation_images3, validation_masks3))

# %% [markdown]
# # Models

# %% [markdown]
# ## U-Net

# %%
'''
  Convolutional block with set parameters and activation layer after
'''

def convBlock(input, filters, kernel, kernel_init='he_normal', act='relu', transpose=False):
  if transpose == False:
    #conv = ZeroPadding2D((1,1))(input)
    conv = Conv2D(filters, kernel, padding = 'same', kernel_initializer = kernel_init)(input)
  else:
    #conv = ZeroPadding2D((1,1))(input)
    conv = Conv2DTranspose(filters, kernel, padding = 'same', kernel_initializer = kernel_init)(input)

  conv = Activation(act)(conv)
  return conv

'''
  U-Net model
'''

def UNet(trained_weights = None, input_size = (512,512,4), drop_rate = 0.25, lr=0.0001):

    ## Can add pretrained weights by specifying 'trained_weights'

    # Input layer
    inputs = Input(input_size, batch_size=1)

    ## Contraction phase
    conv1 = convBlock(inputs, 64, 3)
    conv1 = convBlock(conv1, 64, 3)
    pool1 = MaxPooling2D(pool_size=(2, 2))(conv1)

    conv2 = convBlock(pool1, 128, 3)
    conv2 = convBlock(conv2, 128, 3)
    pool2 = MaxPooling2D(pool_size=(2, 2))(conv2)
    #drop2 = Dropout(drop_rate)(pool2)

    conv3 = convBlock(pool2, 256, 3)
    conv3 = convBlock(conv3, 256, 3)
    pool3 = MaxPooling2D(pool_size=(2, 2))(conv3)
    #drop3 = Dropout(drop_rate)(pool3)

    conv4 = convBlock(pool3, 512, 3)
    conv4 = convBlock(conv4, 512, 3)
    pool4 = MaxPooling2D(pool_size=(2, 2))(conv4)
    #drop4 = Dropout(drop_rate)(pool4)

    conv5 = convBlock(pool4, 1024, 3)
    conv5 = convBlock(conv5, 1024, 3)

    ## Expansion phase
    up6 = (Conv2DTranspose(512, kernel_size=2, strides=2, kernel_initializer='he_normal')(conv5))
    merge6 = concatenate([conv4,up6])
    conv6 = convBlock(merge6, 512, 3)
    conv6 = convBlock(conv6, 512, 3)
    #conv6 = Dropout(drop_rate)(conv6)

    up7 = (Conv2DTranspose(256, kernel_size=2, strides=2, kernel_initializer='he_normal')(conv6))
    merge7 = concatenate([conv3,up7])
    conv7 = convBlock(merge7, 256, 3)
    conv7 = convBlock(conv7, 256, 3)
    #conv7 = Dropout(drop_rate)(conv7)

    up8 = (Conv2DTranspose(128, kernel_size=2, strides=2, kernel_initializer='he_normal')(conv7))
    merge8 = concatenate([conv2,up8])
    conv8 = convBlock(merge8, 128, 3)
    conv8 = convBlock(conv8, 128, 3)
    #conv8 = Dropout(drop_rate)(conv8)

    up9 = (Conv2DTranspose(64, kernel_size=2, strides=2, kernel_initializer='he_normal')(conv8))
    merge9 = concatenate([conv1,up9])
    conv9 = convBlock(merge9, 64, 3)
    conv9 = convBlock(conv9, 64, 3)

    # Output layer
    conv10 = convBlock(conv9, 1, 1, act='sigmoid')

    model = Model(inputs, conv10)

    model.compile(optimizer = Adam(learning_rate = lr), loss = 'binary_crossentropy', metrics = ['accuracy', 'mse'])

    if trained_weights != None:
    	model.load_weights(trained_weights)

    return model

# %%
# Print model layers and number of parameters
UNet().summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (1, 512, 512, 3)  │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d (Conv2D)     │ (1, 512, 512, 64) │      1,792 │ input_layer[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation          │ (1, 512, 512, 64) │          0 │ conv2d[0][0]      │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_1 (Conv2D)   │ (1, 512, 512, 64) │     36,928 │ activation[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_1        │ (1, 512, 512, 64) │          0 │ conv2d_1[0][0]    │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d       │ (1, 256, 256, 64) │          0 │ activation_1[0][… │
# │ (MaxPooling2D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_2 (Conv2D)   │ (1, 256, 256,     │     73,856 │ max_pooling2d[0]… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_2        │ (1, 256, 256,     │          0 │ conv2d_2[0][0]    │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_3 (Conv2D)   │ (1, 256, 256,     │    147,584 │ activation_2[0][… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_3        │ (1, 256, 256,     │          0 │ conv2d_3[0][0]    │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_1     │ (1, 128, 128,     │          0 │ activation_3[0][… │
# │ (MaxPooling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_4 (Conv2D)   │ (1, 128, 128,     │    295,168 │ max_pooling2d_1[… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_4        │ (1, 128, 128,     │          0 │ conv2d_4[0][0]    │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_5 (Conv2D)   │ (1, 128, 128,     │    590,080 │ activation_4[0][… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_5        │ (1, 128, 128,     │          0 │ conv2d_5[0][0]    │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_2     │ (1, 64, 64, 256)  │          0 │ activation_5[0][… │
# │ (MaxPooling2D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_6 (Conv2D)   │ (1, 64, 64, 512)  │  1,180,160 │ max_pooling2d_2[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_6        │ (1, 64, 64, 512)  │          0 │ conv2d_6[0][0]    │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_7 (Conv2D)   │ (1, 64, 64, 512)  │  2,359,808 │ activation_6[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_7        │ (1, 64, 64, 512)  │          0 │ conv2d_7[0][0]    │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_3     │ (1, 32, 32, 512)  │          0 │ activation_7[0][… │
# │ (MaxPooling2D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_8 (Conv2D)   │ (1, 32, 32, 1024) │  4,719,616 │ max_pooling2d_3[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_8        │ (1, 32, 32, 1024) │          0 │ conv2d_8[0][0]    │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_9 (Conv2D)   │ (1, 32, 32, 1024) │  9,438,208 │ activation_8[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_9        │ (1, 32, 32, 1024) │          0 │ conv2d_9[0][0]    │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose    │ (1, 64, 64, 512)  │  2,097,664 │ activation_9[0][… │
# │ (Conv2DTranspose)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate         │ (1, 64, 64, 1024) │          0 │ activation_7[0][… │
# │ (Concatenate)       │                   │            │ conv2d_transpose… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_10 (Conv2D)  │ (1, 64, 64, 512)  │  4,719,104 │ concatenate[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_10       │ (1, 64, 64, 512)  │          0 │ conv2d_10[0][0]   │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_11 (Conv2D)  │ (1, 64, 64, 512)  │  2,359,808 │ activation_10[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_11       │ (1, 64, 64, 512)  │          0 │ conv2d_11[0][0]   │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_1  │ (1, 128, 128,     │    524,544 │ activation_11[0]… │
# │ (Conv2DTranspose)   │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_1       │ (1, 128, 128,     │          0 │ activation_5[0][… │
# │ (Concatenate)       │ 512)              │            │ conv2d_transpose… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_12 (Conv2D)  │ (1, 128, 128,     │  1,179,904 │ concatenate_1[0]… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_12       │ (1, 128, 128,     │          0 │ conv2d_12[0][0]   │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_13 (Conv2D)  │ (1, 128, 128,     │    590,080 │ activation_12[0]… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_13       │ (1, 128, 128,     │          0 │ conv2d_13[0][0]   │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_2  │ (1, 256, 256,     │    131,200 │ activation_13[0]… │
# │ (Conv2DTranspose)   │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_2       │ (1, 256, 256,     │          0 │ activation_3[0][… │
# │ (Concatenate)       │ 256)              │            │ conv2d_transpose… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_14 (Conv2D)  │ (1, 256, 256,     │    295,040 │ concatenate_2[0]… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_14       │ (1, 256, 256,     │          0 │ conv2d_14[0][0]   │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_15 (Conv2D)  │ (1, 256, 256,     │    147,584 │ activation_14[0]… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_15       │ (1, 256, 256,     │          0 │ conv2d_15[0][0]   │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_3  │ (1, 512, 512, 64) │     32,832 │ activation_15[0]… │
# │ (Conv2DTranspose)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_3       │ (1, 512, 512,     │          0 │ activation_1[0][… │
# │ (Concatenate)       │ 128)              │            │ conv2d_transpose… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_16 (Conv2D)  │ (1, 512, 512, 64) │     73,792 │ concatenate_3[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_16       │ (1, 512, 512, 64) │          0 │ conv2d_16[0][0]   │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_17 (Conv2D)  │ (1, 512, 512, 64) │     36,928 │ activation_16[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_17       │ (1, 512, 512, 64) │          0 │ conv2d_17[0][0]   │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_18 (Conv2D)  │ (1, 512, 512, 1)  │         65 │ activation_17[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_18       │ (1, 512, 512, 1)  │          0 │ conv2d_18[0][0]   │
# │ (Activation)        │                   │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 31,031,745 (118.38 MB)
#  Trainable params: 31,031,745 (118.38 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ## Attention U-Net

# %%
'''
  Convolutional block with two conv layers and two activation layers
'''

def convBlock2(input, filters, kernel, kernel_init='he_normal', act='relu', transpose=False):
  if transpose == False:
    conv = Conv2D(filters, kernel, padding = 'same', kernel_initializer = kernel_init)(input)
    conv = Activation(act)(conv)
    conv = Conv2D(filters, kernel, padding = 'same', kernel_initializer = kernel_init)(conv)
    conv = Activation(act)(conv)
  else:
    conv = Conv2DTranspose(filters, kernel, padding = 'same', kernel_initializer = kernel_init)(input)
    conv = Activation(act)(conv)
    conv = Conv2DTranspose(filters, kernel, padding = 'same', kernel_initializer = kernel_init)(conv)
    conv = Activation(act)(conv)

  return conv

'''
  Attention block/mechanism
'''
def attention_block(x, gating, inter_shape, drop_rate=0.25):

    # Find shape of inputs
    shape_x = K.int_shape(x)
    shape_g = K.int_shape(gating)

    ## Process x vector and gating signal
    # x vector input and processing
    theta_x = Conv2D(inter_shape, kernel_size = 1, strides = 1, padding='same', kernel_initializer='he_normal', activation=None)(x)
    theta_x = MaxPooling2D((2,2))(theta_x)
    shape_theta_x = K.int_shape(theta_x)

    # gating signal ""
    phi_g = Conv2D(inter_shape, kernel_size = 1, strides = 1, padding='same', kernel_initializer='he_normal', activation=None)(gating)
    shape_phi_g = K.int_shape(phi_g)

    # Add components
    concat_xg = add([phi_g, theta_x])
    act_xg = Activation('relu')(concat_xg)

    # Apply convolution
    psi = Conv2D(1, kernel_size = 1, strides = 1, padding='same', kernel_initializer='he_normal', activation=None)(act_xg)

    # Apply sigmoid activation
    sigmoid_xg = Activation('sigmoid')(psi)
    shape_sigmoid = K.int_shape(sigmoid_xg)

    # UpSample and resample to correct size
    upsample_psi = UpSampling2D(interpolation='bilinear', size=(shape_x[1] // shape_sigmoid[1], shape_x[2] // shape_sigmoid[2]))(sigmoid_xg)
    y = multiply([upsample_psi, x])

    return y


'''
  Attention U-Net model
'''

def UNetAM(trained_weights = None, input_size = (512,512,3), drop_rate = 0.25, lr=0.0001, filter_base=16):

    ## Can add pretrained weights by specifying 'trained_weights'

    # Input layer
    inputs = Input(input_size, batch_size=1)

    ## Contraction phase
    conv = convBlock2(inputs, filter_base, 3)
    #conv0 = Dropout(drop_rate)(conv0)

    conv0 = MaxPooling2D(pool_size=(2, 2))(conv)
    conv0 = convBlock2(conv0, 2 * filter_base, 3)

    pool0 = MaxPooling2D(pool_size=(2, 2))(conv0)
    conv1 = convBlock2(pool0, 4 * filter_base, 3)
    #conv1 = Dropout(drop_rate)(conv1)

    pool1 = MaxPooling2D(pool_size=(2, 2))(conv1)
    conv2 = convBlock2(pool1, 8 * filter_base, 3)
    #conv2 = Dropout(drop_rate)(conv2)

    pool2 = MaxPooling2D(pool_size=(2, 2))(conv2)
    conv3 = convBlock2(pool2, 16 * filter_base, 3)
    #conv3 = Dropout(drop_rate)(conv3)

    ## Expansion phase
    up4 = (Conv2DTranspose(8 * filter_base, kernel_size=2, strides=2, kernel_initializer='he_normal')(conv3))
    merge4 = attention_block(conv2, conv3, 8 * filter_base, drop_rate) # Attention gate
    conv4 = concatenate([up4, merge4])
    conv4 = convBlock2(conv4, 8 * filter_base, 3)

    up5 = (Conv2DTranspose(4 * filter_base, kernel_size=2, strides=2, kernel_initializer='he_normal')(conv4))
    merge5 = attention_block(conv1, conv4, 4 * filter_base, drop_rate) # Attention gate
    conv5 = concatenate([up5, merge5])
    conv5 = convBlock2(conv5, 4 * filter_base, 3)

    up6 = (Conv2DTranspose(2 * filter_base, kernel_size=2, strides=2, kernel_initializer='he_normal')(conv5))
    merge6 = attention_block(conv0, conv5, 2 * filter_base, drop_rate) # Attention gate
    conv6 = concatenate([up6, merge6])
    conv6 = convBlock2(conv6, 2 * filter_base, 3)

    up7 = (Conv2DTranspose(1 * filter_base, kernel_size=2, strides=2, kernel_initializer='he_normal')(conv6))
    merge7 = attention_block(conv, conv6, 1 * filter_base, drop_rate) # Attention gate
    conv7 = concatenate([up7, merge7])
    conv7 = concatenate([up7, conv])
    conv7 = convBlock2(conv7, 1 * filter_base, 3)

    ## Output layer
    out = convBlock(conv7, 1, 1, act='sigmoid')

    model = Model(inputs, out)

    model.compile(optimizer = Adam(learning_rate = lr), loss = binary_crossentropy, metrics = ['accuracy', 'mse'])

    if trained_weights != None:
    	model.load_weights(trained_weights)

    return model

# %%
# Print model layers and number of parameters
UNetAM().summary()
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_3       │ (1, 512, 512, 3)  │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_45 (Conv2D)  │ (1, 512, 512, 16) │        448 │ input_layer_3[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_43       │ (1, 512, 512, 16) │          0 │ conv2d_45[0][0]   │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_46 (Conv2D)  │ (1, 512, 512, 16) │      2,320 │ activation_43[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_44       │ (1, 512, 512, 16) │          0 │ conv2d_46[0][0]   │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_14    │ (1, 256, 256, 16) │          0 │ activation_44[0]… │
# │ (MaxPooling2D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_47 (Conv2D)  │ (1, 256, 256, 32) │      4,640 │ max_pooling2d_14… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_45       │ (1, 256, 256, 32) │          0 │ conv2d_47[0][0]   │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_48 (Conv2D)  │ (1, 256, 256, 32) │      9,248 │ activation_45[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_46       │ (1, 256, 256, 32) │          0 │ conv2d_48[0][0]   │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_15    │ (1, 128, 128, 32) │          0 │ activation_46[0]… │
# │ (MaxPooling2D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_49 (Conv2D)  │ (1, 128, 128, 64) │     18,496 │ max_pooling2d_15… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_47       │ (1, 128, 128, 64) │          0 │ conv2d_49[0][0]   │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_50 (Conv2D)  │ (1, 128, 128, 64) │     36,928 │ activation_47[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_48       │ (1, 128, 128, 64) │          0 │ conv2d_50[0][0]   │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_16    │ (1, 64, 64, 64)   │          0 │ activation_48[0]… │
# │ (MaxPooling2D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_51 (Conv2D)  │ (1, 64, 64, 128)  │     73,856 │ max_pooling2d_16… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_49       │ (1, 64, 64, 128)  │          0 │ conv2d_51[0][0]   │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_52 (Conv2D)  │ (1, 64, 64, 128)  │    147,584 │ activation_49[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_50       │ (1, 64, 64, 128)  │          0 │ conv2d_52[0][0]   │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_17    │ (1, 32, 32, 128)  │          0 │ activation_50[0]… │
# │ (MaxPooling2D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_53 (Conv2D)  │ (1, 32, 32, 256)  │    295,168 │ max_pooling2d_17… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_51       │ (1, 32, 32, 256)  │          0 │ conv2d_53[0][0]   │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_54 (Conv2D)  │ (1, 32, 32, 256)  │    590,080 │ activation_51[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_52       │ (1, 32, 32, 256)  │          0 │ conv2d_54[0][0]   │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_55 (Conv2D)  │ (1, 64, 64, 128)  │     16,512 │ activation_50[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_56 (Conv2D)  │ (1, 32, 32, 128)  │     32,896 │ activation_52[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_18    │ (1, 32, 32, 128)  │          0 │ conv2d_55[0][0]   │
# │ (MaxPooling2D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_2 (Add)         │ (1, 32, 32, 128)  │          0 │ conv2d_56[0][0],  │
# │                     │                   │            │ max_pooling2d_18… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_53       │ (1, 32, 32, 128)  │          0 │ add_2[0][0]       │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_57 (Conv2D)  │ (1, 32, 32, 1)    │        129 │ activation_53[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_54       │ (1, 32, 32, 1)    │          0 │ conv2d_57[0][0]   │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_2     │ (1, 64, 64, 1)    │          0 │ activation_54[0]… │
# │ (UpSampling2D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_6  │ (1, 64, 64, 128)  │    131,200 │ activation_52[0]… │
# │ (Conv2DTranspose)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply (Multiply) │ (1, 64, 64, 128)  │          0 │ up_sampling2d_2[… │
# │                     │                   │            │ activation_50[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_4       │ (1, 64, 64, 256)  │          0 │ conv2d_transpose… │
# │ (Concatenate)       │                   │            │ multiply[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_58 (Conv2D)  │ (1, 64, 64, 128)  │    295,040 │ concatenate_4[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_55       │ (1, 64, 64, 128)  │          0 │ conv2d_58[0][0]   │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_59 (Conv2D)  │ (1, 64, 64, 128)  │    147,584 │ activation_55[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_56       │ (1, 64, 64, 128)  │          0 │ conv2d_59[0][0]   │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_60 (Conv2D)  │ (1, 128, 128, 64) │      4,160 │ activation_48[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_61 (Conv2D)  │ (1, 64, 64, 64)   │      8,256 │ activation_56[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_19    │ (1, 64, 64, 64)   │          0 │ conv2d_60[0][0]   │
# │ (MaxPooling2D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_3 (Add)         │ (1, 64, 64, 64)   │          0 │ conv2d_61[0][0],  │
# │                     │                   │            │ max_pooling2d_19… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_57       │ (1, 64, 64, 64)   │          0 │ add_3[0][0]       │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_62 (Conv2D)  │ (1, 64, 64, 1)    │         65 │ activation_57[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_58       │ (1, 64, 64, 1)    │          0 │ conv2d_62[0][0]   │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_3     │ (1, 128, 128, 1)  │          0 │ activation_58[0]… │
# │ (UpSampling2D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_7  │ (1, 128, 128, 64) │     32,832 │ activation_56[0]… │
# │ (Conv2DTranspose)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_1          │ (1, 128, 128, 64) │          0 │ up_sampling2d_3[… │
# │ (Multiply)          │                   │            │ activation_48[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_5       │ (1, 128, 128,     │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 128)              │            │ multiply_1[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_63 (Conv2D)  │ (1, 128, 128, 64) │     73,792 │ concatenate_5[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_59       │ (1, 128, 128, 64) │          0 │ conv2d_63[0][0]   │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_64 (Conv2D)  │ (1, 128, 128, 64) │     36,928 │ activation_59[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_60       │ (1, 128, 128, 64) │          0 │ conv2d_64[0][0]   │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_65 (Conv2D)  │ (1, 256, 256, 32) │      1,056 │ activation_46[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_66 (Conv2D)  │ (1, 128, 128, 32) │      2,080 │ activation_60[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_20    │ (1, 128, 128, 32) │          0 │ conv2d_65[0][0]   │
# │ (MaxPooling2D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_4 (Add)         │ (1, 128, 128, 32) │          0 │ conv2d_66[0][0],  │
# │                     │                   │            │ max_pooling2d_20… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_61       │ (1, 128, 128, 32) │          0 │ add_4[0][0]       │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_67 (Conv2D)  │ (1, 128, 128, 1)  │         33 │ activation_61[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_62       │ (1, 128, 128, 1)  │          0 │ conv2d_67[0][0]   │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_4     │ (1, 256, 256, 1)  │          0 │ activation_62[0]… │
# │ (UpSampling2D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_8  │ (1, 256, 256, 32) │      8,224 │ activation_60[0]… │
# │ (Conv2DTranspose)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_2          │ (1, 256, 256, 32) │          0 │ up_sampling2d_4[… │
# │ (Multiply)          │                   │            │ activation_46[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_6       │ (1, 256, 256, 64) │          0 │ conv2d_transpose… │
# │ (Concatenate)       │                   │            │ multiply_2[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_68 (Conv2D)  │ (1, 256, 256, 32) │     18,464 │ concatenate_6[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_63       │ (1, 256, 256, 32) │          0 │ conv2d_68[0][0]   │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_69 (Conv2D)  │ (1, 256, 256, 32) │      9,248 │ activation_63[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_64       │ (1, 256, 256, 32) │          0 │ conv2d_69[0][0]   │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_9  │ (1, 512, 512, 16) │      2,064 │ activation_64[0]… │
# │ (Conv2DTranspose)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_8       │ (1, 512, 512, 32) │          0 │ conv2d_transpose… │
# │ (Concatenate)       │                   │            │ activation_44[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_73 (Conv2D)  │ (1, 512, 512, 16) │      4,624 │ concatenate_8[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_67       │ (1, 512, 512, 16) │          0 │ conv2d_73[0][0]   │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_74 (Conv2D)  │ (1, 512, 512, 16) │      2,320 │ activation_67[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_68       │ (1, 512, 512, 16) │          0 │ conv2d_74[0][0]   │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_75 (Conv2D)  │ (1, 512, 512, 1)  │         17 │ activation_68[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_69       │ (1, 512, 512, 1)  │          0 │ conv2d_75[0][0]   │
# │ (Activation)        │                   │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 2,006,292 (7.65 MB)
#  Trainable params: 2,006,292 (7.65 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ## ResNet50-SegNet

# %%
import tensorflow as tf

# Turn off XLA (JIT) globally
tf.config.optimizer.set_jit(False)

# If you enabled it via env var, also do this BEFORE TF loads (best after restart):
# import os
# os.environ["TF_XLA_FLAGS"] = "--tf_xla_auto_jit=0"

# %%
# Forked code from: https://github.com/ykamikawa/tf-keras-SegNet

'''
  Unpooling using max pooling indices
'''

class MaxPoolingWithArgmax2D(Layer):
    def __init__(self, pool_size=(2, 2), strides=(2, 2), padding="SAME", **kwargs):
        super().__init__(**kwargs)
        self.pool_size = pool_size
        self.strides = strides
        self.padding = padding

    def call(self, inputs):
        ksize = [1, self.pool_size[0], self.pool_size[1], 1]
        strides = [1, self.strides[0], self.strides[1], 1]

        # include_batch_in_index=False -> indices are per-batch, easier to unpool
        output, argmax = tf.nn.max_pool_with_argmax(
            inputs,
            ksize=ksize,
            strides=strides,
            padding=self.padding,
            include_batch_in_index=False
        )
        argmax = tf.cast(argmax, tf.int32)
        return output, argmax


class MaxUnpooling2D(Layer):
    def __init__(self, size=(2, 2), **kwargs):
        super().__init__(**kwargs)
        self.size = size

    def call(self, inputs, output_shape=None):
        updates, mask = inputs
        updates = tf.convert_to_tensor(updates)
        mask = tf.cast(mask, tf.int32)

        in_shape = tf.shape(updates, out_type=tf.int32)

        if output_shape is None:
            output_shape = tf.stack([
                in_shape[0],
                in_shape[1] * self.size[0],
                in_shape[2] * self.size[1],
                in_shape[3]
            ])

        out_b = output_shape[0]
        out_w = output_shape[2]
        out_c = output_shape[3]

        # Flatten updates
        flat_updates = tf.reshape(updates, [-1])

        # mask is flattened index into (H*W*C) per batch
        out_hw_c = out_w * out_c

        # Build batch indices to match mask shape
        per_batch = tf.size(mask[0])
        b = tf.repeat(tf.range(out_b, dtype=tf.int32), per_batch)
        b = tf.reshape(b, tf.shape(mask))

        y = mask // out_hw_c
        x = (mask // out_c) % out_w
        c = mask % out_c

        indices = tf.stack([b, y, x, c], axis=-1)
        indices = tf.reshape(indices, [-1, 4])

        return tf.scatter_nd(indices, flat_updates, output_shape)

    def compute_output_shape(self, input_shape):
        updates_shape = input_shape[0]
        return (
            updates_shape[0],
            updates_shape[1] * self.size[0],
            updates_shape[2] * self.size[1],
            updates_shape[3],
        )


# ---------------------------
# 2) Model blocks (your original structure)
# ---------------------------

def resnetConvDownBlock(x, filters, kernel_sz, act='relu'):
    for _ in range(3):
        x = ZeroPadding2D((1, 1))(x)
        x = Conv2D(filters=filters, kernel_size=kernel_sz, kernel_initializer='he_normal')(x)
        x = Activation(act)(x)
    return x


def resnetConvUpBlock(x, skip_connection=None, filters=64, kernel_sz=3, act='relu'):
    out = UpSampling2D((2, 2))(x)

    for _ in range(3):
        out = ZeroPadding2D((1, 1))(out)
        out = Conv2D(filters=filters, kernel_size=kernel_sz, kernel_initializer='he_normal')(out)
        out = Activation(act)(out)

    if skip_connection is not None:
        out = Add()([out, skip_connection])

    return out


def ResNet50SegNet(input_size=(512, 512, 3), lr=1e-4, base_filters=64, kernel_sz=3):
    inputs = Input(input_size)

    # Encoder
    block1 = resnetConvDownBlock(inputs, filters=base_filters, kernel_sz=kernel_sz)
    pool1, mask1 = MaxPoolingWithArgmax2D((2, 2))(block1)

    block2 = resnetConvDownBlock(pool1, filters=2 * base_filters, kernel_sz=kernel_sz)
    pool2, mask2 = MaxPoolingWithArgmax2D((2, 2))(block2)

    block3 = resnetConvDownBlock(pool2, filters=4 * base_filters, kernel_sz=kernel_sz)
    pool3, mask3 = MaxPoolingWithArgmax2D((2, 2))(block3)

    block4 = resnetConvDownBlock(pool3, filters=8 * base_filters, kernel_sz=kernel_sz)
    pool4, mask4 = MaxPoolingWithArgmax2D((2, 2))(block4)

    block5 = resnetConvDownBlock(pool4, filters=16 * base_filters, kernel_sz=kernel_sz)
    pool5, mask5 = MaxPoolingWithArgmax2D((2, 2))(block5)

    # Decoder
    block5_ = resnetConvUpBlock(pool5, filters=16 * base_filters, kernel_sz=kernel_sz)

    unpool4 = MaxUnpooling2D((2, 2))([pool4, mask4])
    block4_ = resnetConvUpBlock(block5_, skip_connection=unpool4,
                                filters=8 * base_filters, kernel_sz=kernel_sz)

    unpool3 = MaxUnpooling2D((2, 2))([pool3, mask3])
    block3_ = resnetConvUpBlock(block4_, skip_connection=unpool3,
                                filters=4 * base_filters, kernel_sz=kernel_sz)

    unpool2 = MaxUnpooling2D((2, 2))([pool2, mask2])
    block2_ = resnetConvUpBlock(block3_, skip_connection=unpool2,
                                filters=2 * base_filters, kernel_sz=kernel_sz)

    unpool1 = MaxUnpooling2D((2, 2))([pool1, mask1])
    block1_ = resnetConvUpBlock(block2_, skip_connection=unpool1,
                                filters=base_filters, kernel_sz=kernel_sz)

    outputs = Conv2D(1, kernel_size=1, strides=1, kernel_initializer='he_normal')(block1_)
    outputs = Activation('sigmoid')(outputs)

    model = Model(inputs, outputs)
    model.compile(
        optimizer=Adam(learning_rate=lr),
        loss=tf.keras.losses.BinaryCrossentropy(),
        metrics=['accuracy', 'mse'],
        jit_compile=False  # extra safety
    )
    return model

# %%
# Print model layers and number of parameters
ResNet50SegNet().summary()
# Out:
# Model: "functional_44"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_62      │ (None, 512, 512,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ zero_padding2d_1323 │ (None, 514, 514,  │          0 │ input_layer_62[0… │
# │ (ZeroPadding2D)     │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_1535         │ (None, 512, 512,  │      1,792 │ zero_padding2d_1… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_1555     │ (None, 512, 512,  │          0 │ conv2d_1535[0][0] │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ zero_padding2d_1324 │ (None, 514, 514,  │          0 │ activation_1555[… │
# │ (ZeroPadding2D)     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_1536         │ (None, 512, 512,  │     36,928 │ zero_padding2d_1… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_1556     │ (None, 512, 512,  │          0 │ conv2d_1536[0][0] │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ zero_padding2d_1325 │ (None, 514, 514,  │          0 │ activation_1556[… │
# │ (ZeroPadding2D)     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_1537         │ (None, 512, 512,  │     36,928 │ zero_padding2d_1… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_1557     │ (None, 512, 512,  │          0 │ conv2d_1537[0][0] │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling_with_a… │ [(None, 256, 256, │          0 │ activation_1557[… │
# │ (MaxPoolingWithArg… │ 64), (None, 256,  │            │                   │
# │                     │ 256, 64)]         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ zero_padding2d_1326 │ (None, 258, 258,  │          0 │ max_pooling_with… │
# │ (ZeroPadding2D)     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_1538         │ (None, 256, 256,  │     73,856 │ zero_padding2d_1… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_1558     │ (None, 256, 256,  │          0 │ conv2d_1538[0][0] │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ zero_padding2d_1327 │ (None, 258, 258,  │          0 │ activation_1558[… │
# │ (ZeroPadding2D)     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_1539         │ (None, 256, 256,  │    147,584 │ zero_padding2d_1… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_1559     │ (None, 256, 256,  │          0 │ conv2d_1539[0][0] │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ zero_padding2d_1328 │ (None, 258, 258,  │          0 │ activation_1559[… │
# │ (ZeroPadding2D)     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_1540         │ (None, 256, 256,  │    147,584 │ zero_padding2d_1… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_1560     │ (None, 256, 256,  │          0 │ conv2d_1540[0][0] │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling_with_a… │ [(None, 128, 128, │          0 │ activation_1560[… │
# │ (MaxPoolingWithArg… │ 128), (None, 128, │            │                   │
# │                     │ 128, 128)]        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ zero_padding2d_1329 │ (None, 130, 130,  │          0 │ max_pooling_with… │
# │ (ZeroPadding2D)     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_1541         │ (None, 128, 128,  │    295,168 │ zero_padding2d_1… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_1561     │ (None, 128, 128,  │          0 │ conv2d_1541[0][0] │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ zero_padding2d_1330 │ (None, 130, 130,  │          0 │ activation_1561[… │
# │ (ZeroPadding2D)     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_1542         │ (None, 128, 128,  │    590,080 │ zero_padding2d_1… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_1562     │ (None, 128, 128,  │          0 │ conv2d_1542[0][0] │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ zero_padding2d_1331 │ (None, 130, 130,  │          0 │ activation_1562[… │
# │ (ZeroPadding2D)     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_1543         │ (None, 128, 128,  │    590,080 │ zero_padding2d_1… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_1563     │ (None, 128, 128,  │          0 │ conv2d_1543[0][0] │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling_with_a… │ [(None, 64, 64,   │          0 │ activation_1563[… │
# │ (MaxPoolingWithArg… │ 256), (None, 64,  │            │                   │
# │                     │ 64, 256)]         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ zero_padding2d_1332 │ (None, 66, 66,    │          0 │ max_pooling_with… │
# │ (ZeroPadding2D)     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_1544         │ (None, 64, 64,    │  1,180,160 │ zero_padding2d_1… │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_1564     │ (None, 64, 64,    │          0 │ conv2d_1544[0][0] │
# │ (Activation)        │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ zero_padding2d_1333 │ (None, 66, 66,    │          0 │ activation_1564[… │
# │ (ZeroPadding2D)     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_1545         │ (None, 64, 64,    │  2,359,808 │ zero_padding2d_1… │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_1565     │ (None, 64, 64,    │          0 │ conv2d_1545[0][0] │
# │ (Activation)        │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ zero_padding2d_1334 │ (None, 66, 66,    │          0 │ activation_1565[… │
# │ (ZeroPadding2D)     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_1546         │ (None, 64, 64,    │  2,359,808 │ zero_padding2d_1… │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_1566     │ (None, 64, 64,    │          0 │ conv2d_1546[0][0] │
# │ (Activation)        │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling_with_a… │ [(None, 32, 32,   │          0 │ activation_1566[… │
# │ (MaxPoolingWithArg… │ 512), (None, 32,  │            │                   │
# │                     │ 32, 512)]         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ zero_padding2d_1335 │ (None, 34, 34,    │          0 │ max_pooling_with… │
# │ (ZeroPadding2D)     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_1547         │ (None, 32, 32,    │  4,719,616 │ zero_padding2d_1… │
# │ (Conv2D)            │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_1567     │ (None, 32, 32,    │          0 │ conv2d_1547[0][0] │
# │ (Activation)        │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ zero_padding2d_1336 │ (None, 34, 34,    │          0 │ activation_1567[… │
# │ (ZeroPadding2D)     │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_1548         │ (None, 32, 32,    │  9,438,208 │ zero_padding2d_1… │
# │ (Conv2D)            │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_1568     │ (None, 32, 32,    │          0 │ conv2d_1548[0][0] │
# │ (Activation)        │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ zero_padding2d_1337 │ (None, 34, 34,    │          0 │ activation_1568[… │
# │ (ZeroPadding2D)     │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_1549         │ (None, 32, 32,    │  9,438,208 │ zero_padding2d_1… │
# │ (Conv2D)            │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_1569     │ (None, 32, 32,    │          0 │ conv2d_1549[0][0] │
# │ (Activation)        │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling_with_a… │ [(None, 16, 16,   │          0 │ activation_1569[… │
# │ (MaxPoolingWithArg… │ 1024), (None, 16, │            │                   │
# │                     │ 16, 1024)]        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_216   │ (None, 32, 32,    │          0 │ max_pooling_with… │
# │ (UpSampling2D)      │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ zero_padding2d_1338 │ (None, 34, 34,    │          0 │ up_sampling2d_21… │
# │ (ZeroPadding2D)     │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_1550         │ (None, 32, 32,    │  9,438,208 │ zero_padding2d_1… │
# │ (Conv2D)            │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_1570     │ (None, 32, 32,    │          0 │ conv2d_1550[0][0] │
# │ (Activation)        │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ zero_padding2d_1339 │ (None, 34, 34,    │          0 │ activation_1570[… │
# │ (ZeroPadding2D)     │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_1551         │ (None, 32, 32,    │  9,438,208 │ zero_padding2d_1… │
# │ (Conv2D)            │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_1571     │ (None, 32, 32,    │          0 │ conv2d_1551[0][0] │
# │ (Activation)        │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ zero_padding2d_1340 │ (None, 34, 34,    │          0 │ activation_1571[… │
# │ (ZeroPadding2D)     │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_1552         │ (None, 32, 32,    │  9,438,208 │ zero_padding2d_1… │
# │ (Conv2D)            │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_1572     │ (None, 32, 32,    │          0 │ conv2d_1552[0][0] │
# │ (Activation)        │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_217   │ (None, 64, 64,    │          0 │ activation_1572[… │
# │ (UpSampling2D)      │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ zero_padding2d_1341 │ (None, 66, 66,    │          0 │ up_sampling2d_21… │
# │ (ZeroPadding2D)     │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_1553         │ (None, 64, 64,    │  4,719,104 │ zero_padding2d_1… │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_1573     │ (None, 64, 64,    │          0 │ conv2d_1553[0][0] │
# │ (Activation)        │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ zero_padding2d_1342 │ (None, 66, 66,    │          0 │ activation_1573[… │
# │ (ZeroPadding2D)     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_1554         │ (None, 64, 64,    │  2,359,808 │ zero_padding2d_1… │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_1574     │ (None, 64, 64,    │          0 │ conv2d_1554[0][0] │
# │ (Activation)        │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ zero_padding2d_1343 │ (None, 66, 66,    │          0 │ activation_1574[… │
# │ (ZeroPadding2D)     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_1555         │ (None, 64, 64,    │  2,359,808 │ zero_padding2d_1… │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_1575     │ (None, 64, 64,    │          0 │ conv2d_1555[0][0] │
# │ (Activation)        │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_unpooling2d_155 │ (None, 64, 64,    │          0 │ max_pooling_with… │
# │ (MaxUnpooling2D)    │ 512)              │            │ max_pooling_with… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_167 (Add)       │ (None, 64, 64,    │          0 │ activation_1575[… │
# │                     │ 512)              │            │ max_unpooling2d_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_218   │ (None, 128, 128,  │          0 │ add_167[0][0]     │
# │ (UpSampling2D)      │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ zero_padding2d_1344 │ (None, 130, 130,  │          0 │ up_sampling2d_21… │
# │ (ZeroPadding2D)     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_1556         │ (None, 128, 128,  │  1,179,904 │ zero_padding2d_1… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_1576     │ (None, 128, 128,  │          0 │ conv2d_1556[0][0] │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ zero_padding2d_1345 │ (None, 130, 130,  │          0 │ activation_1576[… │
# │ (ZeroPadding2D)     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_1557         │ (None, 128, 128,  │    590,080 │ zero_padding2d_1… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_1577     │ (None, 128, 128,  │          0 │ conv2d_1557[0][0] │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ zero_padding2d_1346 │ (None, 130, 130,  │          0 │ activation_1577[… │
# │ (ZeroPadding2D)     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_1558         │ (None, 128, 128,  │    590,080 │ zero_padding2d_1… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_1578     │ (None, 128, 128,  │          0 │ conv2d_1558[0][0] │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_unpooling2d_156 │ (None, 128, 128,  │          0 │ max_pooling_with… │
# │ (MaxUnpooling2D)    │ 256)              │            │ max_pooling_with… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_168 (Add)       │ (None, 128, 128,  │          0 │ activation_1578[… │
# │                     │ 256)              │            │ max_unpooling2d_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_219   │ (None, 256, 256,  │          0 │ add_168[0][0]     │
# │ (UpSampling2D)      │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ zero_padding2d_1347 │ (None, 258, 258,  │          0 │ up_sampling2d_21… │
# │ (ZeroPadding2D)     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_1559         │ (None, 256, 256,  │    295,040 │ zero_padding2d_1… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_1579     │ (None, 256, 256,  │          0 │ conv2d_1559[0][0] │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ zero_padding2d_1348 │ (None, 258, 258,  │          0 │ activation_1579[… │
# │ (ZeroPadding2D)     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_1560         │ (None, 256, 256,  │    147,584 │ zero_padding2d_1… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_1580     │ (None, 256, 256,  │          0 │ conv2d_1560[0][0] │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ zero_padding2d_1349 │ (None, 258, 258,  │          0 │ activation_1580[… │
# │ (ZeroPadding2D)     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_1561         │ (None, 256, 256,  │    147,584 │ zero_padding2d_1… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_1581     │ (None, 256, 256,  │          0 │ conv2d_1561[0][0] │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_unpooling2d_157 │ (None, 256, 256,  │          0 │ max_pooling_with… │
# │ (MaxUnpooling2D)    │ 128)              │            │ max_pooling_with… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_169 (Add)       │ (None, 256, 256,  │          0 │ activation_1581[… │
# │                     │ 128)              │            │ max_unpooling2d_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_220   │ (None, 512, 512,  │          0 │ add_169[0][0]     │
# │ (UpSampling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ zero_padding2d_1350 │ (None, 514, 514,  │          0 │ up_sampling2d_22… │
# │ (ZeroPadding2D)     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_1562         │ (None, 512, 512,  │     73,792 │ zero_padding2d_1… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_1582     │ (None, 512, 512,  │          0 │ conv2d_1562[0][0] │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ zero_padding2d_1351 │ (None, 514, 514,  │          0 │ activation_1582[… │
# │ (ZeroPadding2D)     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_1563         │ (None, 512, 512,  │     36,928 │ zero_padding2d_1… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_1583     │ (None, 512, 512,  │          0 │ conv2d_1563[0][0] │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ zero_padding2d_1352 │ (None, 514, 514,  │          0 │ activation_1583[… │
# │ (ZeroPadding2D)     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_1564         │ (None, 512, 512,  │     36,928 │ zero_padding2d_1… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_1584     │ (None, 512, 512,  │          0 │ conv2d_1564[0][0] │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_unpooling2d_158 │ (None, 512, 512,  │          0 │ max_pooling_with… │
# │ (MaxUnpooling2D)    │ 64)               │            │ max_pooling_with… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_170 (Add)       │ (None, 512, 512,  │          0 │ activation_1584[… │
# │                     │ 64)               │            │ max_unpooling2d_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_1565         │ (None, 512, 512,  │         65 │ add_170[0][0]     │
# │ (Conv2D)            │ 1)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_1585     │ (None, 512, 512,  │          0 │ conv2d_1565[0][0] │
# │ (Activation)        │ 1)                │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 72,267,137 (275.68 MB)
#  Trainable params: 72,267,137 (275.68 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ## FCN32-VGG16

# %%
# Code forked and modified from: https://github.com/divamgupta/image-segmentation-keras

'''
  FCN32-VGG16 model
'''

def fcn_32(input_size = (512,512,3), lr = 0.0001, drop_rate = 0):

    kernel = 3
    filter_size = 64
    pad = 1
    pool_size = 2

    IMAGE_ORDERING = 'channels_last'
    # Input
    inputs = Input(shape=input_size)

    x = inputs
    levels = []

    ## Encoder
    # Block 1
    x = Conv2D(64, (3, 3), padding='same',
               name='block1_conv1', data_format=IMAGE_ORDERING)(inputs)
    x = Activation('relu')(x)
    x = Conv2D(64, (3, 3), padding='same',
               name='block1_conv2', data_format=IMAGE_ORDERING)(x)
    x = Activation('relu')(x)
    x = MaxPooling2D((2, 2), strides=(2, 2), name='block1_pool',
                     data_format=IMAGE_ORDERING)(x)
    levels.append(x)

    # Block 2
    x = Conv2D(128, (3, 3), padding='same',
               name='block2_conv1', data_format=IMAGE_ORDERING)(x)
    x = Activation('relu')(x)
    x = Conv2D(128, (3, 3), padding='same',
               name='block2_conv2', data_format=IMAGE_ORDERING)(x)
    x = Activation('relu')(x)
    x = MaxPooling2D((2, 2), strides=(2, 2), name='block2_pool',
                     data_format=IMAGE_ORDERING)(x)
    levels.append(x)

    # Block 3
    x = Conv2D(256, (3, 3), padding='same',
               name='block3_conv1', data_format=IMAGE_ORDERING)(x)
    x = Activation('relu')(x)
    x = Conv2D(256, (3, 3), padding='same',
               name='block3_conv2', data_format=IMAGE_ORDERING)(x)
    x = Activation('relu')(x)
    x = Conv2D(256, (3, 3), padding='same',
               name='block3_conv3', data_format=IMAGE_ORDERING)(x)
    x = Activation('relu')(x)
    x = MaxPooling2D((2, 2), strides=(2, 2), name='block3_pool',
                     data_format=IMAGE_ORDERING)(x)
    levels.append(x)

    # Block 4
    x = Conv2D(512, (3, 3), padding='same',
               name='block4_conv1', data_format=IMAGE_ORDERING)(x)
    x = Activation('relu')(x)
    x = Conv2D(512, (3, 3), padding='same',
               name='block4_conv2', data_format=IMAGE_ORDERING)(x)
    x = Activation('relu')(x)
    x = Conv2D(512, (3, 3), padding='same',
               name='block4_conv3', data_format=IMAGE_ORDERING)(x)
    x = Activation('relu')(x)
    x = MaxPooling2D((2, 2), strides=(2, 2), name='block4_pool',
                     data_format=IMAGE_ORDERING)(x)
    levels.append(x)

    # Block 5
    x = Conv2D(512, (3, 3), padding='same',
               name='block5_conv1', data_format=IMAGE_ORDERING)(x)
    x = Activation('relu')(x)
    x = Conv2D(512, (3, 3), padding='same',
               name='block5_conv2', data_format=IMAGE_ORDERING)(x)
    x = Activation('relu')(x)
    x = Conv2D(512, (3, 3), padding='same',
               name='block5_conv3', data_format=IMAGE_ORDERING)(x)
    x = Activation('relu')(x)
    x = MaxPooling2D((2, 2), strides=(2, 2), name='block5_pool',
                     data_format=IMAGE_ORDERING)(x)

    levels.append(x)

    [f1, f2, f3, f4, f5] = levels

    o = f5

    # Decoder
    o = (Conv2D(4096, (7 , 7 ), padding = 'same', kernel_initializer = 'he_normal', name = "conv6"))(o)
    o = Activation('relu')(o)
    o = Dropout(drop_rate)(o)
    o = (Conv2D(4096, (1 , 1 ), padding = 'same', kernel_initializer = 'he_normal', name = "conv7"))(o)
    o = Activation('relu')(o)
    o = Dropout(drop_rate)(o)

    o = (Conv2D(1, 1, padding='same', kernel_initializer='he_normal', name="scorer1"))(o)
    o = Conv2DTranspose(1, kernel_size=(64,64), padding='same', strides=(32,32), name="Upsample32")(o)
    o = (Conv2D(1, 1, padding='same', kernel_initializer='he_normal', name="output"))(o)

    # Output
    o = Activation('sigmoid')(o)

    model = Model(inputs, o)
    model.compile(optimizer = Adam(learning_rate = lr), loss = binary_crossentropy, metrics = ['accuracy', 'mse'])
    model.model_name = "fcn_32"
    return model

# %%
# Print model layers and number of parameters
fcn_32().summary()
# Out:
# Model: "functional_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_9 (InputLayer)      │ (None, 512, 512, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_conv1 (Conv2D)           │ (None, 512, 512, 64)   │         1,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_149 (Activation)     │ (None, 512, 512, 64)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_conv2 (Conv2D)           │ (None, 512, 512, 64)   │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_150 (Activation)     │ (None, 512, 512, 64)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_pool (MaxPooling2D)      │ (None, 256, 256, 64)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_conv1 (Conv2D)           │ (None, 256, 256, 128)  │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_151 (Activation)     │ (None, 256, 256, 128)  │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_conv2 (Conv2D)           │ (None, 256, 256, 128)  │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_152 (Activation)     │ (None, 256, 256, 128)  │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_pool (MaxPooling2D)      │ (None, 128, 128, 128)  │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv1 (Conv2D)           │ (None, 128, 128, 256)  │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_153 (Activation)     │ (None, 128, 128, 256)  │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv2 (Conv2D)           │ (None, 128, 128, 256)  │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_154 (Activation)     │ (None, 128, 128, 256)  │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv3 (Conv2D)           │ (None, 128, 128, 256)  │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_155 (Activation)     │ (None, 128, 128, 256)  │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_pool (MaxPooling2D)      │ (None, 64, 64, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv1 (Conv2D)           │ (None, 64, 64, 512)    │     1,180,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_156 (Activation)     │ (None, 64, 64, 512)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv2 (Conv2D)           │ (None, 64, 64, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_157 (Activation)     │ (None, 64, 64, 512)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv3 (Conv2D)           │ (None, 64, 64, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_158 (Activation)     │ (None, 64, 64, 512)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_pool (MaxPooling2D)      │ (None, 32, 32, 512)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv1 (Conv2D)           │ (None, 32, 32, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_159 (Activation)     │ (None, 32, 32, 512)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv2 (Conv2D)           │ (None, 32, 32, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_160 (Activation)     │ (None, 32, 32, 512)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv3 (Conv2D)           │ (None, 32, 32, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_161 (Activation)     │ (None, 32, 32, 512)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_pool (MaxPooling2D)      │ (None, 16, 16, 512)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv6 (Conv2D)                  │ (None, 16, 16, 4096)   │   102,764,544 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_162 (Activation)     │ (None, 16, 16, 4096)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 16, 16, 4096)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv7 (Conv2D)                  │ (None, 16, 16, 4096)   │    16,781,312 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_163 (Activation)     │ (None, 16, 16, 4096)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 16, 16, 4096)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ scorer1 (Conv2D)                │ (None, 16, 16, 1)      │         4,097 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Upsample32 (Conv2DTranspose)    │ (None, 512, 512, 1)    │         4,097 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ output (Conv2D)                 │ (None, 512, 512, 1)    │             2 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_164 (Activation)     │ (None, 512, 512, 1)    │             0 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 134,268,740 (512.19 MB)
#  Trainable params: 134,268,740 (512.19 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ## ResUNet

# %%
import tensorflow as tf

def res_block_initial(x, num_filters, kernel_size, strides, name):
    """Residual Unet block layer for first layer
    In the residual unet the first residual block does not contain an
    initial batch normalization and activation so we create this separate
    block for it.
    Args:
        x: tensor, image or image activation
        num_filters: list, contains the number of filters for each subblock
        kernel_size: int, size of the convolutional kernel
        strides: list, contains the stride for each subblock convolution
        name: name of the layer
    Returns:
        x1: tensor, output from residual connection of x and x1
    """

    if len(num_filters) == 1:
        num_filters = [num_filters[0], num_filters[0]]

    x1 = tf.keras.layers.Conv2D(filters=num_filters[0],
                                kernel_size=kernel_size,
                                strides=strides[0],
                                padding='same',
                                kernel_initializer = 'he_normal',
                                name=name+'_1')(x)
    #x1 = tf.keras.layers.BatchNormalization()(x1)
    x1 = tf.keras.layers.Activation('relu')(x1)
    x1 = tf.keras.layers.Conv2D(filters=num_filters[1],
                                kernel_size=kernel_size,
                                strides=strides[1],
                                padding='same',
                                kernel_initializer = 'he_normal',
                                name=name+'_2')(x1)

    x = tf.keras.layers.Conv2D(filters=num_filters[-1],
                                kernel_size=1,
                                strides=1,
                                padding='same',
                                kernel_initializer = 'he_normal',
                                name=name+'_shortcut')(x)
    #x = tf.keras.layers.BatchNormalization()(x)

    x1 = tf.keras.layers.Add()([x, x1])

    return x1

def res_block(x, num_filters, kernel_size, strides, name):
    """Residual Unet block layer
    Consists of batch norm and relu, folowed by conv, batch norm and relu and
    final convolution. The input is then put through
    Args:
        x: tensor, image or image activation
        num_filters: list, contains the number of filters for each subblock
        kernel_size: int, size of the convolutional kernel
        strides: list, contains the stride for each subblock convolution
        name: name of the layer
    Returns:
        x1: tensor, output from residual connection of x and x1
    """

    if len(num_filters) == 1:
        num_filters = [num_filters[0], num_filters[0]]

    #x1 = tf.keras.layers.BatchNormalization()(x)
    #x1 = tf.keras.layers.Activation('relu')(x1)
    x1 = tf.keras.layers.Activation('relu')(x)
    x1 = tf.keras.layers.Conv2D(filters=num_filters[0],
                                kernel_size=kernel_size,
                                strides=strides[0],
                                padding='same',
                                kernel_initializer = 'he_normal',
                                name=name+'_1')(x1)
    #x1 = tf.keras.layers.BatchNormalization()(x1)
    x1 = tf.keras.layers.Activation('relu')(x1)
    x1 = tf.keras.layers.Conv2D(filters=num_filters[1],
                                kernel_size=kernel_size,
                                strides=strides[1],
                                padding='same',
                                kernel_initializer = 'he_normal',
                                name=name+'_2')(x1)

    x = tf.keras.layers.Conv2D(filters=num_filters[-1],
                                    kernel_size=1,
                                    strides=strides[0],
                                    padding='same',
                                    kernel_initializer = 'he_normal',
                                    name=name+'_shortcut')(x)
    #x = tf.keras.layers.BatchNormalization()(x)

    x1 = tf.keras.layers.Add()([x, x1])

    return x1


def upsample(x, target_size):
    """"Upsampling function, upsamples the feature map
    Deep Residual Unet paper does not describe the upsampling function
    in detail. Original Unet uses a transpose convolution that downsamples
    the number of feature maps. In order to restrict the number of
    parameters here we use a bilinear resampling layer. This results in
    the concatentation layer concatenting feature maps with n and n/2
    features as opposed to n/2  and n/2 in the original unet.
    Args:
        x: tensor, feature map
        target_size: size to resize feature map to
    Returns:
        x_resized: tensor, upsampled feature map
    """

    x_resized = tf.keras.layers.Lambda(lambda x: tf.image.resize(x, target_size))(x)

    return x_resized

def encoder(x, num_filters, kernel_size):
    """Unet encoder
    Args:
        x: tensor, output from previous layer
        num_filters: list, number of filters for each decoder layer
        kernel_size: int, size of the convolutional kernel
    Returns:
        encoder_output: list, output from all encoder layers
    """

    x = res_block_initial(x, [num_filters[0]], kernel_size, strides=[1,1], name='layer1')

    encoder_output = [x]
    for i in range(1, len(num_filters)):
        layer = 'encoder_layer' + str(i)
        x = res_block(x, [num_filters[i]], kernel_size, strides=[2,1], name=layer)
        encoder_output.append(x)

    return encoder_output

def decoder(x, encoder_output, num_filters, kernel_size):
    """Unet decoder
    Args:
        x: tensor, output from previous layer
        encoder_output: list, output from all previous encoder layers
        num_filters: list, number of filters for each decoder layer
        kernel_size: int, size of the convolutional kernel
    Returns:
        x: tensor, output from last layer of decoder
    """

    for i in range(1, len(num_filters) + 1):
        layer = 'decoder_layer' + str(i)
        target_size = encoder_output[-i].shape[1:3]
        x = upsample(x, target_size)
        x = tf.keras.layers.Concatenate(axis=-1)([x, encoder_output[-i]])
        x = res_block(x, [num_filters[-i]], kernel_size, strides=[1,1], name=layer)

    return x


def res_unet(input_size, num_filters, kernel_size, num_channels, num_classes, lr = 0.0001, out_layer = 'sigmoid', lossfunc='binary_crossentropy', num_out=1):
    """Residual Unet
    Function that generates a residual unet
    Args:
        input_size: int, dimension of the input image
        num_layers: int, number of layers in the encoder half, excludes bridge
        num_filters: list, number of filters for each encoder layer
        kernel_size: size of the kernel, applied to all convolutions
        num_channels: int, number of channels for the input image
        num_classes: int, number of output classes for the output
    Returns:
        model: tensorflow keras model for residual unet architecture
    """

    x = tf.keras.Input(shape=[input_size, input_size, num_channels])

    encoder_output = encoder(x, num_filters, kernel_size)

    # bridge layer, number of filters is double that of the last encoder layer
    bridge = res_block(encoder_output[-1], [num_filters[-1]*2], kernel_size,
                        strides=[2,1], name='bridge')

    decoder_output = decoder(bridge, encoder_output, num_filters, kernel_size)

    output = tf.keras.layers.Conv2D(num_classes,
                                    kernel_size,
                                    strides=1,
                                    padding='same',
                                    kernel_initializer = 'he_normal',
                                    name='output')(decoder_output)

    output = Activation(out_layer)(output)

    model = tf.keras.Model(x, output)
    model.compile(optimizer = Adam(learning_rate = lr), loss = lossfunc, metrics=['accuracy', 'mse'])

    return model

# %%
res_unet(512, [64, 128, 256, 512], 3, 3, 1).summary()
# Out:
# Model: "functional_4"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_10      │ (None, 512, 512,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer1_1 (Conv2D)   │ (None, 512, 512,  │      1,792 │ input_layer_10[0… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_165      │ (None, 512, 512,  │          0 │ layer1_1[0][0]    │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer1_shortcut     │ (None, 512, 512,  │        256 │ input_layer_10[0… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer1_2 (Conv2D)   │ (None, 512, 512,  │     36,928 │ activation_165[0… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_10 (Add)        │ (None, 512, 512,  │          0 │ layer1_shortcut[… │
# │                     │ 64)               │            │ layer1_2[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_166      │ (None, 512, 512,  │          0 │ add_10[0][0]      │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ encoder_layer1_1    │ (None, 256, 256,  │     73,856 │ activation_166[0… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_167      │ (None, 256, 256,  │          0 │ encoder_layer1_1… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ encoder_layer1_sho… │ (None, 256, 256,  │      8,320 │ add_10[0][0]      │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ encoder_layer1_2    │ (None, 256, 256,  │    147,584 │ activation_167[0… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_11 (Add)        │ (None, 256, 256,  │          0 │ encoder_layer1_s… │
# │                     │ 128)              │            │ encoder_layer1_2… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_168      │ (None, 256, 256,  │          0 │ add_11[0][0]      │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ encoder_layer2_1    │ (None, 128, 128,  │    295,168 │ activation_168[0… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_169      │ (None, 128, 128,  │          0 │ encoder_layer2_1… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ encoder_layer2_sho… │ (None, 128, 128,  │     33,024 │ add_11[0][0]      │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ encoder_layer2_2    │ (None, 128, 128,  │    590,080 │ activation_169[0… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_12 (Add)        │ (None, 128, 128,  │          0 │ encoder_layer2_s… │
# │                     │ 256)              │            │ encoder_layer2_2… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_170      │ (None, 128, 128,  │          0 │ add_12[0][0]      │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ encoder_layer3_1    │ (None, 64, 64,    │  1,180,160 │ activation_170[0… │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_171      │ (None, 64, 64,    │          0 │ encoder_layer3_1… │
# │ (Activation)        │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ encoder_layer3_sho… │ (None, 64, 64,    │    131,584 │ add_12[0][0]      │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ encoder_layer3_2    │ (None, 64, 64,    │  2,359,808 │ activation_171[0… │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_13 (Add)        │ (None, 64, 64,    │          0 │ encoder_layer3_s… │
# │                     │ 512)              │            │ encoder_layer3_2… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_172      │ (None, 64, 64,    │          0 │ add_13[0][0]      │
# │ (Activation)        │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ bridge_1 (Conv2D)   │ (None, 32, 32,    │  4,719,616 │ activation_172[0… │
# │                     │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_173      │ (None, 32, 32,    │          0 │ bridge_1[0][0]    │
# │ (Activation)        │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ bridge_shortcut     │ (None, 32, 32,    │    525,312 │ add_13[0][0]      │
# │ (Conv2D)            │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ bridge_2 (Conv2D)   │ (None, 32, 32,    │  9,438,208 │ activation_173[0… │
# │                     │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_14 (Add)        │ (None, 32, 32,    │          0 │ bridge_shortcut[… │
# │                     │ 1024)             │            │ bridge_2[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lambda (Lambda)     │ (None, 64, 64,    │          0 │ add_14[0][0]      │
# │                     │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_9       │ (None, 64, 64,    │          0 │ lambda[0][0],     │
# │ (Concatenate)       │ 1536)             │            │ add_13[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_174      │ (None, 64, 64,    │          0 │ concatenate_9[0]… │
# │ (Activation)        │ 1536)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ decoder_layer1_1    │ (None, 64, 64,    │  7,078,400 │ activation_174[0… │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_175      │ (None, 64, 64,    │          0 │ decoder_layer1_1… │
# │ (Activation)        │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ decoder_layer1_sho… │ (None, 64, 64,    │    786,944 │ concatenate_9[0]… │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ decoder_layer1_2    │ (None, 64, 64,    │  2,359,808 │ activation_175[0… │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_15 (Add)        │ (None, 64, 64,    │          0 │ decoder_layer1_s… │
# │                     │ 512)              │            │ decoder_layer1_2… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lambda_1 (Lambda)   │ (None, 128, 128,  │          0 │ add_15[0][0]      │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_10      │ (None, 128, 128,  │          0 │ lambda_1[0][0],   │
# │ (Concatenate)       │ 768)              │            │ add_12[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_176      │ (None, 128, 128,  │          0 │ concatenate_10[0… │
# │ (Activation)        │ 768)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ decoder_layer2_1    │ (None, 128, 128,  │  1,769,728 │ activation_176[0… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_177      │ (None, 128, 128,  │          0 │ decoder_layer2_1… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ decoder_layer2_sho… │ (None, 128, 128,  │    196,864 │ concatenate_10[0… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ decoder_layer2_2    │ (None, 128, 128,  │    590,080 │ activation_177[0… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_16 (Add)        │ (None, 128, 128,  │          0 │ decoder_layer2_s… │
# │                     │ 256)              │            │ decoder_layer2_2… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lambda_2 (Lambda)   │ (None, 256, 256,  │          0 │ add_16[0][0]      │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_11      │ (None, 256, 256,  │          0 │ lambda_2[0][0],   │
# │ (Concatenate)       │ 384)              │            │ add_11[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_178      │ (None, 256, 256,  │          0 │ concatenate_11[0… │
# │ (Activation)        │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ decoder_layer3_1    │ (None, 256, 256,  │    442,496 │ activation_178[0… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_179      │ (None, 256, 256,  │          0 │ decoder_layer3_1… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ decoder_layer3_sho… │ (None, 256, 256,  │     49,280 │ concatenate_11[0… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ decoder_layer3_2    │ (None, 256, 256,  │    147,584 │ activation_179[0… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_17 (Add)        │ (None, 256, 256,  │          0 │ decoder_layer3_s… │
# │                     │ 128)              │            │ decoder_layer3_2… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lambda_3 (Lambda)   │ (None, 512, 512,  │          0 │ add_17[0][0]      │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_12      │ (None, 512, 512,  │          0 │ lambda_3[0][0],   │
# │ (Concatenate)       │ 192)              │            │ add_10[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_180      │ (None, 512, 512,  │          0 │ concatenate_12[0… │
# │ (Activation)        │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ decoder_layer4_1    │ (None, 512, 512,  │    110,656 │ activation_180[0… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_181      │ (None, 512, 512,  │          0 │ decoder_layer4_1… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ decoder_layer4_sho… │ (None, 512, 512,  │     12,352 │ concatenate_12[0… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ decoder_layer4_2    │ (None, 512, 512,  │     36,928 │ activation_181[0… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_18 (Add)        │ (None, 512, 512,  │          0 │ decoder_layer4_s… │
# │                     │ 64)               │            │ decoder_layer4_2… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ output (Conv2D)     │ (None, 512, 512,  │        577 │ add_18[0][0]      │
# │                     │ 1)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_182      │ (None, 512, 512,  │          0 │ output[0][0]      │
# │ (Activation)        │ 1)                │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 33,123,393 (126.36 MB)
#  Trainable params: 33,123,393 (126.36 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# # Train on RGB feature data

# %% [markdown]
# ## U-Net

# %%
# Train U-Net with generator
model_unet = UNet(input_size=(512,512,3), lr=0.0001)
save_model = ModelCheckpoint('unet-3d.keras', monitor='val_accuracy',verbose=1, save_best_only=True)
train = trainGenerator(1, t_images, t_masks, data_gen_args, save_to_dir=None)

model_unet.fit(train, steps_per_epoch=100, epochs=30, validation_data = validation_df, callbacks=[save_model])
# Out:
# Epoch 1/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.5594 - loss: 0.6962 - mse: 0.2387
# Epoch 1: val_accuracy improved from -inf to 0.87446, saving model to unet-3d.keras
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 35s 119ms/step - accuracy: 0.5608 - loss: 0.6950 - mse: 0.2383 - val_accuracy: 0.8745 - val_loss: 0.3788 - val_mse: 0.1202
# Epoch 2/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.9019 - loss: 0.2987 - mse: 0.0859
# Epoch 2: val_accuracy improved from 0.87446 to 0.89121, saving model to unet-3d.keras
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 9s 90ms/step - accuracy: 0.9020 - loss: 0.2983 - mse: 0.0858 - val_accuracy: 0.8912 - val_loss: 0.2643 - val_mse: 0.0807
# Epoch 3/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.9344 - loss: 0.1965 - mse: 0.0524
# Epoch 3: val_accuracy improved from 0.89121 to 0.90198, saving model to unet-3d.keras
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 9s 92ms/step - accuracy: 0.9344 - loss: 0.1965 - mse: 0.0524 - val_accuracy: 0.9020 - val_loss: 0.2528 - val_mse: 0.0751
# Epoch 4/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.9412 - loss: 0.1679 - mse: 0.0454
# Epoch 4: val_accuracy did not improve from 0.90198
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 7s 70ms/step - accuracy: 0.9413 - loss: 0.1678 - mse: 0.0453 - val_accuracy: 0.8933 - val_loss: 0.3208 - val_mse: 0.0868
# Epoch 5/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.9363 - loss: 0.1924 - mse: 0.0514
# Epoch 5: val_accuracy improved from 0.90198 to 0.91078, saving model to unet-3d.keras
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 9s 87ms/step - accuracy: 0.9364 - loss: 0.1923 - mse: 0.0513 - val_accuracy: 0.9108 - val_loss: 0.2353 - val_mse: 0.0684
# Epoch 6/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.9455 - loss: 0.1612 - mse: 0.0429
# Epoch 6: val_accuracy improved from 0.91078 to 0.91108, saving model to unet-3d.keras
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 8s 80ms/step - accuracy: 0.9455 - loss: 0.1612 - mse: 0.0429 - val_accuracy: 0.9111 - val_loss: 0.2259 - val_mse: 0.0671
# Epoch 7/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.9468 - loss: 0.1513 - mse: 0.0411
# Epoch 7: val_accuracy improved from 0.91108 to 0.91147, saving model to unet-3d.keras
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 8s 77ms/step - accuracy: 0.9468 - loss: 0.1513 - mse: 0.0411 - val_accuracy: 0.9115 - val_loss: 0.2163 - val_mse: 0.0651
# Epoch 8/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.9449 - loss: 0.1660 - mse: 0.0439
# Epoch 8: val_accuracy did not improve from 0.91147
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 7s 70ms/step - accuracy: 0.9449 - loss: 0.1661 - mse: 0.0439 - val_accuracy: 0.9106 - val_loss: 0.2253 - val_mse: 0.0676
# Epoch 9/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.9561 - loss: 0.1310 - mse: 0.0342
# Epoch 9: val_accuracy improved from 0.91147 to 0.91270, saving model to unet-3d.keras
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 9s 90ms/step - accuracy: 0.9560 - loss: 0.1312 - mse: 0.0343 - val_accuracy: 0.9127 - val_loss: 0.2089 - val_mse: 0.0631
# Epoch 10/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.9485 - loss: 0.1544 - mse: 0.0410
# Epoch 10: val_accuracy improved from 0.91270 to 0.91601, saving model to unet-3d.keras
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 8s 79ms/step - accuracy: 0.9485 - loss: 0.1545 - mse: 0.0410 - val_accuracy: 0.9160 - val_loss: 0.2078 - val_mse: 0.0625
# Epoch 11/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.9539 - loss: 0.1426 - mse: 0.0367
# Epoch 11: val_accuracy improved from 0.91601 to 0.92050, saving model to unet-3d.keras
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 8s 78ms/step - accuracy: 0.9539 - loss: 0.1427 - mse: 0.0367 - val_accuracy: 0.9205 - val_loss: 0.1981 - val_mse: 0.0592
# Epoch 12/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.9574 - loss: 0.1295 - mse: 0.0334
# Epoch 12: val_accuracy did not improve from 0.92050
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 6s 62ms/step - accuracy: 0.9574 - loss: 0.1296 - mse: 0.0335 - val_accuracy: 0.9033 - val_loss: 0.2727 - val_mse: 0.0762
# Epoch 13/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.9446 - loss: 0.1687 - mse: 0.0438
# Epoch 13: val_accuracy did not improve from 0.92050
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 7s 75ms/step - accuracy: 0.9446 - loss: 0.1685 - mse: 0.0438 - val_accuracy: 0.9175 - val_loss: 0.2061 - val_mse: 0.0618
# Epoch 14/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.9546 - loss: 0.1368 - mse: 0.0356
# Epoch 14: val_accuracy did not improve from 0.92050
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 7s 73ms/step - accuracy: 0.9546 - loss: 0.1369 - mse: 0.0356 - val_accuracy: 0.9180 - val_loss: 0.2070 - val_mse: 0.0613
# Epoch 15/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 0.9496 - loss: 0.1441 - mse: 0.0390
# Epoch 15: val_accuracy improved from 0.92050 to 0.92079, saving model to unet-3d.keras
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 9s 93ms/step - accuracy: 0.9496 - loss: 0.1442 - mse: 0.0391 - val_accuracy: 0.9208 - val_loss: 0.1953 - val_mse: 0.0584
# Epoch 16/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.9564 - loss: 0.1260 - mse: 0.0333
# Epoch 16: val_accuracy improved from 0.92079 to 0.92321, saving model to unet-3d.keras
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 8s 77ms/step - accuracy: 0.9564 - loss: 0.1260 - mse: 0.0334 - val_accuracy: 0.9232 - val_loss: 0.1979 - val_mse: 0.0585
# Epoch 17/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.9547 - loss: 0.1264 - mse: 0.0344
# Epoch 17: val_accuracy improved from 0.92321 to 0.92365, saving model to unet-3d.keras
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 8s 76ms/step - accuracy: 0.9547 - loss: 0.1265 - mse: 0.0344 - val_accuracy: 0.9236 - val_loss: 0.1950 - val_mse: 0.0577
# Epoch 18/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.9588 - loss: 0.1216 - mse: 0.0318
# Epoch 18: val_accuracy did not improve from 0.92365
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 6s 64ms/step - accuracy: 0.9587 - loss: 0.1217 - mse: 0.0318 - val_accuracy: 0.9218 - val_loss: 0.1992 - val_mse: 0.0589
# Epoch 19/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.9534 - loss: 0.1374 - mse: 0.0364
# Epoch 19: val_accuracy improved from 0.92365 to 0.92912, saving model to unet-3d.keras
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 8s 85ms/step - accuracy: 0.9534 - loss: 0.1375 - mse: 0.0364 - val_accuracy: 0.9291 - val_loss: 0.1822 - val_mse: 0.0534
# Epoch 20/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.9551 - loss: 0.1371 - mse: 0.0356
# Epoch 20: val_accuracy did not improve from 0.92912
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 7s 66ms/step - accuracy: 0.9551 - loss: 0.1372 - mse: 0.0356 - val_accuracy: 0.9193 - val_loss: 0.2002 - val_mse: 0.0598
# Epoch 21/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.9581 - loss: 0.1229 - mse: 0.0326
# Epoch 21: val_accuracy did not improve from 0.92912
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 7s 74ms/step - accuracy: 0.9581 - loss: 0.1230 - mse: 0.0326 - val_accuracy: 0.9206 - val_loss: 0.2149 - val_mse: 0.0613
# Epoch 22/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.9532 - loss: 0.1417 - mse: 0.0369
# Epoch 22: val_accuracy did not improve from 0.92912
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 7s 73ms/step - accuracy: 0.9533 - loss: 0.1416 - mse: 0.0369 - val_accuracy: 0.9161 - val_loss: 0.2129 - val_mse: 0.0627
# Epoch 23/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.9535 - loss: 0.1377 - mse: 0.0365
# Epoch 23: val_accuracy did not improve from 0.92912
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 8s 80ms/step - accuracy: 0.9536 - loss: 0.1375 - mse: 0.0365 - val_accuracy: 0.9197 - val_loss: 0.2277 - val_mse: 0.0616
# Epoch 24/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.9542 - loss: 0.1408 - mse: 0.0363
# Epoch 24: val_accuracy did not improve from 0.92912
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 8s 78ms/step - accuracy: 0.9542 - loss: 0.1406 - mse: 0.0363 - val_accuracy: 0.9191 - val_loss: 0.2071 - val_mse: 0.0615
# Epoch 25/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.9554 - loss: 0.1328 - mse: 0.0350
# Epoch 25: val_accuracy did not improve from 0.92912
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 8s 77ms/step - accuracy: 0.9554 - loss: 0.1328 - mse: 0.0350 - val_accuracy: 0.9263 - val_loss: 0.2011 - val_mse: 0.0556
# Epoch 26/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.9539 - loss: 0.1364 - mse: 0.0358
# Epoch 26: val_accuracy did not improve from 0.92912
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 8s 76ms/step - accuracy: 0.9539 - loss: 0.1365 - mse: 0.0358 - val_accuracy: 0.9062 - val_loss: 0.2341 - val_mse: 0.0708
# Epoch 27/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.9594 - loss: 0.1172 - mse: 0.0311
# Epoch 27: val_accuracy improved from 0.92912 to 0.93237, saving model to unet-3d.keras
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 8s 85ms/step - accuracy: 0.9594 - loss: 0.1173 - mse: 0.0311 - val_accuracy: 0.9324 - val_loss: 0.1668 - val_mse: 0.0492
# Epoch 28/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.9571 - loss: 0.1297 - mse: 0.0340
# Epoch 28: val_accuracy did not improve from 0.93237
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 6s 64ms/step - accuracy: 0.9571 - loss: 0.1297 - mse: 0.0340 - val_accuracy: 0.9182 - val_loss: 0.2223 - val_mse: 0.0645
# Epoch 29/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.9597 - loss: 0.1186 - mse: 0.0316
# Epoch 29: val_accuracy did not improve from 0.93237
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 7s 74ms/step - accuracy: 0.9597 - loss: 0.1186 - mse: 0.0316 - val_accuracy: 0.9208 - val_loss: 0.1994 - val_mse: 0.0590
# Epoch 30/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.9547 - loss: 0.1321 - mse: 0.0354
# Epoch 30: val_accuracy did not improve from 0.93237
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 7s 74ms/step - accuracy: 0.9547 - loss: 0.1320 - mse: 0.0354 - val_accuracy: 0.9240 - val_loss: 0.1954 - val_mse: 0.0574

# %%
# Save model training history
np.save('unet-3d-history.npy',model_unet.history.history)

# %%
# Copy models to drive
# !cp unet-3d.keras drive/MyDrive/Diss/
# !cp unet-3d-history.npy drive/MyDrive/Diss/

# %%
# Plot accuracy and loss

## Accuracy
plt.plot(model_unet.history.history['accuracy'])
plt.plot(model_unet.history.history['val_accuracy'])
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Training', 'Validation'], loc='upper left')
plt.show()

## Loss
plt.plot(model_unet.history.history['loss'])
plt.plot(model_unet.history.history['val_loss'])
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Training', 'Validation'], loc='upper left')

# %% [markdown]
# ## Attention U-Net

# %%
# Train Attention U-Net with generator
model_attention_unet = UNetAM(lr=0.0005, filter_base=16)
save_model_am = ModelCheckpoint('unet-attention-3d.keras', monitor='val_accuracy',verbose=1, save_best_only=True)
train = trainGenerator(1, t_images, t_masks, data_gen_args, save_to_dir=None)
model_attention_unet.fit(train, steps_per_epoch=100, epochs=50, validation_data = validation_df, callbacks=[save_model_am])
# Out:
# Epoch 1/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.6061 - loss: 0.6829 - mse: 0.2450
# Epoch 1: val_accuracy improved from -inf to 0.87826, saving model to unet-attention-3d.keras
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 28s 102ms/step - accuracy: 0.6070 - loss: 0.6823 - mse: 0.2447 - val_accuracy: 0.8783 - val_loss: 0.3722 - val_mse: 0.1101
# Epoch 2/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.9058 - loss: 0.2885 - mse: 0.0815
# Epoch 2: val_accuracy improved from 0.87826 to 0.89732, saving model to unet-attention-3d.keras
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 8s 76ms/step - accuracy: 0.9060 - loss: 0.2880 - mse: 0.0814 - val_accuracy: 0.8973 - val_loss: 0.2586 - val_mse: 0.0767
# Epoch 3/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.9402 - loss: 0.1810 - mse: 0.0478
# Epoch 3: val_accuracy did not improve from 0.89732
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 7s 73ms/step - accuracy: 0.9402 - loss: 0.1811 - mse: 0.0478 - val_accuracy: 0.8908 - val_loss: 0.2972 - val_mse: 0.0860
# Epoch 4/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 0.9464 - loss: 0.1508 - mse: 0.0411
# Epoch 4: val_accuracy improved from 0.89732 to 0.89861, saving model to unet-attention-3d.keras
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 8s 81ms/step - accuracy: 0.9464 - loss: 0.1508 - mse: 0.0411 - val_accuracy: 0.8986 - val_loss: 0.2814 - val_mse: 0.0795
# Epoch 5/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.9436 - loss: 0.1694 - mse: 0.0448
# Epoch 5: val_accuracy improved from 0.89861 to 0.90499, saving model to unet-attention-3d.keras
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 7s 75ms/step - accuracy: 0.9436 - loss: 0.1694 - mse: 0.0447 - val_accuracy: 0.9050 - val_loss: 0.2512 - val_mse: 0.0724
# Epoch 6/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.9454 - loss: 0.1596 - mse: 0.0431
# Epoch 6: val_accuracy improved from 0.90499 to 0.91098, saving model to unet-attention-3d.keras
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 7s 75ms/step - accuracy: 0.9454 - loss: 0.1595 - mse: 0.0431 - val_accuracy: 0.9110 - val_loss: 0.2281 - val_mse: 0.0675
# Epoch 7/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.9495 - loss: 0.1426 - mse: 0.0391
# Epoch 7: val_accuracy did not improve from 0.91098
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 7s 72ms/step - accuracy: 0.9495 - loss: 0.1427 - mse: 0.0392 - val_accuracy: 0.9066 - val_loss: 0.2240 - val_mse: 0.0683
# Epoch 8/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.9488 - loss: 0.1539 - mse: 0.0407
# Epoch 8: val_accuracy did not improve from 0.91098
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 7s 75ms/step - accuracy: 0.9488 - loss: 0.1540 - mse: 0.0407 - val_accuracy: 0.8924 - val_loss: 0.2513 - val_mse: 0.0777
# Epoch 9/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.9564 - loss: 0.1307 - mse: 0.0343
# Epoch 9: val_accuracy improved from 0.91098 to 0.91524, saving model to unet-attention-3d.keras
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 8s 77ms/step - accuracy: 0.9563 - loss: 0.1308 - mse: 0.0343 - val_accuracy: 0.9152 - val_loss: 0.2073 - val_mse: 0.0622
# Epoch 10/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.9497 - loss: 0.1488 - mse: 0.0396
# Epoch 10: val_accuracy did not improve from 0.91524
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 7s 70ms/step - accuracy: 0.9496 - loss: 0.1489 - mse: 0.0397 - val_accuracy: 0.9140 - val_loss: 0.2132 - val_mse: 0.0641
# Epoch 11/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.9524 - loss: 0.1417 - mse: 0.0375
# Epoch 11: val_accuracy did not improve from 0.91524
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 7s 74ms/step - accuracy: 0.9523 - loss: 0.1418 - mse: 0.0376 - val_accuracy: 0.7180 - val_loss: 0.7979 - val_mse: 0.2120
# Epoch 12/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.9520 - loss: 0.1429 - mse: 0.0377
# Epoch 12: val_accuracy did not improve from 0.91524
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 7s 74ms/step - accuracy: 0.9520 - loss: 0.1429 - mse: 0.0377 - val_accuracy: 0.9047 - val_loss: 0.2661 - val_mse: 0.0746
# Epoch 13/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.9444 - loss: 0.1721 - mse: 0.0448
# Epoch 13: val_accuracy did not improve from 0.91524
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 7s 74ms/step - accuracy: 0.9444 - loss: 0.1720 - mse: 0.0448 - val_accuracy: 0.9068 - val_loss: 0.2320 - val_mse: 0.0705
# Epoch 14/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.9539 - loss: 0.1404 - mse: 0.0363
# Epoch 14: val_accuracy did not improve from 0.91524
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 7s 74ms/step - accuracy: 0.9539 - loss: 0.1405 - mse: 0.0363 - val_accuracy: 0.9081 - val_loss: 0.2324 - val_mse: 0.0691
# Epoch 15/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.9455 - loss: 0.1581 - mse: 0.0428
# Epoch 15: val_accuracy did not improve from 0.91524
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 7s 75ms/step - accuracy: 0.9455 - loss: 0.1582 - mse: 0.0428 - val_accuracy: 0.9105 - val_loss: 0.2272 - val_mse: 0.0681
# Epoch 16/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.9479 - loss: 0.1452 - mse: 0.0395
# Epoch 16: val_accuracy did not improve from 0.91524
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 7s 75ms/step - accuracy: 0.9480 - loss: 0.1452 - mse: 0.0395 - val_accuracy: 0.9103 - val_loss: 0.2265 - val_mse: 0.0678
# Epoch 17/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.9494 - loss: 0.1422 - mse: 0.0389
# Epoch 17: val_accuracy did not improve from 0.91524
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 8s 76ms/step - accuracy: 0.9494 - loss: 0.1422 - mse: 0.0389 - val_accuracy: 0.9097 - val_loss: 0.2286 - val_mse: 0.0688
# Epoch 18/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.9546 - loss: 0.1346 - mse: 0.0352
# Epoch 18: val_accuracy did not improve from 0.91524
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 7s 74ms/step - accuracy: 0.9546 - loss: 0.1346 - mse: 0.0352 - val_accuracy: 0.9144 - val_loss: 0.2167 - val_mse: 0.0642
# Epoch 19/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.9513 - loss: 0.1432 - mse: 0.0381
# Epoch 19: val_accuracy improved from 0.91524 to 0.92354, saving model to unet-attention-3d.keras
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 8s 77ms/step - accuracy: 0.9513 - loss: 0.1432 - mse: 0.0381 - val_accuracy: 0.9235 - val_loss: 0.1955 - val_mse: 0.0577
# Epoch 20/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.9519 - loss: 0.1471 - mse: 0.0383
# Epoch 20: val_accuracy did not improve from 0.92354
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 7s 72ms/step - accuracy: 0.9517 - loss: 0.1475 - mse: 0.0384 - val_accuracy: 0.7956 - val_loss: 0.3847 - val_mse: 0.1310
# Epoch 21/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.9258 - loss: 0.2020 - mse: 0.0579
# Epoch 21: val_accuracy did not improve from 0.92354
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 7s 74ms/step - accuracy: 0.9259 - loss: 0.2017 - mse: 0.0578 - val_accuracy: 0.9050 - val_loss: 0.2419 - val_mse: 0.0711
# Epoch 22/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.9417 - loss: 0.1743 - mse: 0.0461
# Epoch 22: val_accuracy did not improve from 0.92354
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 7s 75ms/step - accuracy: 0.9417 - loss: 0.1741 - mse: 0.0461 - val_accuracy: 0.9065 - val_loss: 0.2435 - val_mse: 0.0727
# Epoch 23/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.9451 - loss: 0.1554 - mse: 0.0426
# Epoch 23: val_accuracy did not improve from 0.92354
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 7s 75ms/step - accuracy: 0.9451 - loss: 0.1552 - mse: 0.0425 - val_accuracy: 0.9096 - val_loss: 0.2430 - val_mse: 0.0691
# Epoch 24/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.9503 - loss: 0.1542 - mse: 0.0395
# Epoch 24: val_accuracy did not improve from 0.92354
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 7s 74ms/step - accuracy: 0.9504 - loss: 0.1541 - mse: 0.0395 - val_accuracy: 0.9089 - val_loss: 0.2335 - val_mse: 0.0703
# Epoch 25/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.9504 - loss: 0.1461 - mse: 0.0387
# Epoch 25: val_accuracy did not improve from 0.92354
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 7s 74ms/step - accuracy: 0.9504 - loss: 0.1462 - mse: 0.0387 - val_accuracy: 0.9136 - val_loss: 0.2163 - val_mse: 0.0646
# Epoch 26/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.9499 - loss: 0.1474 - mse: 0.0391
# Epoch 26: val_accuracy did not improve from 0.92354
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 7s 74ms/step - accuracy: 0.9499 - loss: 0.1475 - mse: 0.0391 - val_accuracy: 0.9106 - val_loss: 0.2266 - val_mse: 0.0686
# Epoch 27/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.9567 - loss: 0.1288 - mse: 0.0337
# Epoch 27: val_accuracy did not improve from 0.92354
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 7s 75ms/step - accuracy: 0.9567 - loss: 0.1290 - mse: 0.0338 - val_accuracy: 0.9137 - val_loss: 0.2132 - val_mse: 0.0634
# Epoch 28/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.9502 - loss: 0.1472 - mse: 0.0392
# Epoch 28: val_accuracy did not improve from 0.92354
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 7s 74ms/step - accuracy: 0.9502 - loss: 0.1471 - mse: 0.0392 - val_accuracy: 0.9075 - val_loss: 0.2407 - val_mse: 0.0719
# Epoch 29/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.9537 - loss: 0.1363 - mse: 0.0365
# Epoch 29: val_accuracy did not improve from 0.92354
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 7s 74ms/step - accuracy: 0.9537 - loss: 0.1363 - mse: 0.0365 - val_accuracy: 0.9113 - val_loss: 0.2262 - val_mse: 0.0682
# Epoch 30/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.9492 - loss: 0.1475 - mse: 0.0398
# Epoch 30: val_accuracy did not improve from 0.92354
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 7s 73ms/step - accuracy: 0.9493 - loss: 0.1474 - mse: 0.0398 - val_accuracy: 0.9181 - val_loss: 0.2135 - val_mse: 0.0619
# Epoch 31/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.9565 - loss: 0.1274 - mse: 0.0341
# Epoch 31: val_accuracy did not improve from 0.92354
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 7s 75ms/step - accuracy: 0.9565 - loss: 0.1275 - mse: 0.0341 - val_accuracy: 0.9027 - val_loss: 0.2507 - val_mse: 0.0747
# Epoch 32/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.9500 - loss: 0.1515 - mse: 0.0398
# Epoch 32: val_accuracy did not improve from 0.92354
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 7s 75ms/step - accuracy: 0.9501 - loss: 0.1514 - mse: 0.0398 - val_accuracy: 0.9188 - val_loss: 0.2092 - val_mse: 0.0617
# Epoch 33/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.9375 - loss: 0.1772 - mse: 0.0493
# Epoch 33: val_accuracy did not improve from 0.92354
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 7s 74ms/step - accuracy: 0.9376 - loss: 0.1770 - mse: 0.0493 - val_accuracy: 0.9166 - val_loss: 0.2122 - val_mse: 0.0625
# Epoch 34/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.9568 - loss: 0.1260 - mse: 0.0336
# Epoch 34: val_accuracy did not improve from 0.92354
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 7s 76ms/step - accuracy: 0.9568 - loss: 0.1261 - mse: 0.0336 - val_accuracy: 0.9175 - val_loss: 0.2115 - val_mse: 0.0628
# Epoch 35/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.9549 - loss: 0.1326 - mse: 0.0352
# Epoch 35: val_accuracy did not improve from 0.92354
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 7s 74ms/step - accuracy: 0.9549 - loss: 0.1326 - mse: 0.0352 - val_accuracy: 0.9169 - val_loss: 0.2110 - val_mse: 0.0629
# Epoch 36/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.9519 - loss: 0.1350 - mse: 0.0369
# Epoch 36: val_accuracy did not improve from 0.92354
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 7s 74ms/step - accuracy: 0.9518 - loss: 0.1351 - mse: 0.0369 - val_accuracy: 0.8996 - val_loss: 0.2486 - val_mse: 0.0753
# Epoch 37/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.9445 - loss: 0.1568 - mse: 0.0432
# Epoch 37: val_accuracy did not improve from 0.92354
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 7s 75ms/step - accuracy: 0.9446 - loss: 0.1566 - mse: 0.0431 - val_accuracy: 0.9193 - val_loss: 0.2073 - val_mse: 0.0612
# Epoch 38/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.9549 - loss: 0.1339 - mse: 0.0354
# Epoch 38: val_accuracy did not improve from 0.92354
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 7s 74ms/step - accuracy: 0.9549 - loss: 0.1340 - mse: 0.0354 - val_accuracy: 0.9169 - val_loss: 0.2152 - val_mse: 0.0628
# Epoch 39/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.9567 - loss: 0.1240 - mse: 0.0335
# Epoch 39: val_accuracy did not improve from 0.92354
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 7s 74ms/step - accuracy: 0.9566 - loss: 0.1242 - mse: 0.0336 - val_accuracy: 0.9183 - val_loss: 0.2020 - val_mse: 0.0603
# Epoch 40/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.9500 - loss: 0.1432 - mse: 0.0389
# Epoch 40: val_accuracy did not improve from 0.92354
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 7s 74ms/step - accuracy: 0.9500 - loss: 0.1432 - mse: 0.0389 - val_accuracy: 0.9194 - val_loss: 0.2030 - val_mse: 0.0602
# Epoch 41/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.9567 - loss: 0.1241 - mse: 0.0337
# Epoch 41: val_accuracy did not improve from 0.92354
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 7s 74ms/step - accuracy: 0.9566 - loss: 0.1243 - mse: 0.0337 - val_accuracy: 0.9179 - val_loss: 0.2099 - val_mse: 0.0627
# Epoch 42/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.9492 - loss: 0.1435 - mse: 0.0394
# Epoch 42: val_accuracy did not improve from 0.92354
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 8s 76ms/step - accuracy: 0.9493 - loss: 0.1434 - mse: 0.0394 - val_accuracy: 0.9189 - val_loss: 0.2129 - val_mse: 0.0617
# Epoch 43/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.9538 - loss: 0.1304 - mse: 0.0355
# Epoch 43: val_accuracy did not improve from 0.92354
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 8s 79ms/step - accuracy: 0.9538 - loss: 0.1305 - mse: 0.0355 - val_accuracy: 0.9207 - val_loss: 0.2009 - val_mse: 0.0592
# Epoch 44/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.9610 - loss: 0.1132 - mse: 0.0301
# Epoch 44: val_accuracy did not improve from 0.92354
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 8s 76ms/step - accuracy: 0.9610 - loss: 0.1133 - mse: 0.0302 - val_accuracy: 0.8403 - val_loss: 0.7001 - val_mse: 0.1321
# Epoch 45/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.9486 - loss: 0.1507 - mse: 0.0398
# Epoch 45: val_accuracy did not improve from 0.92354
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 8s 77ms/step - accuracy: 0.9486 - loss: 0.1506 - mse: 0.0398 - val_accuracy: 0.9168 - val_loss: 0.2126 - val_mse: 0.0630
# Epoch 46/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.9562 - loss: 0.1315 - mse: 0.0344
# Epoch 46: val_accuracy did not improve from 0.92354
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 7s 75ms/step - accuracy: 0.9562 - loss: 0.1316 - mse: 0.0344 - val_accuracy: 0.9206 - val_loss: 0.2006 - val_mse: 0.0597
# Epoch 47/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.9525 - loss: 0.1405 - mse: 0.0373
# Epoch 47: val_accuracy did not improve from 0.92354
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 8s 77ms/step - accuracy: 0.9525 - loss: 0.1405 - mse: 0.0372 - val_accuracy: 0.9159 - val_loss: 0.2169 - val_mse: 0.0633
# Epoch 48/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.9524 - loss: 0.1425 - mse: 0.0375
# Epoch 48: val_accuracy did not improve from 0.92354
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 8s 77ms/step - accuracy: 0.9525 - loss: 0.1424 - mse: 0.0375 - val_accuracy: 0.9184 - val_loss: 0.2191 - val_mse: 0.0627
# Epoch 49/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.9584 - loss: 0.1234 - mse: 0.0325
# Epoch 49: val_accuracy did not improve from 0.92354
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 7s 75ms/step - accuracy: 0.9584 - loss: 0.1235 - mse: 0.0325 - val_accuracy: 0.9220 - val_loss: 0.2020 - val_mse: 0.0587
# Epoch 50/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.9599 - loss: 0.1187 - mse: 0.0312
# Epoch 50: val_accuracy did not improve from 0.92354
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 8s 76ms/step - accuracy: 0.9598 - loss: 0.1187 - mse: 0.0312 - val_accuracy: 0.9234 - val_loss: 0.1966 - val_mse: 0.0577

# %%
# Save model history
np.save('unet-attention-3d-history.npy',model_attention_unet.history.history)

# %%
# Copy models to drive
# !cp unet-attention-3d.keras drive/MyDrive/Diss/
# !cp unet-attention-3d-history.npy drive/MyDrive/Diss/

# %% [markdown]
# ## ResNet50-SegNet

# %%
R = ResNet50SegNet()
save_model_resnet = ModelCheckpoint('resnet50segnet-3d.weights.h5', monitor='val_accuracy',verbose=1, save_best_only=True, save_weights_only=True)
train = trainGenerator(1, t_images, t_masks, data_gen_args, save_to_dir=None)
R.fit(train, validation_data = validation_df, epochs = 40, steps_per_epoch = 100, callbacks=[save_model_resnet])
# Out:
# Epoch 1/40
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - accuracy: 0.6252 - loss: 0.7368 - mse: 0.2456
# Epoch 1: val_accuracy improved from -inf to 0.88415, saving model to resnet50segnet-3d.weights.h5
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 31s 167ms/step - accuracy: 0.6263 - loss: 0.7352 - mse: 0.2450 - val_accuracy: 0.8842 - val_loss: 0.3241 - val_mse: 0.0929
# Epoch 2/40
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step - accuracy: 0.9176 - loss: 0.2545 - mse: 0.0688
# Epoch 2: val_accuracy improved from 0.88415 to 0.89903, saving model to resnet50segnet-3d.weights.h5
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 16s 159ms/step - accuracy: 0.9177 - loss: 0.2544 - mse: 0.0688 - val_accuracy: 0.8990 - val_loss: 0.2842 - val_mse: 0.0809
# Epoch 3/40
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - accuracy: 0.9349 - loss: 0.2058 - mse: 0.0547
# Epoch 3: val_accuracy did not improve from 0.89903
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 14s 142ms/step - accuracy: 0.9348 - loss: 0.2058 - mse: 0.0547 - val_accuracy: 0.8961 - val_loss: 0.2866 - val_mse: 0.0814
# Epoch 4/40
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step - accuracy: 0.9438 - loss: 0.1672 - mse: 0.0446
# Epoch 4: val_accuracy improved from 0.89903 to 0.90002, saving model to resnet50segnet-3d.weights.h5
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 15s 155ms/step - accuracy: 0.9438 - loss: 0.1672 - mse: 0.0446 - val_accuracy: 0.9000 - val_loss: 0.2695 - val_mse: 0.0764
# Epoch 5/40
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - accuracy: 0.9436 - loss: 0.1827 - mse: 0.0464
# Epoch 5: val_accuracy improved from 0.90002 to 0.90568, saving model to resnet50segnet-3d.weights.h5
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 16s 156ms/step - accuracy: 0.9436 - loss: 0.1827 - mse: 0.0464 - val_accuracy: 0.9057 - val_loss: 0.2382 - val_mse: 0.0710
# Epoch 6/40
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - accuracy: 0.9485 - loss: 0.1734 - mse: 0.0437
# Epoch 6: val_accuracy improved from 0.90568 to 0.90878, saving model to resnet50segnet-3d.weights.h5
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 16s 156ms/step - accuracy: 0.9485 - loss: 0.1734 - mse: 0.0437 - val_accuracy: 0.9088 - val_loss: 0.2393 - val_mse: 0.0695
# Epoch 7/40
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - accuracy: 0.9481 - loss: 0.1517 - mse: 0.0405
# Epoch 7: val_accuracy improved from 0.90878 to 0.91322, saving model to resnet50segnet-3d.weights.h5
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 16s 157ms/step - accuracy: 0.9480 - loss: 0.1518 - mse: 0.0405 - val_accuracy: 0.9132 - val_loss: 0.2137 - val_mse: 0.0636
# Epoch 8/40
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - accuracy: 0.9401 - loss: 0.1817 - mse: 0.0472
# Epoch 8: val_accuracy improved from 0.91322 to 0.91369, saving model to resnet50segnet-3d.weights.h5
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 16s 158ms/step - accuracy: 0.9401 - loss: 0.1818 - mse: 0.0472 - val_accuracy: 0.9137 - val_loss: 0.2304 - val_mse: 0.0666
# Epoch 9/40
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - accuracy: 0.9530 - loss: 0.1435 - mse: 0.0369
# Epoch 9: val_accuracy did not improve from 0.91369
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 14s 142ms/step - accuracy: 0.9530 - loss: 0.1437 - mse: 0.0370 - val_accuracy: 0.9117 - val_loss: 0.2173 - val_mse: 0.0648
# Epoch 10/40
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - accuracy: 0.9480 - loss: 0.1561 - mse: 0.0414
# Epoch 10: val_accuracy did not improve from 0.91369
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 14s 141ms/step - accuracy: 0.9479 - loss: 0.1562 - mse: 0.0414 - val_accuracy: 0.9136 - val_loss: 0.2126 - val_mse: 0.0642
# Epoch 11/40
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - accuracy: 0.9519 - loss: 0.1522 - mse: 0.0388
# Epoch 11: val_accuracy improved from 0.91369 to 0.91793, saving model to resnet50segnet-3d.weights.h5
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 16s 157ms/step - accuracy: 0.9518 - loss: 0.1524 - mse: 0.0388 - val_accuracy: 0.9179 - val_loss: 0.2090 - val_mse: 0.0614
# Epoch 12/40
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - accuracy: 0.9597 - loss: 0.1294 - mse: 0.0323
# Epoch 12: val_accuracy did not improve from 0.91793
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 14s 141ms/step - accuracy: 0.9597 - loss: 0.1295 - mse: 0.0323 - val_accuracy: 0.9152 - val_loss: 0.2557 - val_mse: 0.0667
# Epoch 13/40
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - accuracy: 0.9485 - loss: 0.1687 - mse: 0.0414
# Epoch 13: val_accuracy did not improve from 0.91793
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 14s 141ms/step - accuracy: 0.9485 - loss: 0.1686 - mse: 0.0414 - val_accuracy: 0.9155 - val_loss: 0.2080 - val_mse: 0.0624
# Epoch 14/40
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - accuracy: 0.9545 - loss: 0.1405 - mse: 0.0358
# Epoch 14: val_accuracy improved from 0.91793 to 0.92263, saving model to resnet50segnet-3d.weights.h5
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 16s 158ms/step - accuracy: 0.9544 - loss: 0.1405 - mse: 0.0358 - val_accuracy: 0.9226 - val_loss: 0.1909 - val_mse: 0.0570
# Epoch 15/40
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - accuracy: 0.9527 - loss: 0.1390 - mse: 0.0368
# Epoch 15: val_accuracy did not improve from 0.92263
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 14s 142ms/step - accuracy: 0.9527 - loss: 0.1391 - mse: 0.0368 - val_accuracy: 0.9211 - val_loss: 0.2000 - val_mse: 0.0589
# Epoch 16/40
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - accuracy: 0.9580 - loss: 0.1275 - mse: 0.0326
# Epoch 16: val_accuracy improved from 0.92263 to 0.92292, saving model to resnet50segnet-3d.weights.h5
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 16s 158ms/step - accuracy: 0.9580 - loss: 0.1276 - mse: 0.0326 - val_accuracy: 0.9229 - val_loss: 0.1907 - val_mse: 0.0568
# Epoch 17/40
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - accuracy: 0.9551 - loss: 0.1271 - mse: 0.0343
# Epoch 17: val_accuracy improved from 0.92292 to 0.92355, saving model to resnet50segnet-3d.weights.h5
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 16s 157ms/step - accuracy: 0.9551 - loss: 0.1272 - mse: 0.0343 - val_accuracy: 0.9236 - val_loss: 0.1954 - val_mse: 0.0576
# Epoch 18/40
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - accuracy: 0.9602 - loss: 0.1216 - mse: 0.0312
# Epoch 18: val_accuracy improved from 0.92355 to 0.92488, saving model to resnet50segnet-3d.weights.h5
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 16s 158ms/step - accuracy: 0.9601 - loss: 0.1217 - mse: 0.0312 - val_accuracy: 0.9249 - val_loss: 0.1958 - val_mse: 0.0567
# Epoch 19/40
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - accuracy: 0.9539 - loss: 0.1454 - mse: 0.0366
# Epoch 19: val_accuracy did not improve from 0.92488
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 14s 141ms/step - accuracy: 0.9539 - loss: 0.1455 - mse: 0.0367 - val_accuracy: 0.9239 - val_loss: 0.1983 - val_mse: 0.0578
# Epoch 20/40
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - accuracy: 0.9560 - loss: 0.1396 - mse: 0.0352
# Epoch 20: val_accuracy improved from 0.92488 to 0.92519, saving model to resnet50segnet-3d.weights.h5
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 16s 158ms/step - accuracy: 0.9560 - loss: 0.1397 - mse: 0.0352 - val_accuracy: 0.9252 - val_loss: 0.1914 - val_mse: 0.0562
# Epoch 21/40
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - accuracy: 0.9573 - loss: 0.1255 - mse: 0.0331
# Epoch 21: val_accuracy did not improve from 0.92519
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 14s 142ms/step - accuracy: 0.9573 - loss: 0.1255 - mse: 0.0331 - val_accuracy: 0.9225 - val_loss: 0.2124 - val_mse: 0.0599
# Epoch 22/40
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - accuracy: 0.9550 - loss: 0.1371 - mse: 0.0357
# Epoch 22: val_accuracy improved from 0.92519 to 0.92689, saving model to resnet50segnet-3d.weights.h5
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 16s 158ms/step - accuracy: 0.9551 - loss: 0.1370 - mse: 0.0357 - val_accuracy: 0.9269 - val_loss: 0.1870 - val_mse: 0.0548
# Epoch 23/40
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - accuracy: 0.9541 - loss: 0.1474 - mse: 0.0373
# Epoch 23: val_accuracy improved from 0.92689 to 0.92968, saving model to resnet50segnet-3d.weights.h5
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 16s 158ms/step - accuracy: 0.9542 - loss: 0.1473 - mse: 0.0372 - val_accuracy: 0.9297 - val_loss: 0.2082 - val_mse: 0.0552
# Epoch 24/40
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - accuracy: 0.9535 - loss: 0.1530 - mse: 0.0378
# Epoch 24: val_accuracy did not improve from 0.92968
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 14s 141ms/step - accuracy: 0.9535 - loss: 0.1527 - mse: 0.0377 - val_accuracy: 0.9230 - val_loss: 0.1915 - val_mse: 0.0573
# Epoch 25/40
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - accuracy: 0.9559 - loss: 0.1364 - mse: 0.0347
# Epoch 25: val_accuracy did not improve from 0.92968
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 14s 141ms/step - accuracy: 0.9559 - loss: 0.1364 - mse: 0.0347 - val_accuracy: 0.9251 - val_loss: 0.1993 - val_mse: 0.0562
# Epoch 26/40
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step - accuracy: 0.9535 - loss: 0.1394 - mse: 0.0364
# Epoch 26: val_accuracy did not improve from 0.92968
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 14s 141ms/step - accuracy: 0.9535 - loss: 0.1394 - mse: 0.0364 - val_accuracy: 0.8889 - val_loss: 0.2589 - val_mse: 0.0802
# Epoch 27/40
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step - accuracy: 0.9580 - loss: 0.1242 - mse: 0.0322
# Epoch 27: val_accuracy improved from 0.92968 to 0.93412, saving model to resnet50segnet-3d.weights.h5
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 16s 155ms/step - accuracy: 0.9580 - loss: 0.1243 - mse: 0.0322 - val_accuracy: 0.9341 - val_loss: 0.1668 - val_mse: 0.0488
# Epoch 28/40
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - accuracy: 0.9589 - loss: 0.1271 - mse: 0.0328
# Epoch 28: val_accuracy did not improve from 0.93412
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 14s 141ms/step - accuracy: 0.9589 - loss: 0.1271 - mse: 0.0328 - val_accuracy: 0.9250 - val_loss: 0.1961 - val_mse: 0.0573
# Epoch 29/40
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step - accuracy: 0.9609 - loss: 0.1180 - mse: 0.0308
# Epoch 29: val_accuracy did not improve from 0.93412
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 14s 141ms/step - accuracy: 0.9609 - loss: 0.1181 - mse: 0.0308 - val_accuracy: 0.9307 - val_loss: 0.1825 - val_mse: 0.0527
# Epoch 30/40
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - accuracy: 0.9582 - loss: 0.1258 - mse: 0.0331
# Epoch 30: val_accuracy did not improve from 0.93412
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 14s 141ms/step - accuracy: 0.9582 - loss: 0.1257 - mse: 0.0331 - val_accuracy: 0.9290 - val_loss: 0.1938 - val_mse: 0.0544
# Epoch 31/40
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - accuracy: 0.9641 - loss: 0.1077 - mse: 0.0281
# Epoch 31: val_accuracy did not improve from 0.93412
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 14s 142ms/step - accuracy: 0.9641 - loss: 0.1078 - mse: 0.0282 - val_accuracy: 0.9287 - val_loss: 0.1860 - val_mse: 0.0540
# Epoch 32/40
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - accuracy: 0.9586 - loss: 0.1242 - mse: 0.0326
# Epoch 32: val_accuracy did not improve from 0.93412
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 14s 141ms/step - accuracy: 0.9586 - loss: 0.1242 - mse: 0.0326 - val_accuracy: 0.9248 - val_loss: 0.1989 - val_mse: 0.0573
# Epoch 33/40
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - accuracy: 0.9529 - loss: 0.1393 - mse: 0.0373
# Epoch 33: val_accuracy improved from 0.93412 to 0.94056, saving model to resnet50segnet-3d.weights.h5
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 16s 158ms/step - accuracy: 0.9529 - loss: 0.1392 - mse: 0.0372 - val_accuracy: 0.9406 - val_loss: 0.1774 - val_mse: 0.0463
# Epoch 34/40
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - accuracy: 0.9642 - loss: 0.1044 - mse: 0.0277
# Epoch 34: val_accuracy did not improve from 0.94056
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 14s 142ms/step - accuracy: 0.9642 - loss: 0.1044 - mse: 0.0277 - val_accuracy: 0.9383 - val_loss: 0.1649 - val_mse: 0.0464
# Epoch 35/40
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - accuracy: 0.9634 - loss: 0.1125 - mse: 0.0289
# Epoch 35: val_accuracy did not improve from 0.94056
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 14s 142ms/step - accuracy: 0.9633 - loss: 0.1125 - mse: 0.0289 - val_accuracy: 0.9341 - val_loss: 0.1722 - val_mse: 0.0493
# Epoch 36/40
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - accuracy: 0.9604 - loss: 0.1155 - mse: 0.0307
# Epoch 36: val_accuracy did not improve from 0.94056
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 14s 142ms/step - accuracy: 0.9604 - loss: 0.1156 - mse: 0.0307 - val_accuracy: 0.9069 - val_loss: 0.2365 - val_mse: 0.0699
# Epoch 37/40
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - accuracy: 0.9501 - loss: 0.1395 - mse: 0.0386
# Epoch 37: val_accuracy did not improve from 0.94056
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 14s 141ms/step - accuracy: 0.9502 - loss: 0.1394 - mse: 0.0385 - val_accuracy: 0.9333 - val_loss: 0.1886 - val_mse: 0.0508
# Epoch 38/40
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - accuracy: 0.9615 - loss: 0.1133 - mse: 0.0302
# Epoch 38: val_accuracy did not improve from 0.94056
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 14s 141ms/step - accuracy: 0.9615 - loss: 0.1133 - mse: 0.0302 - val_accuracy: 0.9379 - val_loss: 0.1880 - val_mse: 0.0487
# Epoch 39/40
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - accuracy: 0.9632 - loss: 0.1010 - mse: 0.0277
# Epoch 39: val_accuracy improved from 0.94056 to 0.94278, saving model to resnet50segnet-3d.weights.h5
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 16s 157ms/step - accuracy: 0.9631 - loss: 0.1012 - mse: 0.0278 - val_accuracy: 0.9428 - val_loss: 0.1495 - val_mse: 0.0426
# Epoch 40/40
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - accuracy: 0.9594 - loss: 0.1112 - mse: 0.0303
# Epoch 40: val_accuracy did not improve from 0.94278
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 14s 141ms/step - accuracy: 0.9594 - loss: 0.1112 - mse: 0.0303 - val_accuracy: 0.9279 - val_loss: 0.1930 - val_mse: 0.0548

# %%
# Save model history
np.save('resnet50segnet-3d-history.npy',R.history.history)

# %%
# Copy models to drive
# !cp resnet50segnet-3d.keras drive/MyDrive/Diss/models/
# !cp resnet50segnet-3d-history.npy drive/MyDrive/Diss/models/
# Out:
# cp: cannot stat 'resnet50segnet-3d.keras': No such file or directory
# cp: cannot create regular file 'drive/MyDrive/Diss/models/': Not a directory

# %% [markdown]
# ## FCN32-VGG16

# %%
F = fcn_32(lr = 0.0001)
save_model_fcn32 = ModelCheckpoint('fcn32-3d.keras', monitor='val_accuracy',verbose=1, save_best_only=True)
train = trainGenerator(1, t_images, t_masks, data_gen_args, save_to_dir=None)
F.fit(train, validation_data = validation_df, epochs=50, steps_per_epoch = 100, shuffle = True, callbacks=[save_model_fcn32])
# Out:
# Epoch 1/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.5024 - loss: 0.6931 - mse: 0.2500
# Epoch 1: val_accuracy improved from -inf to 0.46727, saving model to fcn32-3d.keras
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 57s 207ms/step - accuracy: 0.5028 - loss: 0.6931 - mse: 0.2500 - val_accuracy: 0.4673 - val_loss: 0.6936 - val_mse: 0.2502
# Epoch 2/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - accuracy: 0.5381 - loss: 0.6925 - mse: 0.2497
# Epoch 2: val_accuracy did not improve from 0.46727
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 16s 155ms/step - accuracy: 0.5381 - loss: 0.6925 - mse: 0.2497 - val_accuracy: 0.4190 - val_loss: 0.6883 - val_mse: 0.2476
# Epoch 3/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.5472 - loss: 0.6906 - mse: 0.2452
# Epoch 3: val_accuracy improved from 0.46727 to 0.69784, saving model to fcn32-3d.keras
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 18s 180ms/step - accuracy: 0.5475 - loss: 0.6906 - mse: 0.2451 - val_accuracy: 0.6978 - val_loss: 0.6331 - val_mse: 0.2217
# Epoch 4/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.6998 - loss: 0.5697 - mse: 0.1858
# Epoch 4: val_accuracy improved from 0.69784 to 0.76068, saving model to fcn32-3d.keras
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 18s 182ms/step - accuracy: 0.6999 - loss: 0.5696 - mse: 0.1857 - val_accuracy: 0.7607 - val_loss: 0.5142 - val_mse: 0.1708
# Epoch 5/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.7612 - loss: 0.5355 - mse: 0.1757
# Epoch 5: val_accuracy did not improve from 0.76068
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 13s 127ms/step - accuracy: 0.7614 - loss: 0.5354 - mse: 0.1756 - val_accuracy: 0.6834 - val_loss: 0.5482 - val_mse: 0.1863
# Epoch 6/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.7850 - loss: 0.4772 - mse: 0.1535
# Epoch 6: val_accuracy improved from 0.76068 to 0.77594, saving model to fcn32-3d.keras
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 18s 182ms/step - accuracy: 0.7853 - loss: 0.4768 - mse: 0.1534 - val_accuracy: 0.7759 - val_loss: 0.4867 - val_mse: 0.1620
# Epoch 7/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.8018 - loss: 0.4398 - mse: 0.1403
# Epoch 7: val_accuracy improved from 0.77594 to 0.78546, saving model to fcn32-3d.keras
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 18s 183ms/step - accuracy: 0.8019 - loss: 0.4400 - mse: 0.1403 - val_accuracy: 0.7855 - val_loss: 0.4472 - val_mse: 0.1456
# Epoch 8/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.8464 - loss: 0.3908 - mse: 0.1169
# Epoch 8: val_accuracy improved from 0.78546 to 0.82670, saving model to fcn32-3d.keras
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 18s 182ms/step - accuracy: 0.8465 - loss: 0.3907 - mse: 0.1169 - val_accuracy: 0.8267 - val_loss: 0.3979 - val_mse: 0.1248
# Epoch 9/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.8757 - loss: 0.3246 - mse: 0.0963
# Epoch 9: val_accuracy improved from 0.82670 to 0.85230, saving model to fcn32-3d.keras
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 18s 183ms/step - accuracy: 0.8757 - loss: 0.3248 - mse: 0.0963 - val_accuracy: 0.8523 - val_loss: 0.3467 - val_mse: 0.1081
# Epoch 10/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.8706 - loss: 0.3301 - mse: 0.0979
# Epoch 10: val_accuracy did not improve from 0.85230
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 13s 127ms/step - accuracy: 0.8705 - loss: 0.3303 - mse: 0.0980 - val_accuracy: 0.8463 - val_loss: 0.3577 - val_mse: 0.1113
# Epoch 11/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.8740 - loss: 0.3206 - mse: 0.0944
# Epoch 11: val_accuracy improved from 0.85230 to 0.85970, saving model to fcn32-3d.keras
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 18s 183ms/step - accuracy: 0.8740 - loss: 0.3208 - mse: 0.0944 - val_accuracy: 0.8597 - val_loss: 0.3286 - val_mse: 0.1016
# Epoch 12/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.8858 - loss: 0.2992 - mse: 0.0872
# Epoch 12: val_accuracy did not improve from 0.85970
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 13s 127ms/step - accuracy: 0.8858 - loss: 0.2992 - mse: 0.0872 - val_accuracy: 0.8574 - val_loss: 0.3376 - val_mse: 0.1022
# Epoch 13/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.8852 - loss: 0.2967 - mse: 0.0860
# Epoch 13: val_accuracy improved from 0.85970 to 0.87059, saving model to fcn32-3d.keras
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 18s 182ms/step - accuracy: 0.8852 - loss: 0.2965 - mse: 0.0860 - val_accuracy: 0.8706 - val_loss: 0.3153 - val_mse: 0.0956
# Epoch 14/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.8885 - loss: 0.2869 - mse: 0.0840
# Epoch 14: val_accuracy did not improve from 0.87059
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 13s 127ms/step - accuracy: 0.8884 - loss: 0.2873 - mse: 0.0841 - val_accuracy: 0.8561 - val_loss: 0.3287 - val_mse: 0.1019
# Epoch 15/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.8944 - loss: 0.2767 - mse: 0.0799
# Epoch 15: val_accuracy improved from 0.87059 to 0.87210, saving model to fcn32-3d.keras
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 18s 183ms/step - accuracy: 0.8944 - loss: 0.2767 - mse: 0.0800 - val_accuracy: 0.8721 - val_loss: 0.3125 - val_mse: 0.0943
# Epoch 16/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.8860 - loss: 0.2693 - mse: 0.0806
# Epoch 16: val_accuracy improved from 0.87210 to 0.87634, saving model to fcn32-3d.keras
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 18s 183ms/step - accuracy: 0.8860 - loss: 0.2694 - mse: 0.0806 - val_accuracy: 0.8763 - val_loss: 0.2869 - val_mse: 0.0882
# Epoch 17/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.8997 - loss: 0.2577 - mse: 0.0748
# Epoch 17: val_accuracy did not improve from 0.87634
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 13s 127ms/step - accuracy: 0.8996 - loss: 0.2577 - mse: 0.0748 - val_accuracy: 0.8683 - val_loss: 0.2969 - val_mse: 0.0930
# Epoch 18/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.8788 - loss: 0.3121 - mse: 0.0921
# Epoch 18: val_accuracy improved from 0.87634 to 0.87714, saving model to fcn32-3d.keras
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 18s 183ms/step - accuracy: 0.8789 - loss: 0.3120 - mse: 0.0921 - val_accuracy: 0.8771 - val_loss: 0.2837 - val_mse: 0.0878
# Epoch 19/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.8997 - loss: 0.2525 - mse: 0.0740
# Epoch 19: val_accuracy did not improve from 0.87714
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 13s 127ms/step - accuracy: 0.8996 - loss: 0.2526 - mse: 0.0740 - val_accuracy: 0.8763 - val_loss: 0.2879 - val_mse: 0.0883
# Epoch 20/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.8956 - loss: 0.2637 - mse: 0.0775
# Epoch 20: val_accuracy improved from 0.87714 to 0.87742, saving model to fcn32-3d.keras
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 21s 208ms/step - accuracy: 0.8956 - loss: 0.2638 - mse: 0.0775 - val_accuracy: 0.8774 - val_loss: 0.2966 - val_mse: 0.0887
# Epoch 21/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.8977 - loss: 0.2639 - mse: 0.0771
# Epoch 21: val_accuracy did not improve from 0.87742
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 13s 127ms/step - accuracy: 0.8978 - loss: 0.2639 - mse: 0.0770 - val_accuracy: 0.8471 - val_loss: 0.3411 - val_mse: 0.1068
# Epoch 22/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.8970 - loss: 0.2743 - mse: 0.0794
# Epoch 22: val_accuracy did not improve from 0.87742
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 13s 127ms/step - accuracy: 0.8971 - loss: 0.2740 - mse: 0.0793 - val_accuracy: 0.8732 - val_loss: 0.2964 - val_mse: 0.0913
# Epoch 23/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.8833 - loss: 0.2940 - mse: 0.0867
# Epoch 23: val_accuracy improved from 0.87742 to 0.88484, saving model to fcn32-3d.keras
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 18s 181ms/step - accuracy: 0.8834 - loss: 0.2937 - mse: 0.0866 - val_accuracy: 0.8848 - val_loss: 0.2681 - val_mse: 0.0825
# Epoch 24/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.9020 - loss: 0.2593 - mse: 0.0742
# Epoch 24: val_accuracy did not improve from 0.88484
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 13s 127ms/step - accuracy: 0.9020 - loss: 0.2591 - mse: 0.0742 - val_accuracy: 0.8794 - val_loss: 0.2759 - val_mse: 0.0857
# Epoch 25/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.9134 - loss: 0.2187 - mse: 0.0640
# Epoch 25: val_accuracy did not improve from 0.88484
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 13s 127ms/step - accuracy: 0.9133 - loss: 0.2188 - mse: 0.0640 - val_accuracy: 0.8687 - val_loss: 0.3395 - val_mse: 0.0961
# Epoch 26/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.9065 - loss: 0.2375 - mse: 0.0697
# Epoch 26: val_accuracy did not improve from 0.88484
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 13s 127ms/step - accuracy: 0.9064 - loss: 0.2375 - mse: 0.0697 - val_accuracy: 0.8662 - val_loss: 0.3057 - val_mse: 0.0946
# Epoch 27/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.9149 - loss: 0.2185 - mse: 0.0634
# Epoch 27: val_accuracy did not improve from 0.88484
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 13s 127ms/step - accuracy: 0.9149 - loss: 0.2186 - mse: 0.0634 - val_accuracy: 0.8783 - val_loss: 0.2883 - val_mse: 0.0886
# Epoch 28/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.9011 - loss: 0.2667 - mse: 0.0768
# Epoch 28: val_accuracy did not improve from 0.88484
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 13s 127ms/step - accuracy: 0.9011 - loss: 0.2667 - mse: 0.0768 - val_accuracy: 0.8611 - val_loss: 0.3066 - val_mse: 0.0967
# Epoch 29/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.9048 - loss: 0.2408 - mse: 0.0708
# Epoch 29: val_accuracy did not improve from 0.88484
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 13s 127ms/step - accuracy: 0.9048 - loss: 0.2409 - mse: 0.0708 - val_accuracy: 0.8729 - val_loss: 0.3004 - val_mse: 0.0922
# Epoch 30/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.9096 - loss: 0.2261 - mse: 0.0669
# Epoch 30: val_accuracy did not improve from 0.88484
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 13s 127ms/step - accuracy: 0.9096 - loss: 0.2261 - mse: 0.0669 - val_accuracy: 0.8750 - val_loss: 0.2891 - val_mse: 0.0897
# Epoch 31/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.9141 - loss: 0.2202 - mse: 0.0641
# Epoch 31: val_accuracy improved from 0.88484 to 0.88610, saving model to fcn32-3d.keras
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 21s 207ms/step - accuracy: 0.9141 - loss: 0.2202 - mse: 0.0641 - val_accuracy: 0.8861 - val_loss: 0.2684 - val_mse: 0.0822
# Epoch 32/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.9097 - loss: 0.2212 - mse: 0.0662
# Epoch 32: val_accuracy did not improve from 0.88610
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 13s 127ms/step - accuracy: 0.9097 - loss: 0.2212 - mse: 0.0662 - val_accuracy: 0.8139 - val_loss: 0.3986 - val_mse: 0.1298
# Epoch 33/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.8789 - loss: 0.2950 - mse: 0.0883
# Epoch 33: val_accuracy did not improve from 0.88610
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 13s 127ms/step - accuracy: 0.8791 - loss: 0.2947 - mse: 0.0882 - val_accuracy: 0.8831 - val_loss: 0.2863 - val_mse: 0.0841
# Epoch 34/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.9168 - loss: 0.2067 - mse: 0.0612
# Epoch 34: val_accuracy did not improve from 0.88610
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 13s 126ms/step - accuracy: 0.9167 - loss: 0.2068 - mse: 0.0613 - val_accuracy: 0.8825 - val_loss: 0.2713 - val_mse: 0.0833
# Epoch 35/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.9127 - loss: 0.2126 - mse: 0.0637
# Epoch 35: val_accuracy did not improve from 0.88610
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 13s 127ms/step - accuracy: 0.9127 - loss: 0.2127 - mse: 0.0637 - val_accuracy: 0.8840 - val_loss: 0.2814 - val_mse: 0.0850
# Epoch 36/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.9154 - loss: 0.2117 - mse: 0.0625
# Epoch 36: val_accuracy did not improve from 0.88610
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 13s 126ms/step - accuracy: 0.9153 - loss: 0.2117 - mse: 0.0626 - val_accuracy: 0.8842 - val_loss: 0.2656 - val_mse: 0.0819
# Epoch 37/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.9044 - loss: 0.2293 - mse: 0.0696
# Epoch 37: val_accuracy improved from 0.88610 to 0.88737, saving model to fcn32-3d.keras
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 20s 205ms/step - accuracy: 0.9044 - loss: 0.2292 - mse: 0.0695 - val_accuracy: 0.8874 - val_loss: 0.2618 - val_mse: 0.0802
# Epoch 38/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.9157 - loss: 0.2043 - mse: 0.0616
# Epoch 38: val_accuracy improved from 0.88737 to 0.89267, saving model to fcn32-3d.keras
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 18s 185ms/step - accuracy: 0.9157 - loss: 0.2044 - mse: 0.0616 - val_accuracy: 0.8927 - val_loss: 0.2489 - val_mse: 0.0764
# Epoch 39/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.9173 - loss: 0.1993 - mse: 0.0601
# Epoch 39: val_accuracy did not improve from 0.89267
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 13s 127ms/step - accuracy: 0.9172 - loss: 0.1994 - mse: 0.0602 - val_accuracy: 0.8793 - val_loss: 0.2680 - val_mse: 0.0834
# Epoch 40/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.9047 - loss: 0.2233 - mse: 0.0682
# Epoch 40: val_accuracy did not improve from 0.89267
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 13s 127ms/step - accuracy: 0.9047 - loss: 0.2232 - mse: 0.0681 - val_accuracy: 0.8901 - val_loss: 0.2525 - val_mse: 0.0772
# Epoch 41/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.9192 - loss: 0.1972 - mse: 0.0593
# Epoch 41: val_accuracy did not improve from 0.89267
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 13s 127ms/step - accuracy: 0.9192 - loss: 0.1973 - mse: 0.0594 - val_accuracy: 0.8895 - val_loss: 0.2544 - val_mse: 0.0780
# Epoch 42/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.9136 - loss: 0.2039 - mse: 0.0623
# Epoch 42: val_accuracy did not improve from 0.89267
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 13s 127ms/step - accuracy: 0.9136 - loss: 0.2039 - mse: 0.0623 - val_accuracy: 0.8869 - val_loss: 0.2598 - val_mse: 0.0804
# Epoch 43/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.9141 - loss: 0.2103 - mse: 0.0632
# Epoch 43: val_accuracy did not improve from 0.89267
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 13s 127ms/step - accuracy: 0.9141 - loss: 0.2103 - mse: 0.0632 - val_accuracy: 0.8925 - val_loss: 0.2567 - val_mse: 0.0767
# Epoch 44/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.9196 - loss: 0.1949 - mse: 0.0586
# Epoch 44: val_accuracy did not improve from 0.89267
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 13s 127ms/step - accuracy: 0.9195 - loss: 0.1949 - mse: 0.0586 - val_accuracy: 0.8789 - val_loss: 0.2755 - val_mse: 0.0852
# Epoch 45/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.9108 - loss: 0.2148 - mse: 0.0650
# Epoch 45: val_accuracy did not improve from 0.89267
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 13s 127ms/step - accuracy: 0.9107 - loss: 0.2149 - mse: 0.0650 - val_accuracy: 0.8823 - val_loss: 0.2753 - val_mse: 0.0838
# Epoch 46/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.9128 - loss: 0.2048 - mse: 0.0624
# Epoch 46: val_accuracy improved from 0.89267 to 0.89269, saving model to fcn32-3d.keras
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 18s 182ms/step - accuracy: 0.9128 - loss: 0.2049 - mse: 0.0625 - val_accuracy: 0.8927 - val_loss: 0.2441 - val_mse: 0.0755
# Epoch 47/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.9125 - loss: 0.2086 - mse: 0.0632
# Epoch 47: val_accuracy improved from 0.89269 to 0.89538, saving model to fcn32-3d.keras
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 19s 186ms/step - accuracy: 0.9126 - loss: 0.2085 - mse: 0.0632 - val_accuracy: 0.8954 - val_loss: 0.2412 - val_mse: 0.0738
# Epoch 48/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.9159 - loss: 0.1926 - mse: 0.0595
# Epoch 48: val_accuracy did not improve from 0.89538
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 13s 127ms/step - accuracy: 0.9159 - loss: 0.1925 - mse: 0.0594 - val_accuracy: 0.8916 - val_loss: 0.2541 - val_mse: 0.0768
# Epoch 49/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.9247 - loss: 0.1766 - mse: 0.0539
# Epoch 49: val_accuracy did not improve from 0.89538
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 13s 127ms/step - accuracy: 0.9247 - loss: 0.1768 - mse: 0.0540 - val_accuracy: 0.8822 - val_loss: 0.2720 - val_mse: 0.0825
# Epoch 50/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.8849 - loss: 0.2728 - mse: 0.0828
# Epoch 50: val_accuracy did not improve from 0.89538
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 13s 127ms/step - accuracy: 0.8850 - loss: 0.2726 - mse: 0.0827 - val_accuracy: 0.8850 - val_loss: 0.2598 - val_mse: 0.0799

# %%
# Save model history
np.save('fcn32-3d-history.npy', F.history.history)

# %%
# Copy models to drive
# !cp fcn32-3d.keras drive/MyDrive/Diss/
# !cp fcn32-3d-history.npy drive/MyDrive/Diss/

# %% [markdown]
# ## ResUNet

# %%
R = res_unet(512, [64, 128, 256, 512], 3, 3, 1)
save_model_resunet = ModelCheckpoint('resunet-3d.weights.h5', monitor='val_accuracy',verbose=1, save_best_only=True, save_weights_only=True)
train = trainGenerator(1, t_images, t_masks, data_gen_args, save_to_dir=None)
R.fit(train, validation_data = validation_df, epochs = 40, steps_per_epoch = 100, callbacks=[save_model_resunet])
# Out:
# Epoch 1/40
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.7416 - loss: 8.8976 - mse: 0.2397
# Epoch 1: val_accuracy improved from -inf to 0.83011, saving model to resunet-3d.weights.h5
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 33s 114ms/step - accuracy: 0.7425 - loss: 8.8398 - mse: 0.2388 - val_accuracy: 0.8301 - val_loss: 0.5353 - val_mse: 0.1367
# Epoch 2/40
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.9342 - loss: 0.2153 - mse: 0.0531
# Epoch 2: val_accuracy improved from 0.83011 to 0.90995, saving model to resunet-3d.weights.h5
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 9s 89ms/step - accuracy: 0.9342 - loss: 0.2154 - mse: 0.0532 - val_accuracy: 0.9099 - val_loss: 0.2194 - val_mse: 0.0651
# Epoch 3/40
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.9144 - loss: 0.2574 - mse: 0.0660
# Epoch 3: val_accuracy did not improve from 0.90995
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 8s 77ms/step - accuracy: 0.9144 - loss: 0.2574 - mse: 0.0660 - val_accuracy: 0.9023 - val_loss: 0.2455 - val_mse: 0.0719
# Epoch 4/40
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.9430 - loss: 0.1594 - mse: 0.0442
# Epoch 4: val_accuracy did not improve from 0.90995
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 7s 74ms/step - accuracy: 0.9430 - loss: 0.1595 - mse: 0.0442 - val_accuracy: 0.8820 - val_loss: 0.3434 - val_mse: 0.0929
# Epoch 5/40
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.9374 - loss: 0.2020 - mse: 0.0509
# Epoch 5: val_accuracy improved from 0.90995 to 0.91594, saving model to resunet-3d.weights.h5
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 8s 84ms/step - accuracy: 0.9374 - loss: 0.2018 - mse: 0.0509 - val_accuracy: 0.9159 - val_loss: 0.2126 - val_mse: 0.0632
# Epoch 6/40
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.9470 - loss: 0.1580 - mse: 0.0413
# Epoch 6: val_accuracy did not improve from 0.91594
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 7s 75ms/step - accuracy: 0.9469 - loss: 0.1581 - mse: 0.0413 - val_accuracy: 0.8973 - val_loss: 0.2770 - val_mse: 0.0790
# Epoch 7/40
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.9462 - loss: 0.1574 - mse: 0.0421
# Epoch 7: val_accuracy improved from 0.91594 to 0.91885, saving model to resunet-3d.weights.h5
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 8s 85ms/step - accuracy: 0.9462 - loss: 0.1575 - mse: 0.0421 - val_accuracy: 0.9188 - val_loss: 0.2093 - val_mse: 0.0619
# Epoch 8/40
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.9356 - loss: 0.1788 - mse: 0.0486
# Epoch 8: val_accuracy did not improve from 0.91885
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 7s 69ms/step - accuracy: 0.9355 - loss: 0.1789 - mse: 0.0487 - val_accuracy: 0.9146 - val_loss: 0.2125 - val_mse: 0.0627
# Epoch 9/40
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.9501 - loss: 0.1491 - mse: 0.0394
# Epoch 9: val_accuracy improved from 0.91885 to 0.91885, saving model to resunet-3d.weights.h5
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 8s 83ms/step - accuracy: 0.9500 - loss: 0.1492 - mse: 0.0394 - val_accuracy: 0.9189 - val_loss: 0.1938 - val_mse: 0.0586
# Epoch 10/40
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.9432 - loss: 0.1639 - mse: 0.0450
# Epoch 10: val_accuracy did not improve from 0.91885
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 7s 67ms/step - accuracy: 0.9432 - loss: 0.1639 - mse: 0.0450 - val_accuracy: 0.9160 - val_loss: 0.2119 - val_mse: 0.0621
# Epoch 11/40
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.9431 - loss: 0.1623 - mse: 0.0431
# Epoch 11: val_accuracy did not improve from 0.91885
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 8s 77ms/step - accuracy: 0.9430 - loss: 0.1627 - mse: 0.0432 - val_accuracy: 0.9066 - val_loss: 0.2772 - val_mse: 0.0753
# Epoch 12/40
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.9504 - loss: 0.1671 - mse: 0.0402
# Epoch 12: val_accuracy did not improve from 0.91885
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 7s 73ms/step - accuracy: 0.9504 - loss: 0.1670 - mse: 0.0402 - val_accuracy: 0.8942 - val_loss: 0.3520 - val_mse: 0.0856
# Epoch 13/40
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.9458 - loss: 0.1796 - mse: 0.0441
# Epoch 13: val_accuracy did not improve from 0.91885
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 7s 74ms/step - accuracy: 0.9458 - loss: 0.1795 - mse: 0.0440 - val_accuracy: 0.9132 - val_loss: 0.2190 - val_mse: 0.0649
# Epoch 14/40
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.9498 - loss: 0.1458 - mse: 0.0390
# Epoch 14: val_accuracy did not improve from 0.91885
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 8s 76ms/step - accuracy: 0.9498 - loss: 0.1459 - mse: 0.0390 - val_accuracy: 0.9145 - val_loss: 0.2281 - val_mse: 0.0637
# Epoch 15/40
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.9478 - loss: 0.1588 - mse: 0.0408
# Epoch 15: val_accuracy did not improve from 0.91885
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 8s 76ms/step - accuracy: 0.9478 - loss: 0.1588 - mse: 0.0408 - val_accuracy: 0.9183 - val_loss: 0.2205 - val_mse: 0.0638
# Epoch 16/40
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.9564 - loss: 0.1299 - mse: 0.0336
# Epoch 16: val_accuracy improved from 0.91885 to 0.92371, saving model to resunet-3d.weights.h5
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 9s 87ms/step - accuracy: 0.9564 - loss: 0.1299 - mse: 0.0336 - val_accuracy: 0.9237 - val_loss: 0.1941 - val_mse: 0.0574
# Epoch 17/40
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.9535 - loss: 0.1302 - mse: 0.0353
# Epoch 17: val_accuracy did not improve from 0.92371
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 7s 69ms/step - accuracy: 0.9535 - loss: 0.1304 - mse: 0.0354 - val_accuracy: 0.9235 - val_loss: 0.1883 - val_mse: 0.0562
# Epoch 18/40
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.9457 - loss: 0.1547 - mse: 0.0416
# Epoch 18: val_accuracy did not improve from 0.92371
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 7s 73ms/step - accuracy: 0.9457 - loss: 0.1548 - mse: 0.0416 - val_accuracy: 0.9202 - val_loss: 0.1941 - val_mse: 0.0585
# Epoch 19/40
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.9541 - loss: 0.1408 - mse: 0.0361
# Epoch 19: val_accuracy improved from 0.92371 to 0.92419, saving model to resunet-3d.weights.h5
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 8s 84ms/step - accuracy: 0.9541 - loss: 0.1409 - mse: 0.0361 - val_accuracy: 0.9242 - val_loss: 0.1938 - val_mse: 0.0574
# Epoch 20/40
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.9550 - loss: 0.1466 - mse: 0.0360
# Epoch 20: val_accuracy improved from 0.92419 to 0.92548, saving model to resunet-3d.weights.h5
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 7s 75ms/step - accuracy: 0.9550 - loss: 0.1466 - mse: 0.0360 - val_accuracy: 0.9255 - val_loss: 0.1907 - val_mse: 0.0555
# Epoch 21/40
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.9493 - loss: 0.1482 - mse: 0.0397
# Epoch 21: val_accuracy did not improve from 0.92548
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 7s 67ms/step - accuracy: 0.9492 - loss: 0.1482 - mse: 0.0397 - val_accuracy: 0.9091 - val_loss: 0.2601 - val_mse: 0.0704
# Epoch 22/40
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.9511 - loss: 0.1606 - mse: 0.0388
# Epoch 22: val_accuracy did not improve from 0.92548
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 7s 75ms/step - accuracy: 0.9511 - loss: 0.1603 - mse: 0.0387 - val_accuracy: 0.9221 - val_loss: 0.2091 - val_mse: 0.0606
# Epoch 23/40
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.9497 - loss: 0.1510 - mse: 0.0396
# Epoch 23: val_accuracy did not improve from 0.92548
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 7s 74ms/step - accuracy: 0.9498 - loss: 0.1508 - mse: 0.0396 - val_accuracy: 0.9217 - val_loss: 0.2063 - val_mse: 0.0587
# Epoch 24/40
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.9543 - loss: 0.1483 - mse: 0.0367
# Epoch 24: val_accuracy did not improve from 0.92548
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 8s 76ms/step - accuracy: 0.9543 - loss: 0.1482 - mse: 0.0367 - val_accuracy: 0.9225 - val_loss: 0.1968 - val_mse: 0.0582
# Epoch 25/40
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.9566 - loss: 0.1280 - mse: 0.0337
# Epoch 25: val_accuracy did not improve from 0.92548
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 7s 74ms/step - accuracy: 0.9566 - loss: 0.1281 - mse: 0.0337 - val_accuracy: 0.9223 - val_loss: 0.1945 - val_mse: 0.0573
# Epoch 26/40
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.9545 - loss: 0.1368 - mse: 0.0353
# Epoch 26: val_accuracy did not improve from 0.92548
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 8s 78ms/step - accuracy: 0.9545 - loss: 0.1369 - mse: 0.0354 - val_accuracy: 0.9251 - val_loss: 0.2008 - val_mse: 0.0583
# Epoch 27/40
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.9604 - loss: 0.1186 - mse: 0.0307
# Epoch 27: val_accuracy improved from 0.92548 to 0.92906, saving model to resunet-3d.weights.h5
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 9s 86ms/step - accuracy: 0.9604 - loss: 0.1187 - mse: 0.0307 - val_accuracy: 0.9291 - val_loss: 0.1732 - val_mse: 0.0516
# Epoch 28/40
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.9561 - loss: 0.1367 - mse: 0.0352
# Epoch 28: val_accuracy did not improve from 0.92906
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 7s 67ms/step - accuracy: 0.9561 - loss: 0.1367 - mse: 0.0352 - val_accuracy: 0.9201 - val_loss: 0.2193 - val_mse: 0.0629
# Epoch 29/40
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.9587 - loss: 0.1245 - mse: 0.0328
# Epoch 29: val_accuracy did not improve from 0.92906
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 8s 79ms/step - accuracy: 0.9586 - loss: 0.1247 - mse: 0.0329 - val_accuracy: 0.9136 - val_loss: 0.2380 - val_mse: 0.0661
# Epoch 30/40
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.9508 - loss: 0.1696 - mse: 0.0396
# Epoch 30: val_accuracy did not improve from 0.92906
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 8s 80ms/step - accuracy: 0.9508 - loss: 0.1694 - mse: 0.0395 - val_accuracy: 0.9225 - val_loss: 0.1917 - val_mse: 0.0568
# Epoch 31/40
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.9588 - loss: 0.1236 - mse: 0.0321
# Epoch 31: val_accuracy did not improve from 0.92906
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 7s 73ms/step - accuracy: 0.9588 - loss: 0.1236 - mse: 0.0321 - val_accuracy: 0.9236 - val_loss: 0.1977 - val_mse: 0.0581
# Epoch 32/40
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.9581 - loss: 0.1248 - mse: 0.0330
# Epoch 32: val_accuracy improved from 0.92906 to 0.93212, saving model to resunet-3d.weights.h5
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 8s 85ms/step - accuracy: 0.9581 - loss: 0.1249 - mse: 0.0330 - val_accuracy: 0.9321 - val_loss: 0.1734 - val_mse: 0.0503
# Epoch 33/40
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.9485 - loss: 0.1584 - mse: 0.0421
# Epoch 33: val_accuracy did not improve from 0.93212
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 6s 65ms/step - accuracy: 0.9485 - loss: 0.1584 - mse: 0.0421 - val_accuracy: 0.9314 - val_loss: 0.1845 - val_mse: 0.0517
# Epoch 34/40
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.9569 - loss: 0.1330 - mse: 0.0342
# Epoch 34: val_accuracy did not improve from 0.93212
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 8s 82ms/step - accuracy: 0.9568 - loss: 0.1331 - mse: 0.0342 - val_accuracy: 0.9263 - val_loss: 0.2094 - val_mse: 0.0588
# Epoch 35/40
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.9519 - loss: 0.1512 - mse: 0.0380
# Epoch 35: val_accuracy did not improve from 0.93212
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 7s 74ms/step - accuracy: 0.9519 - loss: 0.1512 - mse: 0.0380 - val_accuracy: 0.9245 - val_loss: 0.1979 - val_mse: 0.0578
# Epoch 36/40
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.9538 - loss: 0.1312 - mse: 0.0356
# Epoch 36: val_accuracy did not improve from 0.93212
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 8s 77ms/step - accuracy: 0.9538 - loss: 0.1313 - mse: 0.0356 - val_accuracy: 0.9141 - val_loss: 0.2374 - val_mse: 0.0684
# Epoch 37/40
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.9469 - loss: 0.1626 - mse: 0.0424
# Epoch 37: val_accuracy did not improve from 0.93212
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 8s 78ms/step - accuracy: 0.9470 - loss: 0.1624 - mse: 0.0423 - val_accuracy: 0.9291 - val_loss: 0.1749 - val_mse: 0.0523
# Epoch 38/40
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.9591 - loss: 0.1286 - mse: 0.0323
# Epoch 38: val_accuracy did not improve from 0.93212
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 7s 75ms/step - accuracy: 0.9591 - loss: 0.1286 - mse: 0.0323 - val_accuracy: 0.9278 - val_loss: 0.1873 - val_mse: 0.0538
# Epoch 39/40
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.9604 - loss: 0.1136 - mse: 0.0304
# Epoch 39: val_accuracy did not improve from 0.93212
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 7s 74ms/step - accuracy: 0.9603 - loss: 0.1138 - mse: 0.0304 - val_accuracy: 0.9125 - val_loss: 0.2196 - val_mse: 0.0646
# Epoch 40/40
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.9533 - loss: 0.1447 - mse: 0.0368
# Epoch 40: val_accuracy did not improve from 0.93212
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 8s 77ms/step - accuracy: 0.9533 - loss: 0.1447 - mse: 0.0368 - val_accuracy: 0.9185 - val_loss: 0.2026 - val_mse: 0.0599

# %%
# Save model history
np.save('resunet-3d-history.npy',R.history.history)

# %%
# Copy models to drive
# !cp resunet-3d.keras drive/MyDrive/Diss/models/
# !cp resunet-3d-history.npy drive/MyDrive/Diss/models/
# Out:
# cp: cannot stat 'resunet-3d.keras': No such file or directory
# cp: cannot create regular file 'drive/MyDrive/Diss/models/': Not a directory

# %% [markdown]
# # Train on 4-band data

# %% [markdown]
# ## Train on 4-band Amazon data

# %% [markdown]
# ### U-Net

# %%
# Train U-Net with generator
model_unet_4band = UNet()
save_model_4band = ModelCheckpoint('unet-4d.keras', monitor='val_accuracy',verbose=1, save_best_only=True)
model_unet_4band.fit(train_df_4band_amazon, epochs = 20, validation_data = validation_df_4band_amazon, callbacks=[save_model_4band])
# Out:
# Epoch 1/20
# 249/250 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.7827 - loss: 0.4632 - mse: 0.1482
# Epoch 1: val_accuracy improved from -inf to 0.91586, saving model to unet-4d.keras
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 21s 44ms/step - accuracy: 0.7833 - loss: 0.4622 - mse: 0.1478 - val_accuracy: 0.9159 - val_loss: 0.2170 - val_mse: 0.0637
# Epoch 2/20
# 249/250 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.8945 - loss: 0.2584 - mse: 0.0775
# Epoch 2: val_accuracy improved from 0.91586 to 0.93956, saving model to unet-4d.keras
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 10s 40ms/step - accuracy: 0.8947 - loss: 0.2581 - mse: 0.0774 - val_accuracy: 0.9396 - val_loss: 0.1625 - val_mse: 0.0460
# Epoch 3/20
# 249/250 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9126 - loss: 0.2191 - mse: 0.0651
# Epoch 3: val_accuracy did not improve from 0.93956
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 9s 34ms/step - accuracy: 0.9127 - loss: 0.2188 - mse: 0.0650 - val_accuracy: 0.9138 - val_loss: 0.2066 - val_mse: 0.0629
# Epoch 4/20
# 249/250 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9322 - loss: 0.1771 - mse: 0.0517
# Epoch 4: val_accuracy did not improve from 0.93956
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 9s 34ms/step - accuracy: 0.9322 - loss: 0.1769 - mse: 0.0516 - val_accuracy: 0.9257 - val_loss: 0.1825 - val_mse: 0.0548
# Epoch 5/20
# 249/250 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9365 - loss: 0.1626 - mse: 0.0474
# Epoch 5: val_accuracy did not improve from 0.93956
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 9s 34ms/step - accuracy: 0.9365 - loss: 0.1625 - mse: 0.0474 - val_accuracy: 0.9320 - val_loss: 0.1702 - val_mse: 0.0502
# Epoch 6/20
# 249/250 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9359 - loss: 0.1598 - mse: 0.0471
# Epoch 6: val_accuracy did not improve from 0.93956
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 9s 34ms/step - accuracy: 0.9360 - loss: 0.1597 - mse: 0.0471 - val_accuracy: 0.9118 - val_loss: 0.2092 - val_mse: 0.0635
# Epoch 7/20
# 249/250 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9430 - loss: 0.1437 - mse: 0.0420
# Epoch 7: val_accuracy improved from 0.93956 to 0.96308, saving model to unet-4d.keras
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 10s 40ms/step - accuracy: 0.9430 - loss: 0.1436 - mse: 0.0420 - val_accuracy: 0.9631 - val_loss: 0.1025 - val_mse: 0.0285
# Epoch 8/20
# 249/250 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9383 - loss: 0.1475 - mse: 0.0443
# Epoch 8: val_accuracy did not improve from 0.96308
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 9s 34ms/step - accuracy: 0.9384 - loss: 0.1473 - mse: 0.0442 - val_accuracy: 0.9611 - val_loss: 0.1005 - val_mse: 0.0293
# Epoch 9/20
# 249/250 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9443 - loss: 0.1341 - mse: 0.0403
# Epoch 9: val_accuracy improved from 0.96308 to 0.96507, saving model to unet-4d.keras
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 10s 40ms/step - accuracy: 0.9444 - loss: 0.1339 - mse: 0.0402 - val_accuracy: 0.9651 - val_loss: 0.0962 - val_mse: 0.0273
# Epoch 10/20
# 249/250 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9514 - loss: 0.1223 - mse: 0.0362
# Epoch 10: val_accuracy did not improve from 0.96507
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 9s 34ms/step - accuracy: 0.9515 - loss: 0.1221 - mse: 0.0362 - val_accuracy: 0.9587 - val_loss: 0.1103 - val_mse: 0.0315
# Epoch 11/20
# 249/250 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9561 - loss: 0.1126 - mse: 0.0329
# Epoch 11: val_accuracy improved from 0.96507 to 0.97059, saving model to unet-4d.keras
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 10s 40ms/step - accuracy: 0.9562 - loss: 0.1124 - mse: 0.0329 - val_accuracy: 0.9706 - val_loss: 0.0799 - val_mse: 0.0225
# Epoch 12/20
# 249/250 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9560 - loss: 0.1093 - mse: 0.0325
# Epoch 12: val_accuracy did not improve from 0.97059
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 9s 34ms/step - accuracy: 0.9561 - loss: 0.1092 - mse: 0.0325 - val_accuracy: 0.9657 - val_loss: 0.0885 - val_mse: 0.0258
# Epoch 13/20
# 249/250 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9570 - loss: 0.1065 - mse: 0.0317
# Epoch 13: val_accuracy did not improve from 0.97059
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 9s 34ms/step - accuracy: 0.9571 - loss: 0.1064 - mse: 0.0317 - val_accuracy: 0.9357 - val_loss: 0.1594 - val_mse: 0.0473
# Epoch 14/20
# 249/250 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9589 - loss: 0.1048 - mse: 0.0306
# Epoch 14: val_accuracy did not improve from 0.97059
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 9s 34ms/step - accuracy: 0.9589 - loss: 0.1046 - mse: 0.0305 - val_accuracy: 0.9673 - val_loss: 0.0937 - val_mse: 0.0258
# Epoch 15/20
# 249/250 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9556 - loss: 0.1119 - mse: 0.0330
# Epoch 15: val_accuracy did not improve from 0.97059
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 9s 34ms/step - accuracy: 0.9557 - loss: 0.1117 - mse: 0.0329 - val_accuracy: 0.9586 - val_loss: 0.1113 - val_mse: 0.0316
# Epoch 16/20
# 249/250 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9644 - loss: 0.0920 - mse: 0.0269
# Epoch 16: val_accuracy did not improve from 0.97059
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 9s 34ms/step - accuracy: 0.9645 - loss: 0.0919 - mse: 0.0268 - val_accuracy: 0.9705 - val_loss: 0.0772 - val_mse: 0.0220
# Epoch 17/20
# 249/250 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9615 - loss: 0.0963 - mse: 0.0284
# Epoch 17: val_accuracy did not improve from 0.97059
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 9s 34ms/step - accuracy: 0.9616 - loss: 0.0961 - mse: 0.0283 - val_accuracy: 0.9697 - val_loss: 0.0790 - val_mse: 0.0227
# Epoch 18/20
# 249/250 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9659 - loss: 0.0846 - mse: 0.0251
# Epoch 18: val_accuracy did not improve from 0.97059
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 9s 34ms/step - accuracy: 0.9659 - loss: 0.0846 - mse: 0.0251 - val_accuracy: 0.9621 - val_loss: 0.0974 - val_mse: 0.0283
# Epoch 19/20
# 249/250 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9635 - loss: 0.0917 - mse: 0.0270
# Epoch 19: val_accuracy did not improve from 0.97059
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 9s 34ms/step - accuracy: 0.9635 - loss: 0.0915 - mse: 0.0269 - val_accuracy: 0.9691 - val_loss: 0.0790 - val_mse: 0.0229
# Epoch 20/20
# 249/250 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9674 - loss: 0.0816 - mse: 0.0240
# Epoch 20: val_accuracy did not improve from 0.97059
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 9s 34ms/step - accuracy: 0.9675 - loss: 0.0815 - mse: 0.0240 - val_accuracy: 0.9696 - val_loss: 0.0732 - val_mse: 0.0220

# %%
# Save model history
np.save('unet-4d-history.npy',model_unet_4band.history.history)

# %%
# Copy models to drive
# !cp unet-4d.keras drive/MyDrive/Diss/
# !cp unet-4d-history.npy drive/MyDrive/Diss/

# %% [markdown]
# ### Attention U-Net

# %%
# Train U-Net with generator
model_attention_unet_4band = UNetAM(input_size=(512,512,4), filter_base=16, lr=0.0005)
save_model_4band_attention = ModelCheckpoint('unet-attention-4d.keras', monitor='val_accuracy',verbose=1, save_best_only=True)
model_attention_unet_4band.fit(train_df_4band_amazon, epochs = 60, validation_data = validation_df_4band_amazon, callbacks=[save_model_4band_attention])
# Out:
# Epoch 1/60
# 249/250 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.7305 - loss: 0.5244 - mse: 0.1786
# Epoch 1: val_accuracy improved from -inf to 0.91808, saving model to unet-attention-4d.keras
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 20s 22ms/step - accuracy: 0.7314 - loss: 0.5232 - mse: 0.1781 - val_accuracy: 0.9181 - val_loss: 0.2136 - val_mse: 0.0623
# Epoch 2/60
# 246/250 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8939 - loss: 0.2564 - mse: 0.0772
# Epoch 2: val_accuracy improved from 0.91808 to 0.93243, saving model to unet-attention-4d.keras
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.8943 - loss: 0.2557 - mse: 0.0770 - val_accuracy: 0.9324 - val_loss: 0.1718 - val_mse: 0.0501
# Epoch 3/60
# 246/250 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9064 - loss: 0.2264 - mse: 0.0685
# Epoch 3: val_accuracy improved from 0.93243 to 0.94188, saving model to unet-attention-4d.keras
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.9068 - loss: 0.2257 - mse: 0.0682 - val_accuracy: 0.9419 - val_loss: 0.1543 - val_mse: 0.0440
# Epoch 4/60
# 246/250 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9202 - loss: 0.1975 - mse: 0.0586
# Epoch 4: val_accuracy did not improve from 0.94188
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.9205 - loss: 0.1968 - mse: 0.0584 - val_accuracy: 0.9250 - val_loss: 0.1865 - val_mse: 0.0552
# Epoch 5/60
# 246/250 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9268 - loss: 0.1797 - mse: 0.0539
# Epoch 5: val_accuracy did not improve from 0.94188
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.9271 - loss: 0.1791 - mse: 0.0537 - val_accuracy: 0.9209 - val_loss: 0.1970 - val_mse: 0.0589
# Epoch 6/60
# 246/250 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9347 - loss: 0.1654 - mse: 0.0491
# Epoch 6: val_accuracy did not improve from 0.94188
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.9350 - loss: 0.1649 - mse: 0.0489 - val_accuracy: 0.9385 - val_loss: 0.1611 - val_mse: 0.0466
# Epoch 7/60
# 246/250 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9354 - loss: 0.1599 - mse: 0.0478
# Epoch 7: val_accuracy did not improve from 0.94188
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.9357 - loss: 0.1593 - mse: 0.0476 - val_accuracy: 0.9402 - val_loss: 0.1629 - val_mse: 0.0461
# Epoch 8/60
# 246/250 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9403 - loss: 0.1498 - mse: 0.0446
# Epoch 8: val_accuracy improved from 0.94188 to 0.95011, saving model to unet-attention-4d.keras
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.9405 - loss: 0.1493 - mse: 0.0444 - val_accuracy: 0.9501 - val_loss: 0.1389 - val_mse: 0.0389
# Epoch 9/60
# 246/250 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9410 - loss: 0.1467 - mse: 0.0437
# Epoch 9: val_accuracy improved from 0.95011 to 0.95347, saving model to unet-attention-4d.keras
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.9412 - loss: 0.1461 - mse: 0.0436 - val_accuracy: 0.9535 - val_loss: 0.1323 - val_mse: 0.0363
# Epoch 10/60
# 246/250 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9432 - loss: 0.1393 - mse: 0.0417
# Epoch 10: val_accuracy improved from 0.95347 to 0.95563, saving model to unet-attention-4d.keras
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.9435 - loss: 0.1388 - mse: 0.0415 - val_accuracy: 0.9556 - val_loss: 0.1286 - val_mse: 0.0352
# Epoch 11/60
# 246/250 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9468 - loss: 0.1326 - mse: 0.0395
# Epoch 11: val_accuracy improved from 0.95563 to 0.95764, saving model to unet-attention-4d.keras
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.9470 - loss: 0.1321 - mse: 0.0393 - val_accuracy: 0.9576 - val_loss: 0.1216 - val_mse: 0.0335
# Epoch 12/60
# 246/250 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9516 - loss: 0.1226 - mse: 0.0362
# Epoch 12: val_accuracy improved from 0.95764 to 0.95924, saving model to unet-attention-4d.keras
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.9518 - loss: 0.1222 - mse: 0.0361 - val_accuracy: 0.9592 - val_loss: 0.1163 - val_mse: 0.0322
# Epoch 13/60
# 246/250 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9510 - loss: 0.1239 - mse: 0.0366
# Epoch 13: val_accuracy improved from 0.95924 to 0.96112, saving model to unet-attention-4d.keras
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.9512 - loss: 0.1234 - mse: 0.0365 - val_accuracy: 0.9611 - val_loss: 0.1036 - val_mse: 0.0297
# Epoch 14/60
# 246/250 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9525 - loss: 0.1166 - mse: 0.0349
# Epoch 14: val_accuracy improved from 0.96112 to 0.96797, saving model to unet-attention-4d.keras
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.9527 - loss: 0.1161 - mse: 0.0348 - val_accuracy: 0.9680 - val_loss: 0.0871 - val_mse: 0.0246
# Epoch 15/60
# 246/250 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9556 - loss: 0.1086 - mse: 0.0325
# Epoch 15: val_accuracy did not improve from 0.96797
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.9558 - loss: 0.1082 - mse: 0.0324 - val_accuracy: 0.9680 - val_loss: 0.0866 - val_mse: 0.0246
# Epoch 16/60
# 246/250 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9571 - loss: 0.1043 - mse: 0.0313
# Epoch 16: val_accuracy did not improve from 0.96797
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.9573 - loss: 0.1039 - mse: 0.0312 - val_accuracy: 0.9674 - val_loss: 0.0855 - val_mse: 0.0247
# Epoch 17/60
# 246/250 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9529 - loss: 0.1144 - mse: 0.0342
# Epoch 17: val_accuracy did not improve from 0.96797
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.9531 - loss: 0.1140 - mse: 0.0340 - val_accuracy: 0.9676 - val_loss: 0.0897 - val_mse: 0.0250
# Epoch 18/60
# 246/250 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9605 - loss: 0.0978 - mse: 0.0289
# Epoch 18: val_accuracy did not improve from 0.96797
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.9606 - loss: 0.0974 - mse: 0.0288 - val_accuracy: 0.9679 - val_loss: 0.0850 - val_mse: 0.0244
# Epoch 19/60
# 246/250 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9571 - loss: 0.1035 - mse: 0.0312
# Epoch 19: val_accuracy did not improve from 0.96797
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.9573 - loss: 0.1031 - mse: 0.0310 - val_accuracy: 0.9674 - val_loss: 0.0866 - val_mse: 0.0249
# Epoch 20/60
# 246/250 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9558 - loss: 0.1067 - mse: 0.0322
# Epoch 20: val_accuracy improved from 0.96797 to 0.97107, saving model to unet-attention-4d.keras
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.9560 - loss: 0.1063 - mse: 0.0320 - val_accuracy: 0.9711 - val_loss: 0.0761 - val_mse: 0.0218
# Epoch 21/60
# 246/250 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9635 - loss: 0.0887 - mse: 0.0265
# Epoch 21: val_accuracy did not improve from 0.97107
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.9636 - loss: 0.0885 - mse: 0.0264 - val_accuracy: 0.9705 - val_loss: 0.0756 - val_mse: 0.0219
# Epoch 22/60
# 246/250 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9638 - loss: 0.0898 - mse: 0.0265
# Epoch 22: val_accuracy improved from 0.97107 to 0.97167, saving model to unet-attention-4d.keras
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.9639 - loss: 0.0895 - mse: 0.0265 - val_accuracy: 0.9717 - val_loss: 0.0732 - val_mse: 0.0211
# Epoch 23/60
# 246/250 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9628 - loss: 0.0911 - mse: 0.0272
# Epoch 23: val_accuracy improved from 0.97167 to 0.97492, saving model to unet-attention-4d.keras
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.9630 - loss: 0.0908 - mse: 0.0271 - val_accuracy: 0.9749 - val_loss: 0.0650 - val_mse: 0.0186
# Epoch 24/60
# 246/250 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9596 - loss: 0.0978 - mse: 0.0294
# Epoch 24: val_accuracy did not improve from 0.97492
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.9598 - loss: 0.0974 - mse: 0.0293 - val_accuracy: 0.9724 - val_loss: 0.0697 - val_mse: 0.0203
# Epoch 25/60
# 246/250 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9672 - loss: 0.0806 - mse: 0.0239
# Epoch 25: val_accuracy did not improve from 0.97492
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.9673 - loss: 0.0804 - mse: 0.0238 - val_accuracy: 0.9728 - val_loss: 0.0684 - val_mse: 0.0200
# Epoch 26/60
# 246/250 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9686 - loss: 0.0773 - mse: 0.0229
# Epoch 26: val_accuracy did not improve from 0.97492
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.9687 - loss: 0.0771 - mse: 0.0228 - val_accuracy: 0.9706 - val_loss: 0.0735 - val_mse: 0.0216
# Epoch 27/60
# 246/250 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9699 - loss: 0.0762 - mse: 0.0224
# Epoch 27: val_accuracy did not improve from 0.97492
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.9700 - loss: 0.0761 - mse: 0.0223 - val_accuracy: 0.9682 - val_loss: 0.0799 - val_mse: 0.0233
# Epoch 28/60
# 246/250 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9672 - loss: 0.0822 - mse: 0.0242
# Epoch 28: val_accuracy did not improve from 0.97492
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.9672 - loss: 0.0820 - mse: 0.0242 - val_accuracy: 0.9674 - val_loss: 0.0831 - val_mse: 0.0242
# Epoch 29/60
# 246/250 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9625 - loss: 0.0933 - mse: 0.0276
# Epoch 29: val_accuracy did not improve from 0.97492
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.9626 - loss: 0.0929 - mse: 0.0275 - val_accuracy: 0.9705 - val_loss: 0.0751 - val_mse: 0.0218
# Epoch 30/60
# 246/250 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9643 - loss: 0.0881 - mse: 0.0262
# Epoch 30: val_accuracy did not improve from 0.97492
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.9645 - loss: 0.0877 - mse: 0.0261 - val_accuracy: 0.9730 - val_loss: 0.0674 - val_mse: 0.0197
# Epoch 31/60
# 246/250 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9694 - loss: 0.0764 - mse: 0.0225
# Epoch 31: val_accuracy improved from 0.97492 to 0.97546, saving model to unet-attention-4d.keras
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.9695 - loss: 0.0762 - mse: 0.0224 - val_accuracy: 0.9755 - val_loss: 0.0604 - val_mse: 0.0178
# Epoch 32/60
# 246/250 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9687 - loss: 0.0767 - mse: 0.0229
# Epoch 32: val_accuracy did not improve from 0.97546
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.9688 - loss: 0.0765 - mse: 0.0228 - val_accuracy: 0.9747 - val_loss: 0.0633 - val_mse: 0.0185
# Epoch 33/60
# 246/250 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9663 - loss: 0.0833 - mse: 0.0248
# Epoch 33: val_accuracy did not improve from 0.97546
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.9664 - loss: 0.0831 - mse: 0.0247 - val_accuracy: 0.9711 - val_loss: 0.0726 - val_mse: 0.0213
# Epoch 34/60
# 246/250 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9694 - loss: 0.0766 - mse: 0.0226
# Epoch 34: val_accuracy did not improve from 0.97546
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.9695 - loss: 0.0763 - mse: 0.0225 - val_accuracy: 0.9752 - val_loss: 0.0611 - val_mse: 0.0181
# Epoch 35/60
# 246/250 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9721 - loss: 0.0687 - mse: 0.0204
# Epoch 35: val_accuracy did not improve from 0.97546
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.9722 - loss: 0.0685 - mse: 0.0204 - val_accuracy: 0.9731 - val_loss: 0.0664 - val_mse: 0.0197
# Epoch 36/60
# 246/250 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9730 - loss: 0.0671 - mse: 0.0198
# Epoch 36: val_accuracy did not improve from 0.97546
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.9731 - loss: 0.0669 - mse: 0.0198 - val_accuracy: 0.9744 - val_loss: 0.0633 - val_mse: 0.0187
# Epoch 37/60
# 246/250 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9737 - loss: 0.0648 - mse: 0.0193
# Epoch 37: val_accuracy did not improve from 0.97546
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.9738 - loss: 0.0646 - mse: 0.0192 - val_accuracy: 0.9741 - val_loss: 0.0645 - val_mse: 0.0190
# Epoch 38/60
# 246/250 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9754 - loss: 0.0615 - mse: 0.0182
# Epoch 38: val_accuracy improved from 0.97546 to 0.97603, saving model to unet-attention-4d.keras
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.9754 - loss: 0.0613 - mse: 0.0181 - val_accuracy: 0.9760 - val_loss: 0.0603 - val_mse: 0.0177
# Epoch 39/60
# 246/250 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9738 - loss: 0.0642 - mse: 0.0191
# Epoch 39: val_accuracy did not improve from 0.97603
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.9738 - loss: 0.0640 - mse: 0.0191 - val_accuracy: 0.9710 - val_loss: 0.0686 - val_mse: 0.0208
# Epoch 40/60
# 246/250 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9724 - loss: 0.0682 - mse: 0.0203
# Epoch 40: val_accuracy did not improve from 0.97603
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.9725 - loss: 0.0681 - mse: 0.0202 - val_accuracy: 0.9583 - val_loss: 0.1007 - val_mse: 0.0301
# Epoch 41/60
# 246/250 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9661 - loss: 0.0819 - mse: 0.0244
# Epoch 41: val_accuracy did not improve from 0.97603
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.9663 - loss: 0.0814 - mse: 0.0243 - val_accuracy: 0.9759 - val_loss: 0.0603 - val_mse: 0.0177
# Epoch 42/60
# 246/250 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9733 - loss: 0.0655 - mse: 0.0195
# Epoch 42: val_accuracy improved from 0.97603 to 0.97657, saving model to unet-attention-4d.keras
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.9734 - loss: 0.0652 - mse: 0.0195 - val_accuracy: 0.9766 - val_loss: 0.0590 - val_mse: 0.0173
# Epoch 43/60
# 246/250 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9771 - loss: 0.0562 - mse: 0.0167
# Epoch 43: val_accuracy improved from 0.97657 to 0.97689, saving model to unet-attention-4d.keras
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.9772 - loss: 0.0560 - mse: 0.0166 - val_accuracy: 0.9769 - val_loss: 0.0589 - val_mse: 0.0171
# Epoch 44/60
# 246/250 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9784 - loss: 0.0531 - mse: 0.0157
# Epoch 44: val_accuracy improved from 0.97689 to 0.97697, saving model to unet-attention-4d.keras
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.9784 - loss: 0.0530 - mse: 0.0157 - val_accuracy: 0.9770 - val_loss: 0.0591 - val_mse: 0.0171
# Epoch 45/60
# 246/250 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9779 - loss: 0.0549 - mse: 0.0162
# Epoch 45: val_accuracy did not improve from 0.97697
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.9778 - loss: 0.0551 - mse: 0.0162 - val_accuracy: 0.9491 - val_loss: 0.1161 - val_mse: 0.0355
# Epoch 46/60
# 246/250 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9664 - loss: 0.0816 - mse: 0.0243
# Epoch 46: val_accuracy did not improve from 0.97697
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.9665 - loss: 0.0812 - mse: 0.0242 - val_accuracy: 0.9733 - val_loss: 0.0651 - val_mse: 0.0194
# Epoch 47/60
# 246/250 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9752 - loss: 0.0610 - mse: 0.0181
# Epoch 47: val_accuracy did not improve from 0.97697
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.9753 - loss: 0.0608 - mse: 0.0181 - val_accuracy: 0.9757 - val_loss: 0.0617 - val_mse: 0.0180
# Epoch 48/60
# 246/250 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9726 - loss: 0.0681 - mse: 0.0202
# Epoch 48: val_accuracy did not improve from 0.97697
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.9727 - loss: 0.0677 - mse: 0.0201 - val_accuracy: 0.9762 - val_loss: 0.0603 - val_mse: 0.0175
# Epoch 49/60
# 246/250 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9782 - loss: 0.0537 - mse: 0.0159
# Epoch 49: val_accuracy improved from 0.97697 to 0.97742, saving model to unet-attention-4d.keras
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.9782 - loss: 0.0536 - mse: 0.0159 - val_accuracy: 0.9774 - val_loss: 0.0584 - val_mse: 0.0168
# Epoch 50/60
# 246/250 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9796 - loss: 0.0501 - mse: 0.0148
# Epoch 50: val_accuracy improved from 0.97742 to 0.97797, saving model to unet-attention-4d.keras
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 0.9796 - loss: 0.0500 - mse: 0.0148 - val_accuracy: 0.9780 - val_loss: 0.0580 - val_mse: 0.0165
# Epoch 51/60
# 246/250 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9804 - loss: 0.0480 - mse: 0.0142
# Epoch 51: val_accuracy did not improve from 0.97797
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.9805 - loss: 0.0478 - mse: 0.0142 - val_accuracy: 0.9779 - val_loss: 0.0591 - val_mse: 0.0167
# Epoch 52/60
# 246/250 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9774 - loss: 0.0554 - mse: 0.0165
# Epoch 52: val_accuracy did not improve from 0.97797
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.9775 - loss: 0.0552 - mse: 0.0164 - val_accuracy: 0.9770 - val_loss: 0.0601 - val_mse: 0.0172
# Epoch 53/60
# 246/250 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9781 - loss: 0.0537 - mse: 0.0159
# Epoch 53: val_accuracy improved from 0.97797 to 0.97847, saving model to unet-attention-4d.keras
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.9782 - loss: 0.0535 - mse: 0.0159 - val_accuracy: 0.9785 - val_loss: 0.0573 - val_mse: 0.0162
# Epoch 54/60
# 246/250 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9695 - loss: 0.0773 - mse: 0.0225
# Epoch 54: val_accuracy did not improve from 0.97847
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.9697 - loss: 0.0768 - mse: 0.0224 - val_accuracy: 0.9728 - val_loss: 0.0691 - val_mse: 0.0202
# Epoch 55/60
# 246/250 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9771 - loss: 0.0566 - mse: 0.0167
# Epoch 55: val_accuracy did not improve from 0.97847
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.9771 - loss: 0.0566 - mse: 0.0167 - val_accuracy: 0.9355 - val_loss: 0.1565 - val_mse: 0.0470
# Epoch 56/60
# 246/250 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9735 - loss: 0.0667 - mse: 0.0195
# Epoch 56: val_accuracy did not improve from 0.97847
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.9736 - loss: 0.0663 - mse: 0.0194 - val_accuracy: 0.9724 - val_loss: 0.0724 - val_mse: 0.0207
# Epoch 57/60
# 246/250 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9798 - loss: 0.0494 - mse: 0.0146
# Epoch 57: val_accuracy did not improve from 0.97847
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.9799 - loss: 0.0492 - mse: 0.0146 - val_accuracy: 0.9769 - val_loss: 0.0618 - val_mse: 0.0174
# Epoch 58/60
# 246/250 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9816 - loss: 0.0450 - mse: 0.0134
# Epoch 58: val_accuracy did not improve from 0.97847
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.9816 - loss: 0.0449 - mse: 0.0134 - val_accuracy: 0.9778 - val_loss: 0.0604 - val_mse: 0.0168
# Epoch 59/60
# 246/250 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9812 - loss: 0.0455 - mse: 0.0136
# Epoch 59: val_accuracy did not improve from 0.97847
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.9812 - loss: 0.0453 - mse: 0.0136 - val_accuracy: 0.9769 - val_loss: 0.0638 - val_mse: 0.0176
# Epoch 60/60
# 246/250 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9814 - loss: 0.0450 - mse: 0.0135
# Epoch 60: val_accuracy did not improve from 0.97847
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.9814 - loss: 0.0449 - mse: 0.0134 - val_accuracy: 0.9775 - val_loss: 0.0636 - val_mse: 0.0172

# %%
# Save model history
np.save('unet-attention-4d-history.npy',model_attention_unet_4band.history.history)

# %%
# Copy models to drive
# !cp unet-attention-4d.keras drive/MyDrive/Diss/
# !cp unet-attention-4d-history.npy drive/MyDrive/Diss/

# %% [markdown]
# ### ResNet50-SegNet

# %%
R_4band = ResNet50SegNet(input_size=(512,512,4))
save_model_resnet_4band = ModelCheckpoint('resnet50segnet-4d.weights.h5', monitor='val_accuracy',verbose=1, save_best_only=True, save_weights_only=True)
R_4band.fit(train_df_4band_amazon, validation_data = validation_df_4band_amazon, epochs = 20, callbacks=[save_model_resnet_4band])
# Out:
# Epoch 1/20
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - accuracy: 0.6576 - loss: 0.8354 - mse: 0.2189
# Epoch 1: val_accuracy improved from -inf to 0.92081, saving model to resnet50segnet-4d.weights.h5
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 49s 159ms/step - accuracy: 0.6580 - loss: 0.8342 - mse: 0.2186 - val_accuracy: 0.9208 - val_loss: 0.2137 - val_mse: 0.0614
# Epoch 2/20
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - accuracy: 0.9098 - loss: 0.2422 - mse: 0.0707
# Epoch 2: val_accuracy improved from 0.92081 to 0.94631, saving model to resnet50segnet-4d.weights.h5
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 39s 156ms/step - accuracy: 0.9098 - loss: 0.2421 - mse: 0.0706 - val_accuracy: 0.9463 - val_loss: 0.1507 - val_mse: 0.0423
# Epoch 3/20
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step - accuracy: 0.9286 - loss: 0.1859 - mse: 0.0542
# Epoch 3: val_accuracy improved from 0.94631 to 0.94801, saving model to resnet50segnet-4d.weights.h5
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 40s 158ms/step - accuracy: 0.9286 - loss: 0.1858 - mse: 0.0541 - val_accuracy: 0.9480 - val_loss: 0.1306 - val_mse: 0.0384
# Epoch 4/20
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - accuracy: 0.9256 - loss: 0.1923 - mse: 0.0561
# Epoch 4: val_accuracy did not improve from 0.94801
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 37s 150ms/step - accuracy: 0.9257 - loss: 0.1922 - mse: 0.0561 - val_accuracy: 0.9261 - val_loss: 0.1831 - val_mse: 0.0544
# Epoch 5/20
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - accuracy: 0.9352 - loss: 0.1614 - mse: 0.0476
# Epoch 5: val_accuracy improved from 0.94801 to 0.95400, saving model to resnet50segnet-4d.weights.h5
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 39s 156ms/step - accuracy: 0.9352 - loss: 0.1614 - mse: 0.0476 - val_accuracy: 0.9540 - val_loss: 0.1258 - val_mse: 0.0353
# Epoch 6/20
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - accuracy: 0.9391 - loss: 0.1509 - mse: 0.0446
# Epoch 6: val_accuracy did not improve from 0.95400
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 38s 150ms/step - accuracy: 0.9391 - loss: 0.1508 - mse: 0.0446 - val_accuracy: 0.9524 - val_loss: 0.1213 - val_mse: 0.0351
# Epoch 7/20
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - accuracy: 0.9426 - loss: 0.1444 - mse: 0.0424
# Epoch 7: val_accuracy did not improve from 0.95400
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 37s 149ms/step - accuracy: 0.9426 - loss: 0.1443 - mse: 0.0424 - val_accuracy: 0.9434 - val_loss: 0.1514 - val_mse: 0.0430
# Epoch 8/20
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - accuracy: 0.9468 - loss: 0.1365 - mse: 0.0398
# Epoch 8: val_accuracy did not improve from 0.95400
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 37s 149ms/step - accuracy: 0.9468 - loss: 0.1364 - mse: 0.0398 - val_accuracy: 0.9270 - val_loss: 0.1949 - val_mse: 0.0561
# Epoch 9/20
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - accuracy: 0.9486 - loss: 0.1320 - mse: 0.0383
# Epoch 9: val_accuracy did not improve from 0.95400
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 37s 150ms/step - accuracy: 0.9487 - loss: 0.1319 - mse: 0.0383 - val_accuracy: 0.9486 - val_loss: 0.1369 - val_mse: 0.0390
# Epoch 10/20
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - accuracy: 0.9476 - loss: 0.1337 - mse: 0.0390
# Epoch 10: val_accuracy improved from 0.95400 to 0.95605, saving model to resnet50segnet-4d.weights.h5
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 39s 156ms/step - accuracy: 0.9477 - loss: 0.1337 - mse: 0.0390 - val_accuracy: 0.9561 - val_loss: 0.1202 - val_mse: 0.0341
# Epoch 11/20
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - accuracy: 0.9491 - loss: 0.1301 - mse: 0.0381
# Epoch 11: val_accuracy did not improve from 0.95605
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 37s 149ms/step - accuracy: 0.9491 - loss: 0.1300 - mse: 0.0380 - val_accuracy: 0.9291 - val_loss: 0.1754 - val_mse: 0.0521
# Epoch 12/20
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - accuracy: 0.9541 - loss: 0.1166 - mse: 0.0341
# Epoch 12: val_accuracy improved from 0.95605 to 0.96271, saving model to resnet50segnet-4d.weights.h5
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 39s 156ms/step - accuracy: 0.9541 - loss: 0.1165 - mse: 0.0341 - val_accuracy: 0.9627 - val_loss: 0.1050 - val_mse: 0.0290
# Epoch 13/20
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - accuracy: 0.9525 - loss: 0.1219 - mse: 0.0354
# Epoch 13: val_accuracy did not improve from 0.96271
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 37s 149ms/step - accuracy: 0.9525 - loss: 0.1219 - mse: 0.0354 - val_accuracy: 0.9548 - val_loss: 0.1199 - val_mse: 0.0341
# Epoch 14/20
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - accuracy: 0.9554 - loss: 0.1142 - mse: 0.0331
# Epoch 14: val_accuracy did not improve from 0.96271
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 37s 149ms/step - accuracy: 0.9554 - loss: 0.1142 - mse: 0.0331 - val_accuracy: 0.9258 - val_loss: 0.1824 - val_mse: 0.0544
# Epoch 15/20
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - accuracy: 0.9492 - loss: 0.1352 - mse: 0.0383
# Epoch 15: val_accuracy did not improve from 0.96271
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 37s 149ms/step - accuracy: 0.9492 - loss: 0.1352 - mse: 0.0383 - val_accuracy: 0.8956 - val_loss: 0.2293 - val_mse: 0.0716
# Epoch 16/20
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - accuracy: 0.9482 - loss: 0.1267 - mse: 0.0378
# Epoch 16: val_accuracy did not improve from 0.96271
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 38s 152ms/step - accuracy: 0.9482 - loss: 0.1266 - mse: 0.0377 - val_accuracy: 0.8797 - val_loss: 0.2609 - val_mse: 0.0823
# Epoch 17/20
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - accuracy: 0.9526 - loss: 0.1144 - mse: 0.0342
# Epoch 17: val_accuracy did not improve from 0.96271
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 39s 156ms/step - accuracy: 0.9526 - loss: 0.1144 - mse: 0.0342 - val_accuracy: 0.9488 - val_loss: 0.1699 - val_mse: 0.0459
# Epoch 18/20
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - accuracy: 0.9533 - loss: 0.1207 - mse: 0.0354
# Epoch 18: val_accuracy improved from 0.96271 to 0.96425, saving model to resnet50segnet-4d.weights.h5
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 40s 160ms/step - accuracy: 0.9533 - loss: 0.1206 - mse: 0.0354 - val_accuracy: 0.9643 - val_loss: 0.1115 - val_mse: 0.0292
# Epoch 19/20
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - accuracy: 0.9525 - loss: 0.1225 - mse: 0.0354
# Epoch 19: val_accuracy did not improve from 0.96425
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 38s 153ms/step - accuracy: 0.9526 - loss: 0.1224 - mse: 0.0354 - val_accuracy: 0.9614 - val_loss: 0.0979 - val_mse: 0.0283
# Epoch 20/20
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - accuracy: 0.9539 - loss: 0.1142 - mse: 0.0338
# Epoch 20: val_accuracy improved from 0.96425 to 0.96894, saving model to resnet50segnet-4d.weights.h5
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 40s 161ms/step - accuracy: 0.9540 - loss: 0.1141 - mse: 0.0338 - val_accuracy: 0.9689 - val_loss: 0.0837 - val_mse: 0.0235

# %%
# Save model history
np.save('resnet50segnet-4d-history.npy', R_4band.history.history)

# %%
# Copy models to drive
# !cp resnet50segnet-4d.keras drive/MyDrive/Diss/models/
# !cp resnet50segnet-4d-history.npy drive/MyDrive/Diss/models/
# Out:
# cp: cannot stat 'resnet50segnet-4d.keras': No such file or directory
# cp: cannot create regular file 'drive/MyDrive/Diss/models/': Not a directory

# %% [markdown]
# ### FCN32-VGG16

# %%
F_4band = fcn_32(input_size=(512,512,4), lr = 0.0001)
save_model_fcn_4band = ModelCheckpoint('fcn32-4d.keras', monitor='val_accuracy',verbose=1, save_best_only=True)
F_4band.fit(train_df_4band_amazon, validation_data = validation_df_4band_amazon, epochs = 50, callbacks=[save_model_fcn_4band])
# Out:
# Epoch 1/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.5123 - loss: 0.6931 - mse: 0.2500
# Epoch 1: val_accuracy improved from -inf to 0.52137, saving model to fcn32-4d.keras
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 50s 167ms/step - accuracy: 0.5124 - loss: 0.6931 - mse: 0.2500 - val_accuracy: 0.5214 - val_loss: 0.6930 - val_mse: 0.2499
# Epoch 2/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.5226 - loss: 0.6930 - mse: 0.2499
# Epoch 2: val_accuracy did not improve from 0.52137
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 35s 142ms/step - accuracy: 0.5226 - loss: 0.6930 - mse: 0.2499 - val_accuracy: 0.5181 - val_loss: 0.6927 - val_mse: 0.2498
# Epoch 3/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.5246 - loss: 0.6929 - mse: 0.2499
# Epoch 3: val_accuracy did not improve from 0.52137
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 35s 142ms/step - accuracy: 0.5247 - loss: 0.6929 - mse: 0.2499 - val_accuracy: 0.5197 - val_loss: 0.6925 - val_mse: 0.2497
# Epoch 4/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.5233 - loss: 0.6932 - mse: 0.2500
# Epoch 4: val_accuracy improved from 0.52137 to 0.52145, saving model to fcn32-4d.keras
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 41s 166ms/step - accuracy: 0.5233 - loss: 0.6932 - mse: 0.2500 - val_accuracy: 0.5215 - val_loss: 0.6927 - val_mse: 0.2498
# Epoch 5/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.5226 - loss: 0.6936 - mse: 0.2502
# Epoch 5: val_accuracy improved from 0.52145 to 0.52173, saving model to fcn32-4d.keras
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 41s 166ms/step - accuracy: 0.5227 - loss: 0.6936 - mse: 0.2502 - val_accuracy: 0.5217 - val_loss: 0.6928 - val_mse: 0.2498
# Epoch 6/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.5215 - loss: 0.7026 - mse: 0.2534
# Epoch 6: val_accuracy improved from 0.52173 to 0.52189, saving model to fcn32-4d.keras
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 41s 165ms/step - accuracy: 0.5216 - loss: 0.7025 - mse: 0.2534 - val_accuracy: 0.5219 - val_loss: 0.6925 - val_mse: 0.2497
# Epoch 7/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.5190 - loss: 0.6909 - mse: 0.2485
# Epoch 7: val_accuracy improved from 0.52189 to 0.75131, saving model to fcn32-4d.keras
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 41s 165ms/step - accuracy: 0.5193 - loss: 0.6908 - mse: 0.2484 - val_accuracy: 0.7513 - val_loss: 0.6740 - val_mse: 0.2404
# Epoch 8/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.6715 - loss: 0.5938 - mse: 0.2047
# Epoch 8: val_accuracy improved from 0.75131 to 0.82788, saving model to fcn32-4d.keras
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 41s 166ms/step - accuracy: 0.6719 - loss: 0.5935 - mse: 0.2046 - val_accuracy: 0.8279 - val_loss: 0.4363 - val_mse: 0.1366
# Epoch 9/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.8216 - loss: 0.4246 - mse: 0.1341
# Epoch 9: val_accuracy improved from 0.82788 to 0.86008, saving model to fcn32-4d.keras
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 41s 165ms/step - accuracy: 0.8217 - loss: 0.4245 - mse: 0.1341 - val_accuracy: 0.8601 - val_loss: 0.3466 - val_mse: 0.1052
# Epoch 10/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.8458 - loss: 0.3771 - mse: 0.1159
# Epoch 10: val_accuracy improved from 0.86008 to 0.87607, saving model to fcn32-4d.keras
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 43s 173ms/step - accuracy: 0.8459 - loss: 0.3769 - mse: 0.1159 - val_accuracy: 0.8761 - val_loss: 0.3056 - val_mse: 0.0923
# Epoch 11/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.8680 - loss: 0.3227 - mse: 0.0981
# Epoch 11: val_accuracy did not improve from 0.87607
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 35s 142ms/step - accuracy: 0.8680 - loss: 0.3226 - mse: 0.0981 - val_accuracy: 0.8593 - val_loss: 0.3156 - val_mse: 0.0986
# Epoch 12/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.8663 - loss: 0.3118 - mse: 0.0959
# Epoch 12: val_accuracy did not improve from 0.87607
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 35s 142ms/step - accuracy: 0.8664 - loss: 0.3116 - mse: 0.0958 - val_accuracy: 0.8090 - val_loss: 0.4046 - val_mse: 0.1303
# Epoch 13/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.8654 - loss: 0.3157 - mse: 0.0968
# Epoch 13: val_accuracy improved from 0.87607 to 0.88946, saving model to fcn32-4d.keras
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 43s 172ms/step - accuracy: 0.8655 - loss: 0.3155 - mse: 0.0967 - val_accuracy: 0.8895 - val_loss: 0.2652 - val_mse: 0.0804
# Epoch 14/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.8830 - loss: 0.2780 - mse: 0.0846
# Epoch 14: val_accuracy did not improve from 0.88946
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 35s 142ms/step - accuracy: 0.8831 - loss: 0.2778 - mse: 0.0845 - val_accuracy: 0.8747 - val_loss: 0.2907 - val_mse: 0.0894
# Epoch 15/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.8811 - loss: 0.2786 - mse: 0.0851
# Epoch 15: val_accuracy did not improve from 0.88946
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 35s 142ms/step - accuracy: 0.8811 - loss: 0.2784 - mse: 0.0851 - val_accuracy: 0.8893 - val_loss: 0.2654 - val_mse: 0.0801
# Epoch 16/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.8879 - loss: 0.2662 - mse: 0.0809
# Epoch 16: val_accuracy improved from 0.88946 to 0.89064, saving model to fcn32-4d.keras
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 43s 173ms/step - accuracy: 0.8879 - loss: 0.2661 - mse: 0.0808 - val_accuracy: 0.8906 - val_loss: 0.2614 - val_mse: 0.0790
# Epoch 17/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.8918 - loss: 0.2568 - mse: 0.0779
# Epoch 17: val_accuracy did not improve from 0.89064
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 35s 142ms/step - accuracy: 0.8919 - loss: 0.2567 - mse: 0.0779 - val_accuracy: 0.8709 - val_loss: 0.3033 - val_mse: 0.0928
# Epoch 18/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.8836 - loss: 0.2757 - mse: 0.0838
# Epoch 18: val_accuracy improved from 0.89064 to 0.89507, saving model to fcn32-4d.keras
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 41s 165ms/step - accuracy: 0.8837 - loss: 0.2755 - mse: 0.0838 - val_accuracy: 0.8951 - val_loss: 0.2554 - val_mse: 0.0764
# Epoch 19/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.8995 - loss: 0.2452 - mse: 0.0738
# Epoch 19: val_accuracy improved from 0.89507 to 0.89722, saving model to fcn32-4d.keras
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 43s 173ms/step - accuracy: 0.8996 - loss: 0.2451 - mse: 0.0738 - val_accuracy: 0.8972 - val_loss: 0.2469 - val_mse: 0.0744
# Epoch 20/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.9026 - loss: 0.2364 - mse: 0.0712
# Epoch 20: val_accuracy did not improve from 0.89722
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 35s 142ms/step - accuracy: 0.9027 - loss: 0.2364 - mse: 0.0712 - val_accuracy: 0.8953 - val_loss: 0.2518 - val_mse: 0.0758
# Epoch 21/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.9037 - loss: 0.2337 - mse: 0.0704
# Epoch 21: val_accuracy did not improve from 0.89722
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 35s 142ms/step - accuracy: 0.9037 - loss: 0.2336 - mse: 0.0703 - val_accuracy: 0.8970 - val_loss: 0.2470 - val_mse: 0.0745
# Epoch 22/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.9058 - loss: 0.2286 - mse: 0.0688
# Epoch 22: val_accuracy did not improve from 0.89722
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 35s 142ms/step - accuracy: 0.9058 - loss: 0.2285 - mse: 0.0688 - val_accuracy: 0.7964 - val_loss: 0.4021 - val_mse: 0.1270
# Epoch 23/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.8951 - loss: 0.2553 - mse: 0.0768
# Epoch 23: val_accuracy did not improve from 0.89722
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 35s 142ms/step - accuracy: 0.8951 - loss: 0.2552 - mse: 0.0768 - val_accuracy: 0.8933 - val_loss: 0.2627 - val_mse: 0.0780
# Epoch 24/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.9071 - loss: 0.2295 - mse: 0.0684
# Epoch 24: val_accuracy did not improve from 0.89722
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 35s 142ms/step - accuracy: 0.9071 - loss: 0.2294 - mse: 0.0684 - val_accuracy: 0.8922 - val_loss: 0.2620 - val_mse: 0.0784
# Epoch 25/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.9100 - loss: 0.2198 - mse: 0.0658
# Epoch 25: val_accuracy did not improve from 0.89722
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 35s 142ms/step - accuracy: 0.9101 - loss: 0.2197 - mse: 0.0658 - val_accuracy: 0.8962 - val_loss: 0.2516 - val_mse: 0.0753
# Epoch 26/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.9120 - loss: 0.2145 - mse: 0.0643
# Epoch 26: val_accuracy did not improve from 0.89722
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 35s 142ms/step - accuracy: 0.9120 - loss: 0.2144 - mse: 0.0643 - val_accuracy: 0.8963 - val_loss: 0.2512 - val_mse: 0.0751
# Epoch 27/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.9137 - loss: 0.2108 - mse: 0.0631
# Epoch 27: val_accuracy did not improve from 0.89722
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 35s 142ms/step - accuracy: 0.9137 - loss: 0.2108 - mse: 0.0631 - val_accuracy: 0.8872 - val_loss: 0.2813 - val_mse: 0.0828
# Epoch 28/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.9138 - loss: 0.2118 - mse: 0.0631
# Epoch 28: val_accuracy improved from 0.89722 to 0.90673, saving model to fcn32-4d.keras
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 44s 175ms/step - accuracy: 0.9139 - loss: 0.2117 - mse: 0.0631 - val_accuracy: 0.9067 - val_loss: 0.2277 - val_mse: 0.0677
# Epoch 29/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.9118 - loss: 0.2168 - mse: 0.0648
# Epoch 29: val_accuracy improved from 0.90673 to 0.91366, saving model to fcn32-4d.keras
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 41s 165ms/step - accuracy: 0.9119 - loss: 0.2168 - mse: 0.0648 - val_accuracy: 0.9137 - val_loss: 0.2155 - val_mse: 0.0633
# Epoch 30/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.9123 - loss: 0.2186 - mse: 0.0649
# Epoch 30: val_accuracy improved from 0.91366 to 0.91446, saving model to fcn32-4d.keras
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 41s 165ms/step - accuracy: 0.9124 - loss: 0.2185 - mse: 0.0649 - val_accuracy: 0.9145 - val_loss: 0.2117 - val_mse: 0.0625
# Epoch 31/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.9125 - loss: 0.2178 - mse: 0.0646
# Epoch 31: val_accuracy improved from 0.91446 to 0.91471, saving model to fcn32-4d.keras
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 41s 165ms/step - accuracy: 0.9126 - loss: 0.2177 - mse: 0.0646 - val_accuracy: 0.9147 - val_loss: 0.2078 - val_mse: 0.0621
# Epoch 32/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.9125 - loss: 0.2168 - mse: 0.0644
# Epoch 32: val_accuracy did not improve from 0.91471
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 35s 142ms/step - accuracy: 0.9125 - loss: 0.2168 - mse: 0.0644 - val_accuracy: 0.9147 - val_loss: 0.2060 - val_mse: 0.0620
# Epoch 33/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.9049 - loss: 0.2319 - mse: 0.0698
# Epoch 33: val_accuracy improved from 0.91471 to 0.91621, saving model to fcn32-4d.keras
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 43s 172ms/step - accuracy: 0.9049 - loss: 0.2318 - mse: 0.0698 - val_accuracy: 0.9162 - val_loss: 0.2048 - val_mse: 0.0614
# Epoch 34/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.9047 - loss: 0.2295 - mse: 0.0694
# Epoch 34: val_accuracy did not improve from 0.91621
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 35s 142ms/step - accuracy: 0.9047 - loss: 0.2294 - mse: 0.0694 - val_accuracy: 0.9141 - val_loss: 0.2138 - val_mse: 0.0634
# Epoch 35/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.9051 - loss: 0.2306 - mse: 0.0694
# Epoch 35: val_accuracy did not improve from 0.91621
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 35s 142ms/step - accuracy: 0.9051 - loss: 0.2305 - mse: 0.0694 - val_accuracy: 0.9161 - val_loss: 0.2071 - val_mse: 0.0615
# Epoch 36/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.9085 - loss: 0.2268 - mse: 0.0675
# Epoch 36: val_accuracy did not improve from 0.91621
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 35s 142ms/step - accuracy: 0.9086 - loss: 0.2267 - mse: 0.0674 - val_accuracy: 0.9144 - val_loss: 0.2106 - val_mse: 0.0626
# Epoch 37/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.9132 - loss: 0.2196 - mse: 0.0648
# Epoch 37: val_accuracy did not improve from 0.91621
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 35s 142ms/step - accuracy: 0.9132 - loss: 0.2195 - mse: 0.0648 - val_accuracy: 0.9152 - val_loss: 0.2073 - val_mse: 0.0620
# Epoch 38/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.9143 - loss: 0.2156 - mse: 0.0637
# Epoch 38: val_accuracy did not improve from 0.91621
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 35s 142ms/step - accuracy: 0.9144 - loss: 0.2155 - mse: 0.0637 - val_accuracy: 0.9144 - val_loss: 0.2097 - val_mse: 0.0626
# Epoch 39/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.9174 - loss: 0.2043 - mse: 0.0608
# Epoch 39: val_accuracy did not improve from 0.91621
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 35s 142ms/step - accuracy: 0.9174 - loss: 0.2042 - mse: 0.0608 - val_accuracy: 0.9149 - val_loss: 0.2075 - val_mse: 0.0622
# Epoch 40/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.9197 - loss: 0.1964 - mse: 0.0587
# Epoch 40: val_accuracy did not improve from 0.91621
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 35s 142ms/step - accuracy: 0.9197 - loss: 0.1963 - mse: 0.0587 - val_accuracy: 0.9148 - val_loss: 0.2128 - val_mse: 0.0627
# Epoch 41/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.9196 - loss: 0.1967 - mse: 0.0588
# Epoch 41: val_accuracy did not improve from 0.91621
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 35s 142ms/step - accuracy: 0.9196 - loss: 0.1967 - mse: 0.0587 - val_accuracy: 0.9116 - val_loss: 0.2136 - val_mse: 0.0641
# Epoch 42/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.9186 - loss: 0.1962 - mse: 0.0590
# Epoch 42: val_accuracy improved from 0.91621 to 0.91669, saving model to fcn32-4d.keras
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 44s 175ms/step - accuracy: 0.9186 - loss: 0.1962 - mse: 0.0590 - val_accuracy: 0.9167 - val_loss: 0.2048 - val_mse: 0.0609
# Epoch 43/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.9217 - loss: 0.1884 - mse: 0.0568
# Epoch 43: val_accuracy did not improve from 0.91669
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 35s 142ms/step - accuracy: 0.9217 - loss: 0.1883 - mse: 0.0568 - val_accuracy: 0.9157 - val_loss: 0.2121 - val_mse: 0.0620
# Epoch 44/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.9222 - loss: 0.1866 - mse: 0.0563
# Epoch 44: val_accuracy improved from 0.91669 to 0.91674, saving model to fcn32-4d.keras
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 41s 166ms/step - accuracy: 0.9222 - loss: 0.1865 - mse: 0.0563 - val_accuracy: 0.9167 - val_loss: 0.2134 - val_mse: 0.0616
# Epoch 45/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.9223 - loss: 0.1864 - mse: 0.0563
# Epoch 45: val_accuracy did not improve from 0.91674
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 35s 142ms/step - accuracy: 0.9223 - loss: 0.1863 - mse: 0.0563 - val_accuracy: 0.9166 - val_loss: 0.2158 - val_mse: 0.0618
# Epoch 46/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.9221 - loss: 0.1864 - mse: 0.0563
# Epoch 46: val_accuracy did not improve from 0.91674
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 35s 142ms/step - accuracy: 0.9221 - loss: 0.1863 - mse: 0.0563 - val_accuracy: 0.9167 - val_loss: 0.2198 - val_mse: 0.0620
# Epoch 47/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.9216 - loss: 0.1880 - mse: 0.0568
# Epoch 47: val_accuracy did not improve from 0.91674
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 35s 142ms/step - accuracy: 0.9216 - loss: 0.1879 - mse: 0.0568 - val_accuracy: 0.9131 - val_loss: 0.2315 - val_mse: 0.0648
# Epoch 48/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.9174 - loss: 0.2003 - mse: 0.0601
# Epoch 48: val_accuracy did not improve from 0.91674
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 35s 142ms/step - accuracy: 0.9174 - loss: 0.2002 - mse: 0.0600 - val_accuracy: 0.9105 - val_loss: 0.2295 - val_mse: 0.0660
# Epoch 49/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.9185 - loss: 0.1963 - mse: 0.0592
# Epoch 49: val_accuracy did not improve from 0.91674
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 35s 142ms/step - accuracy: 0.9185 - loss: 0.1962 - mse: 0.0591 - val_accuracy: 0.9118 - val_loss: 0.2343 - val_mse: 0.0657
# Epoch 50/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.9224 - loss: 0.1848 - mse: 0.0560
# Epoch 50: val_accuracy did not improve from 0.91674
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 35s 142ms/step - accuracy: 0.9224 - loss: 0.1848 - mse: 0.0560 - val_accuracy: 0.9064 - val_loss: 0.2560 - val_mse: 0.0703

# %%
# Save model history
np.save('fcn32-4d-history.npy', F_4band.history.history)

# %%
# Copy models to drive
# !cp fcn32-4d.hdf5 drive/MyDrive/Diss/
# !cp fcn32-4d-history.npy drive/MyDrive/Diss/
# Out:
# cp: cannot stat 'fcn32-4d.hdf5': No such file or directory

# %% [markdown]
# ### ResUNet

# %%
R_4band = res_unet(512, [64, 128, 256, 512], 3, 4, 1)
save_model_resunet_4band = ModelCheckpoint('resunet-4d.weights.h5', monitor='val_accuracy',verbose=1, save_best_only=True, save_weights_only=True)
R_4band.fit(train_df_4band_amazon, validation_data = validation_df_4band_amazon, epochs = 20, callbacks=[save_model_resunet_4band])
# Out:
# Epoch 1/20
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.7520 - loss: 9.2989 - mse: 0.2322
# Epoch 1: val_accuracy improved from -inf to 0.91618, saving model to resunet-4d.weights.h5
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 31s 64ms/step - accuracy: 0.7524 - loss: 9.2721 - mse: 0.2318 - val_accuracy: 0.9162 - val_loss: 0.2092 - val_mse: 0.0622
# Epoch 2/20
# 249/250 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.9176 - loss: 0.2162 - mse: 0.0619
# Epoch 2: val_accuracy did not improve from 0.91618
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 13s 54ms/step - accuracy: 0.9176 - loss: 0.2160 - mse: 0.0619 - val_accuracy: 0.9077 - val_loss: 0.2348 - val_mse: 0.0692
# Epoch 3/20
# 249/250 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.9318 - loss: 0.1823 - mse: 0.0518
# Epoch 3: val_accuracy did not improve from 0.91618
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 13s 54ms/step - accuracy: 0.9318 - loss: 0.1822 - mse: 0.0518 - val_accuracy: 0.8964 - val_loss: 0.2636 - val_mse: 0.0783
# Epoch 4/20
# 249/250 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.9359 - loss: 0.1738 - mse: 0.0490
# Epoch 4: val_accuracy improved from 0.91618 to 0.92975, saving model to resunet-4d.weights.h5
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 14s 57ms/step - accuracy: 0.9359 - loss: 0.1737 - mse: 0.0490 - val_accuracy: 0.9297 - val_loss: 0.1790 - val_mse: 0.0524
# Epoch 5/20
# 249/250 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.9426 - loss: 0.1528 - mse: 0.0433
# Epoch 5: val_accuracy improved from 0.92975 to 0.94473, saving model to resunet-4d.weights.h5
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 14s 57ms/step - accuracy: 0.9427 - loss: 0.1528 - mse: 0.0433 - val_accuracy: 0.9447 - val_loss: 0.1400 - val_mse: 0.0409
# Epoch 6/20
# 249/250 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.9469 - loss: 0.1384 - mse: 0.0398
# Epoch 6: val_accuracy improved from 0.94473 to 0.94585, saving model to resunet-4d.weights.h5
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 14s 57ms/step - accuracy: 0.9469 - loss: 0.1383 - mse: 0.0397 - val_accuracy: 0.9459 - val_loss: 0.1374 - val_mse: 0.0401
# Epoch 7/20
# 249/250 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.9482 - loss: 0.1367 - mse: 0.0389
# Epoch 7: val_accuracy did not improve from 0.94585
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 13s 54ms/step - accuracy: 0.9483 - loss: 0.1366 - mse: 0.0389 - val_accuracy: 0.9211 - val_loss: 0.2077 - val_mse: 0.0600
# Epoch 8/20
# 249/250 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.9487 - loss: 0.1360 - mse: 0.0387
# Epoch 8: val_accuracy did not improve from 0.94585
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 13s 54ms/step - accuracy: 0.9488 - loss: 0.1359 - mse: 0.0387 - val_accuracy: 0.9459 - val_loss: 0.1378 - val_mse: 0.0401
# Epoch 9/20
# 249/250 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.9493 - loss: 0.1305 - mse: 0.0377
# Epoch 9: val_accuracy did not improve from 0.94585
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 13s 54ms/step - accuracy: 0.9494 - loss: 0.1304 - mse: 0.0377 - val_accuracy: 0.9113 - val_loss: 0.2403 - val_mse: 0.0682
# Epoch 10/20
# 249/250 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.9532 - loss: 0.1237 - mse: 0.0352
# Epoch 10: val_accuracy improved from 0.94585 to 0.95665, saving model to resunet-4d.weights.h5
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 14s 57ms/step - accuracy: 0.9532 - loss: 0.1236 - mse: 0.0352 - val_accuracy: 0.9567 - val_loss: 0.1095 - val_mse: 0.0320
# Epoch 11/20
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.9484 - loss: 0.1256 - mse: 0.0373
# Epoch 11: val_accuracy did not improve from 0.95665
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 13s 54ms/step - accuracy: 0.9484 - loss: 0.1255 - mse: 0.0373 - val_accuracy: 0.9555 - val_loss: 0.1129 - val_mse: 0.0329
# Epoch 12/20
# 249/250 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.9511 - loss: 0.1215 - mse: 0.0357
# Epoch 12: val_accuracy did not improve from 0.95665
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 13s 54ms/step - accuracy: 0.9511 - loss: 0.1213 - mse: 0.0356 - val_accuracy: 0.9163 - val_loss: 0.2227 - val_mse: 0.0639
# Epoch 13/20
# 249/250 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.9545 - loss: 0.1169 - mse: 0.0338
# Epoch 13: val_accuracy did not improve from 0.95665
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 13s 54ms/step - accuracy: 0.9546 - loss: 0.1168 - mse: 0.0338 - val_accuracy: 0.9488 - val_loss: 0.1287 - val_mse: 0.0378
# Epoch 14/20
# 249/250 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.9535 - loss: 0.1139 - mse: 0.0338
# Epoch 14: val_accuracy improved from 0.95665 to 0.95805, saving model to resunet-4d.weights.h5
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 14s 56ms/step - accuracy: 0.9535 - loss: 0.1138 - mse: 0.0337 - val_accuracy: 0.9581 - val_loss: 0.1048 - val_mse: 0.0307
# Epoch 15/20
# 249/250 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.9532 - loss: 0.1147 - mse: 0.0339
# Epoch 15: val_accuracy did not improve from 0.95805
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 13s 54ms/step - accuracy: 0.9533 - loss: 0.1145 - mse: 0.0339 - val_accuracy: 0.9332 - val_loss: 0.1686 - val_mse: 0.0496
# Epoch 16/20
# 249/250 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.9581 - loss: 0.1050 - mse: 0.0308
# Epoch 16: val_accuracy did not improve from 0.95805
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 13s 54ms/step - accuracy: 0.9582 - loss: 0.1049 - mse: 0.0308 - val_accuracy: 0.9239 - val_loss: 0.2061 - val_mse: 0.0582
# Epoch 17/20
# 249/250 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.9591 - loss: 0.1052 - mse: 0.0304
# Epoch 17: val_accuracy did not improve from 0.95805
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 13s 54ms/step - accuracy: 0.9592 - loss: 0.1051 - mse: 0.0304 - val_accuracy: 0.9253 - val_loss: 0.1949 - val_mse: 0.0566
# Epoch 18/20
# 249/250 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.9582 - loss: 0.1060 - mse: 0.0310
# Epoch 18: val_accuracy did not improve from 0.95805
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 13s 54ms/step - accuracy: 0.9583 - loss: 0.1059 - mse: 0.0310 - val_accuracy: 0.9406 - val_loss: 0.1489 - val_mse: 0.0440
# Epoch 19/20
# 249/250 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.9581 - loss: 0.1048 - mse: 0.0308
# Epoch 19: val_accuracy did not improve from 0.95805
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 13s 54ms/step - accuracy: 0.9582 - loss: 0.1047 - mse: 0.0307 - val_accuracy: 0.9561 - val_loss: 0.1075 - val_mse: 0.0320
# Epoch 20/20
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.9584 - loss: 0.1009 - mse: 0.0301
# Epoch 20: val_accuracy did not improve from 0.95805
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 13s 54ms/step - accuracy: 0.9584 - loss: 0.1009 - mse: 0.0301 - val_accuracy: 0.9334 - val_loss: 0.1659 - val_mse: 0.0493

# %%
# Save model history
np.save('resunet-4d-history.npy', R_4band.history.history)

# %%
# Copy models to drive
# !cp resunet-4d.hdf5 drive/MyDrive/Diss/models/
# !cp resunet-4d-history.npy drive/MyDrive/Diss/models/
# Out:
# cp: cannot stat 'resunet-4d.hdf5': No such file or directory
# cp: cannot create regular file 'drive/MyDrive/Diss/models/': Not a directory

# %% [markdown]
# ## Train on 4-band Atlantic data

# %% [markdown]
# ### U-Net

# %%
# Train U-Net with generator
model_unet_4band_atlantic = UNet()
save_model_4band_atlantic = ModelCheckpoint('unet-4d-atlantic.keras', monitor='val_accuracy',verbose=1, save_best_only=True)
model_unet_4band_atlantic.fit(train_df_4band_atlantic, epochs = 20, validation_data = validation_df_4band_atlantic, callbacks=[save_model_4band_atlantic])
# Out:
# Epoch 1/20
# 249/250 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.7491 - loss: 0.4833 - mse: 0.1642
# Epoch 1: val_accuracy improved from -inf to 0.87000, saving model to unet-4d-atlantic.keras
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 21s 44ms/step - accuracy: 0.7495 - loss: 0.4827 - mse: 0.1639 - val_accuracy: 0.8700 - val_loss: 0.3174 - val_mse: 0.1005
# Epoch 2/20
# 249/250 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.8585 - loss: 0.3381 - mse: 0.1091
# Epoch 2: val_accuracy improved from 0.87000 to 0.88020, saving model to unet-4d-atlantic.keras
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 10s 40ms/step - accuracy: 0.8585 - loss: 0.3380 - mse: 0.1091 - val_accuracy: 0.8802 - val_loss: 0.2914 - val_mse: 0.0912
# Epoch 3/20
# 249/250 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.8671 - loss: 0.3070 - mse: 0.0978
# Epoch 3: val_accuracy improved from 0.88020 to 0.89296, saving model to unet-4d-atlantic.keras
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 10s 40ms/step - accuracy: 0.8671 - loss: 0.3069 - mse: 0.0978 - val_accuracy: 0.8930 - val_loss: 0.2665 - val_mse: 0.0822
# Epoch 4/20
# 249/250 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.8856 - loss: 0.2721 - mse: 0.0854
# Epoch 4: val_accuracy improved from 0.89296 to 0.89334, saving model to unet-4d-atlantic.keras
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 10s 40ms/step - accuracy: 0.8856 - loss: 0.2721 - mse: 0.0853 - val_accuracy: 0.8933 - val_loss: 0.2504 - val_mse: 0.0769
# Epoch 5/20
# 249/250 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.8947 - loss: 0.2486 - mse: 0.0769
# Epoch 5: val_accuracy improved from 0.89334 to 0.89641, saving model to unet-4d-atlantic.keras
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 10s 40ms/step - accuracy: 0.8947 - loss: 0.2486 - mse: 0.0769 - val_accuracy: 0.8964 - val_loss: 0.2471 - val_mse: 0.0755
# Epoch 6/20
# 249/250 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9023 - loss: 0.2313 - mse: 0.0710
# Epoch 6: val_accuracy improved from 0.89641 to 0.90600, saving model to unet-4d-atlantic.keras
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 10s 40ms/step - accuracy: 0.9023 - loss: 0.2313 - mse: 0.0710 - val_accuracy: 0.9060 - val_loss: 0.2239 - val_mse: 0.0680
# Epoch 7/20
# 249/250 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9105 - loss: 0.2170 - mse: 0.0658
# Epoch 7: val_accuracy improved from 0.90600 to 0.91036, saving model to unet-4d-atlantic.keras
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 10s 40ms/step - accuracy: 0.9104 - loss: 0.2170 - mse: 0.0658 - val_accuracy: 0.9104 - val_loss: 0.2151 - val_mse: 0.0651
# Epoch 8/20
# 249/250 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9153 - loss: 0.2074 - mse: 0.0626
# Epoch 8: val_accuracy improved from 0.91036 to 0.91716, saving model to unet-4d-atlantic.keras
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 10s 39ms/step - accuracy: 0.9153 - loss: 0.2075 - mse: 0.0626 - val_accuracy: 0.9172 - val_loss: 0.2009 - val_mse: 0.0604
# Epoch 9/20
# 249/250 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9181 - loss: 0.2013 - mse: 0.0605
# Epoch 9: val_accuracy improved from 0.91716 to 0.91979, saving model to unet-4d-atlantic.keras
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 10s 40ms/step - accuracy: 0.9181 - loss: 0.2013 - mse: 0.0605 - val_accuracy: 0.9198 - val_loss: 0.1941 - val_mse: 0.0583
# Epoch 10/20
# 249/250 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9218 - loss: 0.1924 - mse: 0.0577
# Epoch 10: val_accuracy improved from 0.91979 to 0.92486, saving model to unet-4d-atlantic.keras
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 10s 40ms/step - accuracy: 0.9218 - loss: 0.1925 - mse: 0.0577 - val_accuracy: 0.9249 - val_loss: 0.1826 - val_mse: 0.0547
# Epoch 11/20
# 249/250 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9245 - loss: 0.1860 - mse: 0.0557
# Epoch 11: val_accuracy did not improve from 0.92486
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 9s 34ms/step - accuracy: 0.9245 - loss: 0.1861 - mse: 0.0557 - val_accuracy: 0.9226 - val_loss: 0.1917 - val_mse: 0.0572
# Epoch 12/20
# 249/250 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9282 - loss: 0.1789 - mse: 0.0534
# Epoch 12: val_accuracy improved from 0.92486 to 0.92810, saving model to unet-4d-atlantic.keras
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 10s 40ms/step - accuracy: 0.9281 - loss: 0.1790 - mse: 0.0534 - val_accuracy: 0.9281 - val_loss: 0.1790 - val_mse: 0.0534
# Epoch 13/20
# 249/250 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9298 - loss: 0.1732 - mse: 0.0517
# Epoch 13: val_accuracy improved from 0.92810 to 0.93251, saving model to unet-4d-atlantic.keras
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 10s 39ms/step - accuracy: 0.9298 - loss: 0.1732 - mse: 0.0518 - val_accuracy: 0.9325 - val_loss: 0.1668 - val_mse: 0.0496
# Epoch 14/20
# 249/250 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9299 - loss: 0.1723 - mse: 0.0516
# Epoch 14: val_accuracy improved from 0.93251 to 0.93321, saving model to unet-4d-atlantic.keras
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 10s 40ms/step - accuracy: 0.9299 - loss: 0.1724 - mse: 0.0516 - val_accuracy: 0.9332 - val_loss: 0.1698 - val_mse: 0.0502
# Epoch 15/20
# 249/250 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9322 - loss: 0.1659 - mse: 0.0497
# Epoch 15: val_accuracy improved from 0.93321 to 0.93527, saving model to unet-4d-atlantic.keras
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 10s 40ms/step - accuracy: 0.9322 - loss: 0.1659 - mse: 0.0497 - val_accuracy: 0.9353 - val_loss: 0.1596 - val_mse: 0.0477
# Epoch 16/20
# 249/250 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9332 - loss: 0.1625 - mse: 0.0488
# Epoch 16: val_accuracy did not improve from 0.93527
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 9s 34ms/step - accuracy: 0.9332 - loss: 0.1625 - mse: 0.0488 - val_accuracy: 0.9310 - val_loss: 0.1729 - val_mse: 0.0517
# Epoch 17/20
# 249/250 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9369 - loss: 0.1559 - mse: 0.0466
# Epoch 17: val_accuracy improved from 0.93527 to 0.93646, saving model to unet-4d-atlantic.keras
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 10s 40ms/step - accuracy: 0.9369 - loss: 0.1559 - mse: 0.0466 - val_accuracy: 0.9365 - val_loss: 0.1595 - val_mse: 0.0474
# Epoch 18/20
# 249/250 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9400 - loss: 0.1477 - mse: 0.0440
# Epoch 18: val_accuracy improved from 0.93646 to 0.93709, saving model to unet-4d-atlantic.keras
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 10s 40ms/step - accuracy: 0.9400 - loss: 0.1477 - mse: 0.0440 - val_accuracy: 0.9371 - val_loss: 0.1545 - val_mse: 0.0461
# Epoch 19/20
# 249/250 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9418 - loss: 0.1422 - mse: 0.0425
# Epoch 19: val_accuracy did not improve from 0.93709
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 9s 34ms/step - accuracy: 0.9417 - loss: 0.1423 - mse: 0.0425 - val_accuracy: 0.9365 - val_loss: 0.1714 - val_mse: 0.0497
# Epoch 20/20
# 249/250 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9417 - loss: 0.1447 - mse: 0.0430
# Epoch 20: val_accuracy improved from 0.93709 to 0.94286, saving model to unet-4d-atlantic.keras
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 10s 40ms/step - accuracy: 0.9417 - loss: 0.1447 - mse: 0.0430 - val_accuracy: 0.9429 - val_loss: 0.1390 - val_mse: 0.0417

# %%
# Save model history
np.save('unet-4d-atlantic-history.npy',model_unet_4band_atlantic.history.history)

# %%
# Copy models to drive
# !cp unet-4d-atlantic.hdf5 drive/MyDrive/Diss/
# !cp unet-4d-atlantic-history.npy drive/MyDrive/Diss/
# Out:
# cp: cannot stat 'unet-4d-atlantic.hdf5': No such file or directory

# %% [markdown]
# ### Attention U-Net

# %%
# Train Attention U-Net with generator
model_attention_unet_4band_atlantic = UNetAM(input_size=(512,512,4), filter_base=16, lr=0.0005)
save_model_4band_attention_atlantic = ModelCheckpoint('unet-attention-4d-atlantic.keras', monitor='val_accuracy',verbose=1, save_best_only=True)
model_attention_unet_4band_atlantic.fit(train_df_4band_atlantic, epochs = 60, validation_data = validation_df_4band_atlantic, callbacks=[save_model_4band_attention_atlantic])
# Out:
# Epoch 1/60
# 247/250 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.7166 - loss: 0.5146 - mse: 0.1772
# Epoch 1: val_accuracy improved from -inf to 0.86062, saving model to unet-attention-4d-atlantic.keras
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 19s 22ms/step - accuracy: 0.7178 - loss: 0.5132 - mse: 0.1767 - val_accuracy: 0.8606 - val_loss: 0.3338 - val_mse: 0.1072
# Epoch 2/60
# 246/250 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8562 - loss: 0.3494 - mse: 0.1131
# Epoch 2: val_accuracy improved from 0.86062 to 0.87683, saving model to unet-attention-4d-atlantic.keras
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.8562 - loss: 0.3492 - mse: 0.1130 - val_accuracy: 0.8768 - val_loss: 0.3010 - val_mse: 0.0941
# Epoch 3/60
# 246/250 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8674 - loss: 0.3156 - mse: 0.1006
# Epoch 3: val_accuracy improved from 0.87683 to 0.87772, saving model to unet-attention-4d-atlantic.keras
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.8673 - loss: 0.3155 - mse: 0.1006 - val_accuracy: 0.8777 - val_loss: 0.2877 - val_mse: 0.0904
# Epoch 4/60
# 246/250 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8745 - loss: 0.2897 - mse: 0.0909
# Epoch 4: val_accuracy improved from 0.87772 to 0.88339, saving model to unet-attention-4d-atlantic.keras
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.8744 - loss: 0.2896 - mse: 0.0909 - val_accuracy: 0.8834 - val_loss: 0.2738 - val_mse: 0.0859
# Epoch 5/60
# 246/250 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8856 - loss: 0.2709 - mse: 0.0842
# Epoch 5: val_accuracy did not improve from 0.88339
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.8855 - loss: 0.2709 - mse: 0.0842 - val_accuracy: 0.8753 - val_loss: 0.2634 - val_mse: 0.0835
# Epoch 6/60
# 246/250 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8938 - loss: 0.2525 - mse: 0.0773
# Epoch 6: val_accuracy improved from 0.88339 to 0.88683, saving model to unet-attention-4d-atlantic.keras
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.8937 - loss: 0.2526 - mse: 0.0773 - val_accuracy: 0.8868 - val_loss: 0.2543 - val_mse: 0.0798
# Epoch 7/60
# 246/250 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9002 - loss: 0.2411 - mse: 0.0734
# Epoch 7: val_accuracy improved from 0.88683 to 0.88855, saving model to unet-attention-4d-atlantic.keras
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.9001 - loss: 0.2412 - mse: 0.0734 - val_accuracy: 0.8885 - val_loss: 0.2509 - val_mse: 0.0788
# Epoch 8/60
# 246/250 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9029 - loss: 0.2338 - mse: 0.0710
# Epoch 8: val_accuracy improved from 0.88855 to 0.89087, saving model to unet-attention-4d-atlantic.keras
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.9028 - loss: 0.2339 - mse: 0.0711 - val_accuracy: 0.8909 - val_loss: 0.2466 - val_mse: 0.0774
# Epoch 9/60
# 246/250 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9053 - loss: 0.2282 - mse: 0.0692
# Epoch 9: val_accuracy improved from 0.89087 to 0.89359, saving model to unet-attention-4d-atlantic.keras
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.9051 - loss: 0.2284 - mse: 0.0693 - val_accuracy: 0.8936 - val_loss: 0.2426 - val_mse: 0.0759
# Epoch 10/60
# 246/250 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9073 - loss: 0.2235 - mse: 0.0677
# Epoch 10: val_accuracy improved from 0.89359 to 0.89529, saving model to unet-attention-4d-atlantic.keras
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.9071 - loss: 0.2237 - mse: 0.0678 - val_accuracy: 0.8953 - val_loss: 0.2397 - val_mse: 0.0749
# Epoch 11/60
# 246/250 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9093 - loss: 0.2186 - mse: 0.0662
# Epoch 11: val_accuracy improved from 0.89529 to 0.89601, saving model to unet-attention-4d-atlantic.keras
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 0.9091 - loss: 0.2188 - mse: 0.0663 - val_accuracy: 0.8960 - val_loss: 0.2387 - val_mse: 0.0746
# Epoch 12/60
# 246/250 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9110 - loss: 0.2146 - mse: 0.0650
# Epoch 12: val_accuracy did not improve from 0.89601
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.9108 - loss: 0.2149 - mse: 0.0651 - val_accuracy: 0.8938 - val_loss: 0.2405 - val_mse: 0.0755
# Epoch 13/60
# 246/250 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9121 - loss: 0.2114 - mse: 0.0641
# Epoch 13: val_accuracy improved from 0.89601 to 0.89677, saving model to unet-attention-4d-atlantic.keras
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.9119 - loss: 0.2116 - mse: 0.0642 - val_accuracy: 0.8968 - val_loss: 0.2340 - val_mse: 0.0733
# Epoch 14/60
# 246/250 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9137 - loss: 0.2077 - mse: 0.0630
# Epoch 14: val_accuracy improved from 0.89677 to 0.90026, saving model to unet-attention-4d-atlantic.keras
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.9136 - loss: 0.2080 - mse: 0.0631 - val_accuracy: 0.9003 - val_loss: 0.2276 - val_mse: 0.0712
# Epoch 15/60
# 246/250 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9151 - loss: 0.2046 - mse: 0.0621
# Epoch 15: val_accuracy did not improve from 0.90026
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.9150 - loss: 0.2048 - mse: 0.0622 - val_accuracy: 0.9000 - val_loss: 0.2271 - val_mse: 0.0713
# Epoch 16/60
# 246/250 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9167 - loss: 0.2009 - mse: 0.0609
# Epoch 16: val_accuracy improved from 0.90026 to 0.90199, saving model to unet-attention-4d-atlantic.keras
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.9166 - loss: 0.2012 - mse: 0.0610 - val_accuracy: 0.9020 - val_loss: 0.2223 - val_mse: 0.0697
# Epoch 17/60
# 246/250 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9181 - loss: 0.1979 - mse: 0.0600
# Epoch 17: val_accuracy improved from 0.90199 to 0.90428, saving model to unet-attention-4d-atlantic.keras
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.9180 - loss: 0.1981 - mse: 0.0600 - val_accuracy: 0.9043 - val_loss: 0.2175 - val_mse: 0.0681
# Epoch 18/60
# 246/250 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9193 - loss: 0.1950 - mse: 0.0590
# Epoch 18: val_accuracy improved from 0.90428 to 0.90581, saving model to unet-attention-4d-atlantic.keras
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.9192 - loss: 0.1952 - mse: 0.0591 - val_accuracy: 0.9058 - val_loss: 0.2139 - val_mse: 0.0669
# Epoch 19/60
# 246/250 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9197 - loss: 0.1944 - mse: 0.0588
# Epoch 19: val_accuracy improved from 0.90581 to 0.90672, saving model to unet-attention-4d-atlantic.keras
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.9196 - loss: 0.1946 - mse: 0.0589 - val_accuracy: 0.9067 - val_loss: 0.2125 - val_mse: 0.0664
# Epoch 20/60
# 246/250 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9219 - loss: 0.1888 - mse: 0.0571
# Epoch 20: val_accuracy improved from 0.90672 to 0.91024, saving model to unet-attention-4d-atlantic.keras
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.9217 - loss: 0.1890 - mse: 0.0572 - val_accuracy: 0.9102 - val_loss: 0.2040 - val_mse: 0.0635
# Epoch 21/60
# 246/250 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9231 - loss: 0.1860 - mse: 0.0562
# Epoch 21: val_accuracy did not improve from 0.91024
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.9230 - loss: 0.1862 - mse: 0.0563 - val_accuracy: 0.9097 - val_loss: 0.2039 - val_mse: 0.0638
# Epoch 22/60
# 246/250 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9245 - loss: 0.1828 - mse: 0.0552
# Epoch 22: val_accuracy improved from 0.91024 to 0.91221, saving model to unet-attention-4d-atlantic.keras
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 0.9244 - loss: 0.1830 - mse: 0.0553 - val_accuracy: 0.9122 - val_loss: 0.1984 - val_mse: 0.0618
# Epoch 23/60
# 246/250 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9256 - loss: 0.1806 - mse: 0.0545
# Epoch 23: val_accuracy improved from 0.91221 to 0.91295, saving model to unet-attention-4d-atlantic.keras
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.9255 - loss: 0.1807 - mse: 0.0545 - val_accuracy: 0.9130 - val_loss: 0.1964 - val_mse: 0.0612
# Epoch 24/60
# 246/250 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9259 - loss: 0.1796 - mse: 0.0542
# Epoch 24: val_accuracy did not improve from 0.91295
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.9258 - loss: 0.1798 - mse: 0.0542 - val_accuracy: 0.9107 - val_loss: 0.2016 - val_mse: 0.0629
# Epoch 25/60
# 246/250 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9283 - loss: 0.1745 - mse: 0.0525
# Epoch 25: val_accuracy improved from 0.91295 to 0.91414, saving model to unet-attention-4d-atlantic.keras
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 0.9282 - loss: 0.1747 - mse: 0.0525 - val_accuracy: 0.9141 - val_loss: 0.1964 - val_mse: 0.0607
# Epoch 26/60
# 246/250 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9258 - loss: 0.1803 - mse: 0.0543
# Epoch 26: val_accuracy improved from 0.91414 to 0.91751, saving model to unet-attention-4d-atlantic.keras
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.9257 - loss: 0.1804 - mse: 0.0543 - val_accuracy: 0.9175 - val_loss: 0.1888 - val_mse: 0.0584
# Epoch 27/60
# 246/250 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9299 - loss: 0.1717 - mse: 0.0515
# Epoch 27: val_accuracy improved from 0.91751 to 0.92183, saving model to unet-attention-4d-atlantic.keras
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.9298 - loss: 0.1718 - mse: 0.0516 - val_accuracy: 0.9218 - val_loss: 0.1799 - val_mse: 0.0554
# Epoch 28/60
# 246/250 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9316 - loss: 0.1675 - mse: 0.0502
# Epoch 28: val_accuracy improved from 0.92183 to 0.92281, saving model to unet-attention-4d-atlantic.keras
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.9315 - loss: 0.1677 - mse: 0.0503 - val_accuracy: 0.9228 - val_loss: 0.1789 - val_mse: 0.0549
# Epoch 29/60
# 246/250 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9328 - loss: 0.1647 - mse: 0.0493
# Epoch 29: val_accuracy did not improve from 0.92281
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.9327 - loss: 0.1648 - mse: 0.0494 - val_accuracy: 0.9216 - val_loss: 0.1791 - val_mse: 0.0555
# Epoch 30/60
# 246/250 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9341 - loss: 0.1624 - mse: 0.0485
# Epoch 30: val_accuracy improved from 0.92281 to 0.92422, saving model to unet-attention-4d-atlantic.keras
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.9340 - loss: 0.1625 - mse: 0.0486 - val_accuracy: 0.9242 - val_loss: 0.1768 - val_mse: 0.0542
# Epoch 31/60
# 246/250 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9354 - loss: 0.1584 - mse: 0.0474
# Epoch 31: val_accuracy improved from 0.92422 to 0.92655, saving model to unet-attention-4d-atlantic.keras
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.9353 - loss: 0.1586 - mse: 0.0475 - val_accuracy: 0.9265 - val_loss: 0.1706 - val_mse: 0.0524
# Epoch 32/60
# 246/250 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9348 - loss: 0.1605 - mse: 0.0480
# Epoch 32: val_accuracy improved from 0.92655 to 0.92672, saving model to unet-attention-4d-atlantic.keras
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.9347 - loss: 0.1606 - mse: 0.0480 - val_accuracy: 0.9267 - val_loss: 0.1727 - val_mse: 0.0528
# Epoch 33/60
# 246/250 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9375 - loss: 0.1536 - mse: 0.0459
# Epoch 33: val_accuracy improved from 0.92672 to 0.93166, saving model to unet-attention-4d-atlantic.keras
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.9374 - loss: 0.1538 - mse: 0.0459 - val_accuracy: 0.9317 - val_loss: 0.1661 - val_mse: 0.0501
# Epoch 34/60
# 246/250 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9374 - loss: 0.1534 - mse: 0.0459
# Epoch 34: val_accuracy improved from 0.93166 to 0.93384, saving model to unet-attention-4d-atlantic.keras
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.9373 - loss: 0.1535 - mse: 0.0459 - val_accuracy: 0.9338 - val_loss: 0.1595 - val_mse: 0.0482
# Epoch 35/60
# 246/250 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9386 - loss: 0.1510 - mse: 0.0450
# Epoch 35: val_accuracy improved from 0.93384 to 0.93749, saving model to unet-attention-4d-atlantic.keras
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.9385 - loss: 0.1511 - mse: 0.0450 - val_accuracy: 0.9375 - val_loss: 0.1529 - val_mse: 0.0460
# Epoch 36/60
# 246/250 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9394 - loss: 0.1488 - mse: 0.0444
# Epoch 36: val_accuracy improved from 0.93749 to 0.94029, saving model to unet-attention-4d-atlantic.keras
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 0.9394 - loss: 0.1489 - mse: 0.0445 - val_accuracy: 0.9403 - val_loss: 0.1497 - val_mse: 0.0444
# Epoch 37/60
# 246/250 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9392 - loss: 0.1489 - mse: 0.0445
# Epoch 37: val_accuracy did not improve from 0.94029
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.9391 - loss: 0.1489 - mse: 0.0445 - val_accuracy: 0.9396 - val_loss: 0.1475 - val_mse: 0.0443
# Epoch 38/60
# 246/250 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9414 - loss: 0.1444 - mse: 0.0429
# Epoch 38: val_accuracy did not improve from 0.94029
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.9414 - loss: 0.1445 - mse: 0.0430 - val_accuracy: 0.9361 - val_loss: 0.1567 - val_mse: 0.0468
# Epoch 39/60
# 246/250 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9398 - loss: 0.1473 - mse: 0.0440
# Epoch 39: val_accuracy improved from 0.94029 to 0.94162, saving model to unet-attention-4d-atlantic.keras
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.9398 - loss: 0.1473 - mse: 0.0440 - val_accuracy: 0.9416 - val_loss: 0.1436 - val_mse: 0.0430
# Epoch 40/60
# 246/250 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9421 - loss: 0.1426 - mse: 0.0424
# Epoch 40: val_accuracy did not improve from 0.94162
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.9421 - loss: 0.1427 - mse: 0.0424 - val_accuracy: 0.9413 - val_loss: 0.1440 - val_mse: 0.0432
# Epoch 41/60
# 246/250 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9431 - loss: 0.1402 - mse: 0.0417
# Epoch 41: val_accuracy improved from 0.94162 to 0.94304, saving model to unet-attention-4d-atlantic.keras
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.9431 - loss: 0.1403 - mse: 0.0417 - val_accuracy: 0.9430 - val_loss: 0.1415 - val_mse: 0.0420
# Epoch 42/60
# 246/250 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9425 - loss: 0.1414 - mse: 0.0421
# Epoch 42: val_accuracy did not improve from 0.94304
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.9425 - loss: 0.1414 - mse: 0.0421 - val_accuracy: 0.9426 - val_loss: 0.1399 - val_mse: 0.0420
# Epoch 43/60
# 246/250 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9442 - loss: 0.1373 - mse: 0.0408
# Epoch 43: val_accuracy did not improve from 0.94304
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.9442 - loss: 0.1374 - mse: 0.0409 - val_accuracy: 0.9416 - val_loss: 0.1436 - val_mse: 0.0430
# Epoch 44/60
# 246/250 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9429 - loss: 0.1414 - mse: 0.0419
# Epoch 44: val_accuracy did not improve from 0.94304
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.9429 - loss: 0.1414 - mse: 0.0419 - val_accuracy: 0.9405 - val_loss: 0.1452 - val_mse: 0.0435
# Epoch 45/60
# 246/250 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9453 - loss: 0.1346 - mse: 0.0401
# Epoch 45: val_accuracy did not improve from 0.94304
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.9453 - loss: 0.1347 - mse: 0.0401 - val_accuracy: 0.9401 - val_loss: 0.1456 - val_mse: 0.0437
# Epoch 46/60
# 246/250 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9432 - loss: 0.1393 - mse: 0.0416
# Epoch 46: val_accuracy improved from 0.94304 to 0.94334, saving model to unet-attention-4d-atlantic.keras
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.9431 - loss: 0.1393 - mse: 0.0416 - val_accuracy: 0.9433 - val_loss: 0.1395 - val_mse: 0.0417
# Epoch 47/60
# 246/250 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9445 - loss: 0.1366 - mse: 0.0407
# Epoch 47: val_accuracy did not improve from 0.94334
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.9445 - loss: 0.1366 - mse: 0.0407 - val_accuracy: 0.9421 - val_loss: 0.1405 - val_mse: 0.0423
# Epoch 48/60
# 246/250 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9467 - loss: 0.1309 - mse: 0.0390
# Epoch 48: val_accuracy did not improve from 0.94334
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.9466 - loss: 0.1310 - mse: 0.0390 - val_accuracy: 0.9387 - val_loss: 0.1530 - val_mse: 0.0452
# Epoch 49/60
# 246/250 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9407 - loss: 0.1468 - mse: 0.0436
# Epoch 49: val_accuracy did not improve from 0.94334
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.9407 - loss: 0.1467 - mse: 0.0436 - val_accuracy: 0.9354 - val_loss: 0.1561 - val_mse: 0.0470
# Epoch 50/60
# 246/250 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9447 - loss: 0.1353 - mse: 0.0405
# Epoch 50: val_accuracy improved from 0.94334 to 0.94405, saving model to unet-attention-4d-atlantic.keras
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.9447 - loss: 0.1352 - mse: 0.0405 - val_accuracy: 0.9441 - val_loss: 0.1386 - val_mse: 0.0414
# Epoch 51/60
# 246/250 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9489 - loss: 0.1259 - mse: 0.0375
# Epoch 51: val_accuracy improved from 0.94405 to 0.94548, saving model to unet-attention-4d-atlantic.keras
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.9489 - loss: 0.1260 - mse: 0.0375 - val_accuracy: 0.9455 - val_loss: 0.1342 - val_mse: 0.0400
# Epoch 52/60
# 246/250 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9477 - loss: 0.1283 - mse: 0.0383
# Epoch 52: val_accuracy did not improve from 0.94548
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.9476 - loss: 0.1283 - mse: 0.0383 - val_accuracy: 0.9443 - val_loss: 0.1360 - val_mse: 0.0408
# Epoch 53/60
# 246/250 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9486 - loss: 0.1255 - mse: 0.0375
# Epoch 53: val_accuracy improved from 0.94548 to 0.94624, saving model to unet-attention-4d-atlantic.keras
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.9486 - loss: 0.1255 - mse: 0.0375 - val_accuracy: 0.9462 - val_loss: 0.1335 - val_mse: 0.0396
# Epoch 54/60
# 246/250 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9475 - loss: 0.1281 - mse: 0.0383
# Epoch 54: val_accuracy did not improve from 0.94624
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.9475 - loss: 0.1281 - mse: 0.0383 - val_accuracy: 0.9439 - val_loss: 0.1370 - val_mse: 0.0411
# Epoch 55/60
# 246/250 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9485 - loss: 0.1256 - mse: 0.0376
# Epoch 55: val_accuracy improved from 0.94624 to 0.94756, saving model to unet-attention-4d-atlantic.keras
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.9485 - loss: 0.1256 - mse: 0.0376 - val_accuracy: 0.9476 - val_loss: 0.1306 - val_mse: 0.0388
# Epoch 56/60
# 246/250 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9478 - loss: 0.1271 - mse: 0.0380
# Epoch 56: val_accuracy did not improve from 0.94756
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.9478 - loss: 0.1272 - mse: 0.0380 - val_accuracy: 0.9438 - val_loss: 0.1388 - val_mse: 0.0415
# Epoch 57/60
# 246/250 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9462 - loss: 0.1312 - mse: 0.0393
# Epoch 57: val_accuracy did not improve from 0.94756
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.9462 - loss: 0.1312 - mse: 0.0393 - val_accuracy: 0.9464 - val_loss: 0.1307 - val_mse: 0.0393
# Epoch 58/60
# 246/250 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9513 - loss: 0.1195 - mse: 0.0356
# Epoch 58: val_accuracy improved from 0.94756 to 0.94867, saving model to unet-attention-4d-atlantic.keras
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.9513 - loss: 0.1195 - mse: 0.0356 - val_accuracy: 0.9487 - val_loss: 0.1273 - val_mse: 0.0379
# Epoch 59/60
# 246/250 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9521 - loss: 0.1174 - mse: 0.0349
# Epoch 59: val_accuracy improved from 0.94867 to 0.94878, saving model to unet-attention-4d-atlantic.keras
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.9521 - loss: 0.1174 - mse: 0.0350 - val_accuracy: 0.9488 - val_loss: 0.1276 - val_mse: 0.0379
# Epoch 60/60
# 246/250 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9529 - loss: 0.1156 - mse: 0.0344
# Epoch 60: val_accuracy improved from 0.94878 to 0.94900, saving model to unet-attention-4d-atlantic.keras
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.9529 - loss: 0.1156 - mse: 0.0344 - val_accuracy: 0.9490 - val_loss: 0.1275 - val_mse: 0.0378

# %%
# Save model history
np.save('unet-attention-4d-atlantic-history.npy',model_attention_unet_4band_atlantic.history.history)

# %%
# Copy models to drive
# !cp unet-attention-4d-atlantic.hdf5 drive/MyDrive/Diss/
# !cp unet-attention-4d-atlantic-history.npy drive/MyDrive/Diss/
# Out:
# cp: cannot stat 'unet-attention-4d-atlantic.hdf5': No such file or directory

# %% [markdown]
# ### ResNet50-SegNet

# %%
R_4band_atlantic = ResNet50SegNet(input_size=(512,512,4))
save_model_resnet_4band_atlantic = ModelCheckpoint('resnet50segnet-4d-atlantic.weights.h5', monitor='val_accuracy',verbose=1, save_best_only=True, save_weights_only=True)
R_4band_atlantic.fit(train_df_4band_atlantic, validation_data = validation_df_4band_atlantic, epochs = 30, callbacks=[save_model_resnet_4band_atlantic])
# Out:
# Epoch 1/30
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - accuracy: 0.6792 - loss: 0.5488 - mse: 0.1903
# Epoch 1: val_accuracy improved from -inf to 0.84885, saving model to resnet50segnet-4d-atlantic.weights.h5
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 49s 160ms/step - accuracy: 0.6796 - loss: 0.5484 - mse: 0.1901 - val_accuracy: 0.8488 - val_loss: 0.3579 - val_mse: 0.1179
# Epoch 2/30
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - accuracy: 0.8493 - loss: 0.3621 - mse: 0.1183
# Epoch 2: val_accuracy improved from 0.84885 to 0.86935, saving model to resnet50segnet-4d-atlantic.weights.h5
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 39s 155ms/step - accuracy: 0.8493 - loss: 0.3621 - mse: 0.1183 - val_accuracy: 0.8693 - val_loss: 0.3224 - val_mse: 0.1025
# Epoch 3/30
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - accuracy: 0.8596 - loss: 0.3372 - mse: 0.1080
# Epoch 3: val_accuracy improved from 0.86935 to 0.87228, saving model to resnet50segnet-4d-atlantic.weights.h5
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 39s 156ms/step - accuracy: 0.8596 - loss: 0.3372 - mse: 0.1080 - val_accuracy: 0.8723 - val_loss: 0.3054 - val_mse: 0.0960
# Epoch 4/30
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - accuracy: 0.8688 - loss: 0.3169 - mse: 0.0998
# Epoch 4: val_accuracy improved from 0.87228 to 0.88197, saving model to resnet50segnet-4d-atlantic.weights.h5
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 39s 156ms/step - accuracy: 0.8688 - loss: 0.3168 - mse: 0.0998 - val_accuracy: 0.8820 - val_loss: 0.2804 - val_mse: 0.0864
# Epoch 5/30
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - accuracy: 0.8706 - loss: 0.3027 - mse: 0.0948
# Epoch 5: val_accuracy improved from 0.88197 to 0.89004, saving model to resnet50segnet-4d-atlantic.weights.h5
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 39s 156ms/step - accuracy: 0.8706 - loss: 0.3026 - mse: 0.0948 - val_accuracy: 0.8900 - val_loss: 0.2640 - val_mse: 0.0802
# Epoch 6/30
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - accuracy: 0.8846 - loss: 0.2724 - mse: 0.0841
# Epoch 6: val_accuracy improved from 0.89004 to 0.90000, saving model to resnet50segnet-4d-atlantic.weights.h5
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 39s 155ms/step - accuracy: 0.8846 - loss: 0.2724 - mse: 0.0841 - val_accuracy: 0.9000 - val_loss: 0.2435 - val_mse: 0.0736
# Epoch 7/30
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - accuracy: 0.8924 - loss: 0.2544 - mse: 0.0782
# Epoch 7: val_accuracy did not improve from 0.90000
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 37s 150ms/step - accuracy: 0.8924 - loss: 0.2544 - mse: 0.0782 - val_accuracy: 0.8976 - val_loss: 0.2359 - val_mse: 0.0725
# Epoch 8/30
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - accuracy: 0.8995 - loss: 0.2377 - mse: 0.0728
# Epoch 8: val_accuracy improved from 0.90000 to 0.90427, saving model to resnet50segnet-4d-atlantic.weights.h5
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 39s 156ms/step - accuracy: 0.8995 - loss: 0.2377 - mse: 0.0728 - val_accuracy: 0.9043 - val_loss: 0.2277 - val_mse: 0.0691
# Epoch 9/30
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - accuracy: 0.9076 - loss: 0.2241 - mse: 0.0677
# Epoch 9: val_accuracy did not improve from 0.90427
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 37s 150ms/step - accuracy: 0.9076 - loss: 0.2241 - mse: 0.0677 - val_accuracy: 0.9006 - val_loss: 0.2404 - val_mse: 0.0733
# Epoch 10/30
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - accuracy: 0.9063 - loss: 0.2281 - mse: 0.0688
# Epoch 10: val_accuracy improved from 0.90427 to 0.91168, saving model to resnet50segnet-4d-atlantic.weights.h5
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 39s 156ms/step - accuracy: 0.9063 - loss: 0.2281 - mse: 0.0688 - val_accuracy: 0.9117 - val_loss: 0.2075 - val_mse: 0.0634
# Epoch 11/30
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - accuracy: 0.9129 - loss: 0.2114 - mse: 0.0638
# Epoch 11: val_accuracy improved from 0.91168 to 0.91566, saving model to resnet50segnet-4d-atlantic.weights.h5
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 39s 156ms/step - accuracy: 0.9129 - loss: 0.2114 - mse: 0.0638 - val_accuracy: 0.9157 - val_loss: 0.1995 - val_mse: 0.0608
# Epoch 12/30
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - accuracy: 0.9158 - loss: 0.2039 - mse: 0.0616
# Epoch 12: val_accuracy improved from 0.91566 to 0.91802, saving model to resnet50segnet-4d-atlantic.weights.h5
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 39s 156ms/step - accuracy: 0.9157 - loss: 0.2040 - mse: 0.0616 - val_accuracy: 0.9180 - val_loss: 0.1941 - val_mse: 0.0591
# Epoch 13/30
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - accuracy: 0.9204 - loss: 0.1935 - mse: 0.0583
# Epoch 13: val_accuracy improved from 0.91802 to 0.92293, saving model to resnet50segnet-4d-atlantic.weights.h5
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 39s 156ms/step - accuracy: 0.9204 - loss: 0.1935 - mse: 0.0583 - val_accuracy: 0.9229 - val_loss: 0.1873 - val_mse: 0.0564
# Epoch 14/30
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - accuracy: 0.9211 - loss: 0.1908 - mse: 0.0576
# Epoch 14: val_accuracy improved from 0.92293 to 0.92817, saving model to resnet50segnet-4d-atlantic.weights.h5
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 39s 156ms/step - accuracy: 0.9211 - loss: 0.1908 - mse: 0.0576 - val_accuracy: 0.9282 - val_loss: 0.1755 - val_mse: 0.0526
# Epoch 15/30
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - accuracy: 0.9232 - loss: 0.1861 - mse: 0.0561
# Epoch 15: val_accuracy improved from 0.92817 to 0.93077, saving model to resnet50segnet-4d-atlantic.weights.h5
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 39s 156ms/step - accuracy: 0.9232 - loss: 0.1861 - mse: 0.0561 - val_accuracy: 0.9308 - val_loss: 0.1708 - val_mse: 0.0509
# Epoch 16/30
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - accuracy: 0.9285 - loss: 0.1742 - mse: 0.0523
# Epoch 16: val_accuracy improved from 0.93077 to 0.93241, saving model to resnet50segnet-4d-atlantic.weights.h5
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 39s 156ms/step - accuracy: 0.9284 - loss: 0.1742 - mse: 0.0523 - val_accuracy: 0.9324 - val_loss: 0.1676 - val_mse: 0.0499
# Epoch 17/30
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - accuracy: 0.9294 - loss: 0.1707 - mse: 0.0515
# Epoch 17: val_accuracy did not improve from 0.93241
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 38s 150ms/step - accuracy: 0.9294 - loss: 0.1707 - mse: 0.0515 - val_accuracy: 0.9309 - val_loss: 0.1739 - val_mse: 0.0516
# Epoch 18/30
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - accuracy: 0.9266 - loss: 0.1795 - mse: 0.0539
# Epoch 18: val_accuracy improved from 0.93241 to 0.93373, saving model to resnet50segnet-4d-atlantic.weights.h5
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 39s 155ms/step - accuracy: 0.9266 - loss: 0.1795 - mse: 0.0539 - val_accuracy: 0.9337 - val_loss: 0.1663 - val_mse: 0.0492
# Epoch 19/30
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - accuracy: 0.9319 - loss: 0.1657 - mse: 0.0498
# Epoch 19: val_accuracy did not improve from 0.93373
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 37s 150ms/step - accuracy: 0.9319 - loss: 0.1658 - mse: 0.0498 - val_accuracy: 0.9332 - val_loss: 0.1644 - val_mse: 0.0491
# Epoch 20/30
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - accuracy: 0.9348 - loss: 0.1592 - mse: 0.0478
# Epoch 20: val_accuracy improved from 0.93373 to 0.93574, saving model to resnet50segnet-4d-atlantic.weights.h5
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 39s 155ms/step - accuracy: 0.9348 - loss: 0.1592 - mse: 0.0478 - val_accuracy: 0.9357 - val_loss: 0.1564 - val_mse: 0.0470
# Epoch 21/30
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - accuracy: 0.9374 - loss: 0.1526 - mse: 0.0458
# Epoch 21: val_accuracy did not improve from 0.93574
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 37s 149ms/step - accuracy: 0.9374 - loss: 0.1526 - mse: 0.0458 - val_accuracy: 0.9350 - val_loss: 0.1576 - val_mse: 0.0475
# Epoch 22/30
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - accuracy: 0.9382 - loss: 0.1502 - mse: 0.0451
# Epoch 22: val_accuracy did not improve from 0.93574
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 37s 150ms/step - accuracy: 0.9382 - loss: 0.1502 - mse: 0.0451 - val_accuracy: 0.9104 - val_loss: 0.2040 - val_mse: 0.0637
# Epoch 23/30
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - accuracy: 0.9367 - loss: 0.1517 - mse: 0.0459
# Epoch 23: val_accuracy did not improve from 0.93574
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 37s 149ms/step - accuracy: 0.9367 - loss: 0.1517 - mse: 0.0459 - val_accuracy: 0.9330 - val_loss: 0.1603 - val_mse: 0.0487
# Epoch 24/30
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - accuracy: 0.9414 - loss: 0.1427 - mse: 0.0428
# Epoch 24: val_accuracy improved from 0.93574 to 0.93679, saving model to resnet50segnet-4d-atlantic.weights.h5
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 39s 156ms/step - accuracy: 0.9414 - loss: 0.1427 - mse: 0.0428 - val_accuracy: 0.9368 - val_loss: 0.1514 - val_mse: 0.0459
# Epoch 25/30
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - accuracy: 0.9432 - loss: 0.1380 - mse: 0.0414
# Epoch 25: val_accuracy improved from 0.93679 to 0.93777, saving model to resnet50segnet-4d-atlantic.weights.h5
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 39s 156ms/step - accuracy: 0.9432 - loss: 0.1380 - mse: 0.0414 - val_accuracy: 0.9378 - val_loss: 0.1511 - val_mse: 0.0456
# Epoch 26/30
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - accuracy: 0.9424 - loss: 0.1398 - mse: 0.0420
# Epoch 26: val_accuracy improved from 0.93777 to 0.94297, saving model to resnet50segnet-4d-atlantic.weights.h5
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 39s 155ms/step - accuracy: 0.9424 - loss: 0.1398 - mse: 0.0420 - val_accuracy: 0.9430 - val_loss: 0.1396 - val_mse: 0.0418
# Epoch 27/30
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - accuracy: 0.9467 - loss: 0.1302 - mse: 0.0389
# Epoch 27: val_accuracy improved from 0.94297 to 0.94568, saving model to resnet50segnet-4d-atlantic.weights.h5
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 39s 156ms/step - accuracy: 0.9467 - loss: 0.1302 - mse: 0.0389 - val_accuracy: 0.9457 - val_loss: 0.1328 - val_mse: 0.0398
# Epoch 28/30
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - accuracy: 0.9479 - loss: 0.1268 - mse: 0.0380
# Epoch 28: val_accuracy did not improve from 0.94568
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 37s 150ms/step - accuracy: 0.9479 - loss: 0.1268 - mse: 0.0380 - val_accuracy: 0.9431 - val_loss: 0.1401 - val_mse: 0.0419
# Epoch 29/30
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - accuracy: 0.9495 - loss: 0.1231 - mse: 0.0368
# Epoch 29: val_accuracy did not improve from 0.94568
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 37s 150ms/step - accuracy: 0.9495 - loss: 0.1231 - mse: 0.0368 - val_accuracy: 0.9440 - val_loss: 0.1366 - val_mse: 0.0412
# Epoch 30/30
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - accuracy: 0.9513 - loss: 0.1189 - mse: 0.0355
# Epoch 30: val_accuracy did not improve from 0.94568
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 37s 150ms/step - accuracy: 0.9513 - loss: 0.1189 - mse: 0.0355 - val_accuracy: 0.9449 - val_loss: 0.1358 - val_mse: 0.0407

# %%
# Save model history
np.save('resnet50segnet-4d-history-atlantic.npy', R_4band_atlantic.history.history)

# %%
# Copy models to drive
# !cp resnet50segnet-4d-atlantic.hdf5 drive/MyDrive/Diss/models/
# !cp resnet50segnet-4d-history-atlantic.npy drive/MyDrive/Diss/models/
# Out:
# cp: cannot stat 'resnet50segnet-4d-atlantic.hdf5': No such file or directory
# cp: cannot create regular file 'drive/MyDrive/Diss/models/': Not a directory

# %% [markdown]
# ### FCN32-VGG16

# %%
F_4band_atlantic = fcn_32(input_size=(512,512,4), lr = 0.0001)
save_model_fcn32_4band_atlantic = ModelCheckpoint('fcn32-4d-atlantic.keras', monitor='val_accuracy',verbose=1, save_best_only=True)
F_4band_atlantic.fit(train_df_4band_atlantic, validation_data = validation_df_4band_atlantic, epochs = 50, callbacks=[save_model_fcn32_4band_atlantic])
# Out:
# Epoch 1/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.6000 - loss: 0.6875 - mse: 0.2470
# Epoch 1: val_accuracy improved from -inf to 0.64892, saving model to fcn32-4d-atlantic.keras
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 50s 169ms/step - accuracy: 0.6001 - loss: 0.6875 - mse: 0.2470 - val_accuracy: 0.6489 - val_loss: 0.6514 - val_mse: 0.2294
# Epoch 2/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.6415 - loss: 0.6620 - mse: 0.2341
# Epoch 2: val_accuracy improved from 0.64892 to 0.65860, saving model to fcn32-4d-atlantic.keras
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 41s 165ms/step - accuracy: 0.6416 - loss: 0.6620 - mse: 0.2341 - val_accuracy: 0.6586 - val_loss: 0.6138 - val_mse: 0.2126
# Epoch 3/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.6463 - loss: 0.6498 - mse: 0.2287
# Epoch 3: val_accuracy improved from 0.65860 to 0.65889, saving model to fcn32-4d-atlantic.keras
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 41s 165ms/step - accuracy: 0.6464 - loss: 0.6497 - mse: 0.2286 - val_accuracy: 0.6589 - val_loss: 0.5884 - val_mse: 0.2016
# Epoch 4/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.6420 - loss: 0.6187 - mse: 0.2150
# Epoch 4: val_accuracy improved from 0.65889 to 0.67466, saving model to fcn32-4d-atlantic.keras
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 41s 164ms/step - accuracy: 0.6421 - loss: 0.6186 - mse: 0.2150 - val_accuracy: 0.6747 - val_loss: 0.5521 - val_mse: 0.1875
# Epoch 5/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.6777 - loss: 0.5655 - mse: 0.1926
# Epoch 5: val_accuracy improved from 0.67466 to 0.75910, saving model to fcn32-4d-atlantic.keras
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 41s 166ms/step - accuracy: 0.6778 - loss: 0.5654 - mse: 0.1925 - val_accuracy: 0.7591 - val_loss: 0.4959 - val_mse: 0.1640
# Epoch 6/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.7404 - loss: 0.5445 - mse: 0.1816
# Epoch 6: val_accuracy improved from 0.75910 to 0.76767, saving model to fcn32-4d-atlantic.keras
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 42s 167ms/step - accuracy: 0.7404 - loss: 0.5444 - mse: 0.1816 - val_accuracy: 0.7677 - val_loss: 0.4835 - val_mse: 0.1590
# Epoch 7/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.7573 - loss: 0.4992 - mse: 0.1653
# Epoch 7: val_accuracy improved from 0.76767 to 0.78548, saving model to fcn32-4d-atlantic.keras
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 41s 166ms/step - accuracy: 0.7574 - loss: 0.4992 - mse: 0.1653 - val_accuracy: 0.7855 - val_loss: 0.4588 - val_mse: 0.1493
# Epoch 8/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.7729 - loss: 0.4776 - mse: 0.1564
# Epoch 8: val_accuracy improved from 0.78548 to 0.79250, saving model to fcn32-4d-atlantic.keras
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 42s 167ms/step - accuracy: 0.7730 - loss: 0.4776 - mse: 0.1564 - val_accuracy: 0.7925 - val_loss: 0.4488 - val_mse: 0.1452
# Epoch 9/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.7752 - loss: 0.4752 - mse: 0.1552
# Epoch 9: val_accuracy improved from 0.79250 to 0.80439, saving model to fcn32-4d-atlantic.keras
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 41s 166ms/step - accuracy: 0.7752 - loss: 0.4752 - mse: 0.1552 - val_accuracy: 0.8044 - val_loss: 0.4283 - val_mse: 0.1374
# Epoch 10/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.7958 - loss: 0.4448 - mse: 0.1431
# Epoch 10: val_accuracy did not improve from 0.80439
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 35s 142ms/step - accuracy: 0.7958 - loss: 0.4448 - mse: 0.1431 - val_accuracy: 0.8002 - val_loss: 0.4334 - val_mse: 0.1392
# Epoch 11/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.8039 - loss: 0.4326 - mse: 0.1383
# Epoch 11: val_accuracy improved from 0.80439 to 0.80615, saving model to fcn32-4d-atlantic.keras
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 43s 173ms/step - accuracy: 0.8039 - loss: 0.4326 - mse: 0.1383 - val_accuracy: 0.8061 - val_loss: 0.4221 - val_mse: 0.1354
# Epoch 12/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.8088 - loss: 0.4223 - mse: 0.1348
# Epoch 12: val_accuracy improved from 0.80615 to 0.80696, saving model to fcn32-4d-atlantic.keras
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 41s 166ms/step - accuracy: 0.8088 - loss: 0.4223 - mse: 0.1348 - val_accuracy: 0.8070 - val_loss: 0.4171 - val_mse: 0.1339
# Epoch 13/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.8115 - loss: 0.4160 - mse: 0.1327
# Epoch 13: val_accuracy improved from 0.80696 to 0.81128, saving model to fcn32-4d-atlantic.keras
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 41s 166ms/step - accuracy: 0.8115 - loss: 0.4160 - mse: 0.1327 - val_accuracy: 0.8113 - val_loss: 0.4113 - val_mse: 0.1317
# Epoch 14/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.8148 - loss: 0.4088 - mse: 0.1303
# Epoch 14: val_accuracy improved from 0.81128 to 0.81230, saving model to fcn32-4d-atlantic.keras
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 43s 174ms/step - accuracy: 0.8148 - loss: 0.4088 - mse: 0.1303 - val_accuracy: 0.8123 - val_loss: 0.4065 - val_mse: 0.1304
# Epoch 15/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.8168 - loss: 0.4044 - mse: 0.1288
# Epoch 15: val_accuracy improved from 0.81230 to 0.81252, saving model to fcn32-4d-atlantic.keras
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 41s 165ms/step - accuracy: 0.8168 - loss: 0.4044 - mse: 0.1288 - val_accuracy: 0.8125 - val_loss: 0.4063 - val_mse: 0.1302
# Epoch 16/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.8196 - loss: 0.3988 - mse: 0.1270
# Epoch 16: val_accuracy improved from 0.81252 to 0.81631, saving model to fcn32-4d-atlantic.keras
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 41s 166ms/step - accuracy: 0.8196 - loss: 0.3988 - mse: 0.1270 - val_accuracy: 0.8163 - val_loss: 0.4008 - val_mse: 0.1281
# Epoch 17/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.8228 - loss: 0.3920 - mse: 0.1247
# Epoch 17: val_accuracy improved from 0.81631 to 0.81770, saving model to fcn32-4d-atlantic.keras
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 42s 166ms/step - accuracy: 0.8228 - loss: 0.3920 - mse: 0.1247 - val_accuracy: 0.8177 - val_loss: 0.3978 - val_mse: 0.1270
# Epoch 18/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.8256 - loss: 0.3859 - mse: 0.1226
# Epoch 18: val_accuracy did not improve from 0.81770
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 35s 142ms/step - accuracy: 0.8256 - loss: 0.3859 - mse: 0.1226 - val_accuracy: 0.8176 - val_loss: 0.3976 - val_mse: 0.1270
# Epoch 19/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.8289 - loss: 0.3795 - mse: 0.1204
# Epoch 19: val_accuracy improved from 0.81770 to 0.81848, saving model to fcn32-4d-atlantic.keras
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 41s 165ms/step - accuracy: 0.8289 - loss: 0.3795 - mse: 0.1204 - val_accuracy: 0.8185 - val_loss: 0.3952 - val_mse: 0.1262
# Epoch 20/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.8324 - loss: 0.3732 - mse: 0.1183
# Epoch 20: val_accuracy improved from 0.81848 to 0.82025, saving model to fcn32-4d-atlantic.keras
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 41s 165ms/step - accuracy: 0.8324 - loss: 0.3732 - mse: 0.1183 - val_accuracy: 0.8202 - val_loss: 0.3940 - val_mse: 0.1254
# Epoch 21/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.8359 - loss: 0.3670 - mse: 0.1161
# Epoch 21: val_accuracy improved from 0.82025 to 0.82231, saving model to fcn32-4d-atlantic.keras
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 41s 165ms/step - accuracy: 0.8359 - loss: 0.3670 - mse: 0.1161 - val_accuracy: 0.8223 - val_loss: 0.3929 - val_mse: 0.1245
# Epoch 22/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.8381 - loss: 0.3630 - mse: 0.1147
# Epoch 22: val_accuracy improved from 0.82231 to 0.82343, saving model to fcn32-4d-atlantic.keras
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 41s 166ms/step - accuracy: 0.8381 - loss: 0.3630 - mse: 0.1147 - val_accuracy: 0.8234 - val_loss: 0.3903 - val_mse: 0.1236
# Epoch 23/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.8398 - loss: 0.3604 - mse: 0.1138
# Epoch 23: val_accuracy did not improve from 0.82343
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 35s 142ms/step - accuracy: 0.8398 - loss: 0.3604 - mse: 0.1138 - val_accuracy: 0.8160 - val_loss: 0.4114 - val_mse: 0.1295
# Epoch 24/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.8374 - loss: 0.3648 - mse: 0.1152
# Epoch 24: val_accuracy did not improve from 0.82343
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 35s 142ms/step - accuracy: 0.8374 - loss: 0.3648 - mse: 0.1152 - val_accuracy: 0.8205 - val_loss: 0.3999 - val_mse: 0.1260
# Epoch 25/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.8388 - loss: 0.3645 - mse: 0.1148
# Epoch 25: val_accuracy did not improve from 0.82343
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 35s 142ms/step - accuracy: 0.8388 - loss: 0.3645 - mse: 0.1148 - val_accuracy: 0.8098 - val_loss: 0.4261 - val_mse: 0.1339
# Epoch 26/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.8377 - loss: 0.3677 - mse: 0.1157
# Epoch 26: val_accuracy did not improve from 0.82343
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 35s 142ms/step - accuracy: 0.8377 - loss: 0.3677 - mse: 0.1157 - val_accuracy: 0.8097 - val_loss: 0.4333 - val_mse: 0.1350
# Epoch 27/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.8331 - loss: 0.3797 - mse: 0.1194
# Epoch 27: val_accuracy did not improve from 0.82343
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 35s 142ms/step - accuracy: 0.8331 - loss: 0.3797 - mse: 0.1194 - val_accuracy: 0.8143 - val_loss: 0.4226 - val_mse: 0.1315
# Epoch 28/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.8367 - loss: 0.3706 - mse: 0.1164
# Epoch 28: val_accuracy did not improve from 0.82343
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 35s 142ms/step - accuracy: 0.8367 - loss: 0.3706 - mse: 0.1164 - val_accuracy: 0.7957 - val_loss: 0.4902 - val_mse: 0.1470
# Epoch 29/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.8407 - loss: 0.3596 - mse: 0.1131
# Epoch 29: val_accuracy did not improve from 0.82343
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 35s 142ms/step - accuracy: 0.8407 - loss: 0.3596 - mse: 0.1131 - val_accuracy: 0.8147 - val_loss: 0.4052 - val_mse: 0.1293
# Epoch 30/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.8440 - loss: 0.3519 - mse: 0.1107
# Epoch 30: val_accuracy improved from 0.82343 to 0.82425, saving model to fcn32-4d-atlantic.keras
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 43s 173ms/step - accuracy: 0.8440 - loss: 0.3519 - mse: 0.1107 - val_accuracy: 0.8242 - val_loss: 0.3882 - val_mse: 0.1238
# Epoch 31/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.8455 - loss: 0.3495 - mse: 0.1099
# Epoch 31: val_accuracy did not improve from 0.82425
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 35s 142ms/step - accuracy: 0.8455 - loss: 0.3494 - mse: 0.1099 - val_accuracy: 0.8231 - val_loss: 0.3927 - val_mse: 0.1250
# Epoch 32/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.8470 - loss: 0.3464 - mse: 0.1089
# Epoch 32: val_accuracy did not improve from 0.82425
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 35s 142ms/step - accuracy: 0.8470 - loss: 0.3464 - mse: 0.1089 - val_accuracy: 0.8208 - val_loss: 0.3983 - val_mse: 0.1267
# Epoch 33/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.8467 - loss: 0.3472 - mse: 0.1091
# Epoch 33: val_accuracy did not improve from 0.82425
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 35s 142ms/step - accuracy: 0.8467 - loss: 0.3472 - mse: 0.1091 - val_accuracy: 0.8221 - val_loss: 0.4055 - val_mse: 0.1287
# Epoch 34/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.8466 - loss: 0.3485 - mse: 0.1095
# Epoch 34: val_accuracy did not improve from 0.82425
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 35s 142ms/step - accuracy: 0.8466 - loss: 0.3485 - mse: 0.1095 - val_accuracy: 0.8121 - val_loss: 0.4355 - val_mse: 0.1345
# Epoch 35/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.8457 - loss: 0.3483 - mse: 0.1096
# Epoch 35: val_accuracy did not improve from 0.82425
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 35s 142ms/step - accuracy: 0.8457 - loss: 0.3483 - mse: 0.1096 - val_accuracy: 0.8161 - val_loss: 0.4462 - val_mse: 0.1334
# Epoch 36/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.8461 - loss: 0.3482 - mse: 0.1095
# Epoch 36: val_accuracy did not improve from 0.82425
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 35s 142ms/step - accuracy: 0.8461 - loss: 0.3482 - mse: 0.1095 - val_accuracy: 0.8124 - val_loss: 0.4453 - val_mse: 0.1351
# Epoch 37/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.8454 - loss: 0.3490 - mse: 0.1098
# Epoch 37: val_accuracy improved from 0.82425 to 0.82452, saving model to fcn32-4d-atlantic.keras
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 43s 172ms/step - accuracy: 0.8454 - loss: 0.3489 - mse: 0.1098 - val_accuracy: 0.8245 - val_loss: 0.3969 - val_mse: 0.1242
# Epoch 38/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.8476 - loss: 0.3446 - mse: 0.1084
# Epoch 38: val_accuracy improved from 0.82452 to 0.82510, saving model to fcn32-4d-atlantic.keras
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 42s 166ms/step - accuracy: 0.8476 - loss: 0.3446 - mse: 0.1084 - val_accuracy: 0.8251 - val_loss: 0.3887 - val_mse: 0.1228
# Epoch 39/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.8478 - loss: 0.3443 - mse: 0.1082
# Epoch 39: val_accuracy did not improve from 0.82510
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 35s 142ms/step - accuracy: 0.8478 - loss: 0.3443 - mse: 0.1082 - val_accuracy: 0.8235 - val_loss: 0.3883 - val_mse: 0.1236
# Epoch 40/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.8449 - loss: 0.3517 - mse: 0.1104
# Epoch 40: val_accuracy did not improve from 0.82510
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 35s 142ms/step - accuracy: 0.8450 - loss: 0.3517 - mse: 0.1104 - val_accuracy: 0.8231 - val_loss: 0.3925 - val_mse: 0.1243
# Epoch 41/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.8473 - loss: 0.3462 - mse: 0.1086
# Epoch 41: val_accuracy did not improve from 0.82510
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 35s 142ms/step - accuracy: 0.8473 - loss: 0.3462 - mse: 0.1086 - val_accuracy: 0.8058 - val_loss: 0.4320 - val_mse: 0.1364
# Epoch 42/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.8467 - loss: 0.3485 - mse: 0.1093
# Epoch 42: val_accuracy improved from 0.82510 to 0.82683, saving model to fcn32-4d-atlantic.keras
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 41s 166ms/step - accuracy: 0.8467 - loss: 0.3485 - mse: 0.1093 - val_accuracy: 0.8268 - val_loss: 0.3867 - val_mse: 0.1217
# Epoch 43/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.8474 - loss: 0.3460 - mse: 0.1084
# Epoch 43: val_accuracy did not improve from 0.82683
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 35s 142ms/step - accuracy: 0.8474 - loss: 0.3460 - mse: 0.1084 - val_accuracy: 0.8249 - val_loss: 0.3846 - val_mse: 0.1226
# Epoch 44/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.8488 - loss: 0.3418 - mse: 0.1073
# Epoch 44: val_accuracy did not improve from 0.82683
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 35s 142ms/step - accuracy: 0.8488 - loss: 0.3418 - mse: 0.1073 - val_accuracy: 0.8238 - val_loss: 0.3890 - val_mse: 0.1240
# Epoch 45/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.8476 - loss: 0.3432 - mse: 0.1081
# Epoch 45: val_accuracy did not improve from 0.82683
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 35s 142ms/step - accuracy: 0.8476 - loss: 0.3432 - mse: 0.1081 - val_accuracy: 0.8246 - val_loss: 0.3892 - val_mse: 0.1240
# Epoch 46/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.8474 - loss: 0.3427 - mse: 0.1081
# Epoch 46: val_accuracy improved from 0.82683 to 0.82830, saving model to fcn32-4d-atlantic.keras
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 42s 166ms/step - accuracy: 0.8474 - loss: 0.3427 - mse: 0.1081 - val_accuracy: 0.8283 - val_loss: 0.3859 - val_mse: 0.1225
# Epoch 47/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.8475 - loss: 0.3420 - mse: 0.1078
# Epoch 47: val_accuracy did not improve from 0.82830
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 35s 142ms/step - accuracy: 0.8475 - loss: 0.3420 - mse: 0.1078 - val_accuracy: 0.8280 - val_loss: 0.3823 - val_mse: 0.1215
# Epoch 48/50
# 178/250 ━━━━━━━━━━━━━━━━━━━━ 7s 111ms/step - accuracy: 0.8483 - loss: 0.3401 - mse: 0.1073

# %%
# Save model history
np.save('fcn32-4d-atlantic-history.npy', F_4band_atlantic.history.history)

# %%
# Copy models to drive
# !cp fcn32-4d-atlantic.hdf5 drive/MyDrive/Diss/
# !cp fcn32-4d-atlantic-history.npy drive/MyDrive/Diss/

# %% [markdown]
# ### ResUNet

# %%
R_4band_atlantic = res_unet(512, [64, 128, 256, 512], 3, 4, 1)
save_model_resunet_4band_atlantic = ModelCheckpoint('resunet-4d-atlantic.keras', monitor='val_accuracy',verbose=1, save_best_only=True, save_weights_only=True)
R_4band_atlantic.fit(train_df_4band_atlantic, validation_data = validation_df_4band_atlantic, epochs = 30, callbacks=[save_model_resunet_4band_atlantic])

# %%
# Save model history
np.save('resunet-4d-history-atlantic.npy', R_4band_atlantic.history.history)

# %%
# Copy models to drive
# !cp resunet-4d-atlantic.hdf5 drive/MyDrive/Diss/models/
# !cp resunet-4d-history-atlantic.npy drive/MyDrive/Diss/models/

# %% [markdown]
# # Import Models and Compute Metrics

# %% [markdown]
# ## RGB

# %%
# Load 3-dim models and history stats
attention_unet = load_model('unet-attention-3d.keras')
unet = load_model('unet-3d.keras')

unet_history = np.load('unet-3d-history.npy', allow_pickle='TRUE').item()
attention_unet_history = np.load('unet-attention-3d-history.npy', allow_pickle='TRUE').item()

# %%
# Plot accuracy and loss for U-Net

## Accuracy
plt.plot(unet_history['accuracy'])
plt.plot(unet_history['val_accuracy'])
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Training', 'Validation'], loc='upper left')
plt.show()

## Loss
plt.plot(unet_history['loss'])
plt.plot(unet_history['val_loss'])
plt.ylabel('Loss', size=12)
plt.xlabel('Epoch', size=12)
plt.legend(['Training', 'Validation'], loc='lower right')

# %%
# Plot accuracy and loss for Attention U-Net

## Accuracy
plt.plot(attention_unet_history['accuracy'])
plt.plot(attention_unet_history['val_accuracy'])
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Training', 'Validation'], loc='lower right')
plt.show()

## Loss
plt.plot(attention_unet_history['loss'])
plt.plot(attention_unet_history['val_loss'])
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Training', 'Validation'], loc='upper right')

# %%
# Scores of each model
unet_score = (score_eval(unet, validation_images, validation_masks))
am_unet_score = (score_eval(attention_unet, validation_images, validation_masks))

# %%
# Precision and recall of each model
unet_precision = (precision_eval(unet, validation_images, validation_masks))
am_unet_precision = (precision_eval(attention_unet, validation_images, validation_masks))

unet_recall = (recall_eval(unet, validation_images, validation_masks))
am_unet_recall = (recall_eval(attention_unet, validation_images, validation_masks))

# %%
# F1-scores of each model
unet_f1_score = (f1_score_eval_basic(unet_precision, unet_recall))
am_unet_f1_score = (f1_score_eval_basic(am_unet_precision, am_unet_recall))

# %%
# Print score eval results for each model
print('U-Net accuracy: ', np.mean(unet_score), np.std(unet_score))
print('Attention U-Net accuracy: ', np.mean(am_unet_score), np.std(am_unet_score))

# %%
# Print precision eval results for each model
print('U-Net precision: ', np.mean(unet_precision), np.std(unet_precision))
print('Attention U-Net precision: ', np.mean(am_unet_precision), np.std(am_unet_precision))

# %%
# Print recall eval results for each model
print('U-Net recall: ', np.mean(unet_recall), np.std(unet_recall))
print('Attention U-Net recall: ', np.mean(am_unet_recall), np.std(am_unet_recall))

# %%
# Print f1-score eval results for each model
print('U-Net F1-score: ', np.mean(unet_f1_score))
print('Attention U-Net F1-score: ', np.mean(am_unet_f1_score))

# %% [markdown]
# ## 4-band

# %% [markdown]
# ### Amazon Data

# %%
# Load 4-dim models and history stats
attention_unet_4d = load_model('unet-attention-4d.keras')
unet_4d = load_model('unet-4d.keras')

unet_4d_history = np.load('unet-4d-history.npy', allow_pickle='TRUE').item()
attention_unet_4d_history = np.load('unet-attention-4d-history.npy', allow_pickle='TRUE').item()

# %%
# Plot accuracy and loss for U-Net

## Accuracy
plt.plot(unet_4d_history['accuracy'])
plt.plot(unet_4d_history['val_accuracy'])
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Training', 'Validation'], loc='upper left')
plt.show()

## Loss
plt.plot(unet_4d_history['loss'])
plt.plot(unet_4d_history['val_loss'])
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Training', 'Validation'], loc='upper left')

# %%
# Plot accuracy and loss for Attention U-Net

## Accuracy
plt.plot(attention_unet_4d_history['accuracy'])
plt.plot(attention_unet_4d_history['val_accuracy'])
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Training', 'Validation'], loc='upper left')
plt.show()

## Loss
plt.plot(attention_unet_4d_history['loss'])
plt.plot(attention_unet_4d_history['val_loss'])
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Training', 'Validation'], loc='upper left')

# %%
# Scores of each model
unet_4d_score = (score_eval2(unet_4d, validation_images2, validation_masks2))
am_unet_4d_score = (score_eval2(attention_unet_4d, validation_images2, validation_masks2))

# %%
# Precision and recall of each model
unet_4d_precision = (precision_eval(unet_4d, validation_images2, validation_masks2))
am_unet_4d_precision = (precision_eval(attention_unet_4d, validation_images2, validation_masks2))

unet_4d_recall = (recall_eval(unet_4d, validation_images2, validation_masks2))
am_unet_4d_recall = (recall_eval(attention_unet_4d, validation_images2, validation_masks2))

# %%
# F1-scores of each model
unet_4d_f1_score = (f1_score_eval_basic(unet_4d_precision, unet_4d_recall))
am_unet_4d_f1_score = (f1_score_eval_basic(am_unet_4d_precision, am_unet_4d_recall))

# %%
# Print score eval results for each model
print('U-Net accuracy: ', np.mean(unet_4d_score), np.std(unet_4d_score))
print('Attention U-Net accuracy: ', np.mean(am_unet_4d_score), np.std(am_unet_4d_score))

# %%
# Print precision eval results for each model
print('U-Net precision: ', np.mean(unet_4d_precision), np.std(unet_4d_precision))
print('Attention U-Net precision: ', np.mean(am_unet_4d_precision), np.std(am_unet_4d_precision))

# %%
# Print recall eval results for each model
print('U-Net recall: ', np.mean(unet_4d_recall), np.std(unet_4d_recall))
print('Attention U-Net recall: ', np.mean(am_unet_4d_recall), np.std(am_unet_4d_recall))

# %%
# Print f1-score eval results for each model
print('U-Net F1-score: ', np.mean(unet_4d_f1_score))
print('Attention U-Net F1-score: ', np.mean(am_unet_4d_f1_score))

# %% [markdown]
# ### Amazon on unseen Atlantic data

# %%
# Score
unet_amazon_on_atlantic_score = score_eval2(unet_4d, validation_images3+test_images3, validation_masks3+test_masks3)
am_unet_amazon_on_atlantic_score = score_eval2(attention_unet_4d, validation_images3+test_images3, validation_masks3+test_masks3)

# Precision
unet_amazon_on_atlantic_precision = (precision_eval(unet_4d, validation_images3+test_images3, validation_masks3+test_masks3))
am_unet_amazon_on_atlantic_precision = (precision_eval(attention_unet_4d, validation_images3+test_images3, validation_masks3+test_masks3))

# Recall
unet_amazon_on_atlantic_recall = (recall_eval(unet_4d, validation_images3+test_images3, validation_masks3+test_masks3))
am_unet_amazon_on_atlantic_recall = (recall_eval(attention_unet_4d, validation_images3+test_images3, validation_masks3+test_masks3))

# F1-scores of each model
unet_amazon_on_atlantic_f1_score = (f1_score_eval_basic(unet_amazon_on_atlantic_precision, unet_amazon_on_atlantic_recall))
am_unet_amazon_on_atlantic_f1_score = (f1_score_eval_basic(am_unet_amazon_on_atlantic_precision, am_unet_amazon_on_atlantic_recall))

# %%
# Print metrics
print('U-Net score: ', np.mean(unet_amazon_on_atlantic_score), np.std(unet_amazon_on_atlantic_score))
print('Attention U-Net score: ', np.mean(am_unet_amazon_on_atlantic_score), np.std(am_unet_amazon_on_atlantic_score))

print('U-Net precision: ', np.mean(unet_amazon_on_atlantic_precision), np.std(unet_amazon_on_atlantic_precision))
print('Attention U-Net precision: ', np.mean(am_unet_amazon_on_atlantic_precision), np.std(am_unet_amazon_on_atlantic_precision))

print('U-Net recall: ', np.mean(unet_amazon_on_atlantic_recall), np.std(unet_amazon_on_atlantic_recall))
print('Attention U-Net recall: ', np.mean(am_unet_amazon_on_atlantic_recall), np.std(am_unet_amazon_on_atlantic_recall))

print('U-Net F1-score: ', unet_amazon_on_atlantic_f1_score)
print('Attention U-Net F1-score: ', am_unet_amazon_on_atlantic_f1_score)

# %% [markdown]
# ### Atlantic Data

# %%
# Load 4-dim models and history stats
attention_unet_4d_atlantic = load_model('unet-attention-4d-atlantic.keras')
unet_4d_atlantic = load_model('unet-4d-atlantic.keras')

unet_4d_atlantic_history = np.load('unet-4d-atlantic-history.npy', allow_pickle='TRUE').item()
attention_unet_4d_atlantic_history = np.load('unet-attention-4d-atlantic-history.npy', allow_pickle='TRUE').item()

# %%
# Plot accuracy and loss for U-Net

## Accuracy
plt.plot(unet_4d_atlantic_history['accuracy'])
plt.plot(unet_4d_atlantic_history['val_accuracy'])
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Training', 'Validation'], loc='upper left')
plt.show()

## Loss
plt.plot(unet_4d_atlantic_history['loss'])
plt.plot(unet_4d_atlantic_history['val_loss'])
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Training', 'Validation'], loc='upper left')

# %%
# Plot accuracy and loss for Attention U-Net

## Accuracy
plt.plot(attention_unet_4d_atlantic_history['accuracy'])
plt.plot(attention_unet_4d_atlantic_history['val_accuracy'])
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Training', 'Validation'], loc='upper left')
plt.show()

## Loss
plt.plot(attention_unet_4d_atlantic_history['loss'])
plt.plot(attention_unet_4d_atlantic_history['val_loss'])
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Training', 'Validation'], loc='upper left')

# %%
# Scores of each model
unet_4d_atlantic_score = (score_eval2(unet_4d_atlantic, validation_images3, validation_masks3))
am_unet_4d_atlantic_score = (score_eval2(attention_unet_4d_atlantic, validation_images3, validation_masks3))

# Precision and recall of each model
unet_4d_atlantic_precision = (precision_eval(unet_4d_atlantic, validation_images3, validation_masks3))
am_unet_4d_atlantic_precision = (precision_eval(attention_unet_4d_atlantic, validation_images3, validation_masks3))

unet_4d_atlantic_recall = (recall_eval(unet_4d_atlantic, validation_images3, validation_masks3))
am_unet_4d_atlantic_recall = (recall_eval(attention_unet_4d_atlantic, validation_images3, validation_masks3))

# F1-scores of each model
unet_4d_atlantic_f1_score = (f1_score_eval_basic(unet_4d_atlantic_precision, unet_4d_atlantic_recall))
am_unet_4d_atlantic_f1_score = (f1_score_eval_basic(am_unet_4d_atlantic_precision, am_unet_4d_atlantic_recall))

# %%
# Print metrics
print('U-Net score: ', np.mean(unet_4d_atlantic_score), np.std(unet_4d_atlantic_score))
print('Attention U-Net score: ', np.mean(am_unet_4d_atlantic_score), np.std(am_unet_4d_atlantic_score))

print('U-Net precision: ', np.mean(unet_4d_atlantic_precision), np.std(unet_4d_atlantic_precision))
print('Attention U-Net precision: ', np.mean(am_unet_4d_atlantic_precision), np.std(am_unet_4d_atlantic_precision))

print('U-Net recall: ', np.mean(unet_4d_atlantic_recall), np.std(unet_4d_atlantic_recall))
print('Attention U-Net recall: ', np.mean(am_unet_4d_atlantic_recall), np.std(am_unet_4d_atlantic_recall))

print('U-Net F1-score: ', unet_4d_atlantic_f1_score)
print('Attention U-Net F1-score: ', am_unet_4d_atlantic_f1_score)

# %% [markdown]
# ### Atlantic on unseen Amazon data

# %%
# Score
unet_atlantic_on_amazon_score = score_eval2(unet_4d_atlantic, validation_images2+test_images2, validation_masks2+test_masks2)
am_unet_atlantic_on_amazon_score = score_eval2(attention_unet_4d_atlantic, validation_images2+test_images2, validation_masks2+test_masks2)

# Precision
unet_atlantic_on_amazon_precision = (precision_eval(unet_4d_atlantic, validation_images2+test_images2, validation_masks2+test_masks2))
am_unet_atlantic_on_amazon_precision = (precision_eval(attention_unet_4d_atlantic, validation_images2+test_images2, validation_masks2+test_masks2))

# Recall
unet_atlantic_on_amazon_recall = (recall_eval(unet_4d_atlantic, validation_images2+test_images2, validation_masks2+test_masks2))
am_unet_atlantic_on_amazon_recall = (recall_eval(attention_unet_4d_atlantic, validation_images2+test_images2, validation_masks2+test_masks2))

# F1-scores of each model
unet_atlantic_on_amazon_f1_score = (f1_score_eval_basic(unet_atlantic_on_amazon_precision, unet_atlantic_on_amazon_recall))
am_unet_atlantic_on_amazon_f1_score = (f1_score_eval_basic(am_unet_atlantic_on_amazon_precision, am_unet_atlantic_on_amazon_recall))

# %%
# Print metrics
print('U-Net score: ', np.mean(unet_atlantic_on_amazon_score), np.std(unet_atlantic_on_amazon_score))
print('Attention U-Net score: ', np.mean(am_unet_atlantic_on_amazon_score), np.std(am_unet_atlantic_on_amazon_score))

print('U-Net precision: ', np.mean(unet_atlantic_on_amazon_precision), np.std(unet_atlantic_on_amazon_precision))
print('Attention U-Net precision: ', np.mean(am_unet_atlantic_on_amazon_precision), np.std(am_unet_atlantic_on_amazon_precision))

print('U-Net recall: ', np.mean(unet_atlantic_on_amazon_recall), np.std(unet_atlantic_on_amazon_recall))
print('Attention U-Net recall: ', np.mean(am_unet_atlantic_on_amazon_recall), np.std(am_unet_atlantic_on_amazon_recall))

print('U-Net F1-score: ', unet_atlantic_on_amazon_f1_score)
print('Attention U-Net F1-score: ', am_unet_atlantic_on_amazon_f1_score)

# %% [markdown]
# ### Amazon and Atlantic unseen test data

# %%
# Amazon trained model on Amazon test data
# Scores of each model
unet_4d_score_test = (score_eval2(unet_4d, test_images2, test_masks2))
am_unet_4d_score_test = (score_eval2(attention_unet_4d, test_images2, test_masks2))

# Precision and recall of each model
unet_4d_precision_test = (precision_eval(unet_4d, test_images2, test_masks2))
am_unet_4d_precision_test = (precision_eval(attention_unet_4d, test_images2, test_masks2))

unet_4d_recall_test = (recall_eval(unet_4d, test_images2, test_masks2))
am_unet_4d_recall_test = (recall_eval(attention_unet_4d, test_images2, test_masks2))

# F1-scores of each model
unet_4d_f1_score_test = (f1_score_eval_basic(unet_4d_precision_test, unet_4d_recall_test))
am_unet_4d_f1_score_test = (f1_score_eval_basic(am_unet_4d_precision_test, am_unet_4d_recall_test))

# %%
# Atlantic trained model on Atlantic test data
# Scores of each model
unet_4d_atlantic_score_test = (score_eval2(unet_4d_atlantic, test_images3, test_masks3))
am_unet_4d_atlantic_score_test = (score_eval2(attention_unet_4d_atlantic, test_images3, test_masks3))

# Precision and recall of each model
unet_4d_atlantic_precision_test = (precision_eval(unet_4d_atlantic, test_images3, test_masks3))
am_unet_4d_atlantic_precision_test = (precision_eval(attention_unet_4d_atlantic, test_images3, test_masks3))

unet_4d_atlantic_recall_test = (recall_eval(unet_4d_atlantic, test_images3, test_masks3))
am_unet_4d_atlantic_recall_test = (recall_eval(attention_unet_4d_atlantic, test_images3, test_masks3))

# F1-scores of each model
unet_4d_atlantic_f1_score_test = (f1_score_eval_basic(unet_4d_atlantic_precision_test, unet_4d_atlantic_recall_test))
am_unet_4d_atlantic_f1_score_test = (f1_score_eval_basic(am_unet_4d_atlantic_precision_test, am_unet_4d_atlantic_recall_test))

# %%
# Print metrics for Amazon on Amazon Test set
print('U-Net score: ', np.mean(unet_4d_score_test), np.std(unet_4d_score_test))
print('Attention U-Net score: ', np.mean(am_unet_4d_score_test), np.std(am_unet_4d_score_test))

print('U-Net precision: ', np.mean(unet_4d_precision_test), np.std(unet_4d_precision_test))
print('Attention U-Net precision: ', np.mean(am_unet_4d_precision_test), np.std(am_unet_4d_precision_test))

print('U-Net recall: ', np.mean(unet_4d_recall_test), np.std(unet_4d_recall_test))
print('Attention U-Net recall: ', np.mean(am_unet_4d_recall_test), np.std(am_unet_4d_recall_test))

print('U-Net F1-score: ', unet_4d_f1_score_test)
print('Attention U-Net F1-score: ', am_unet_4d_f1_score_test)

# %%
# Print metrics for Atlantic on Atlantic Test set
print('U-Net score: ', np.mean(unet_4d_atlantic_score_test), np.std(unet_4d_atlantic_score_test))
print('Attention U-Net score: ', np.mean(am_unet_4d_atlantic_score_test), np.std(am_unet_4d_atlantic_score_test))

print('U-Net precision: ', np.mean(unet_4d_atlantic_precision_test), np.std(unet_4d_atlantic_precision_test))
print('Attention U-Net precision: ', np.mean(am_unet_4d_atlantic_precision_test), np.std(am_unet_4d_atlantic_precision_test))

print('U-Net recall: ', np.mean(unet_4d_atlantic_recall_test), np.std(unet_4d_atlantic_recall_test))
print('Attention U-Net recall: ', np.mean(am_unet_4d_atlantic_recall_test), np.std(am_unet_4d_atlantic_recall_test))

print('U-Net F1-score: ', unet_4d_atlantic_f1_score_test)
print('Attention U-Net F1-score: ', am_unet_4d_atlantic_f1_score_test)

# %% [markdown]
# ## ResNet50-SegNet

# %%
# Load ResNet models and history stats
resnet_3d = ResNet50SegNet()
resnet_3d.load_weights('resnet50segnet-3d.hdf5')
resnet_4d_amazon = ResNet50SegNet(input_size=(512,512,4))
resnet_4d_amazon.load_weights('resnet50segnet-4d.hdf5')
resnet_4d_atlantic = ResNet50SegNet(input_size=(512,512,4))
resnet_4d_atlantic.load_weights('resnet50segnet-4d-atlantic.hdf5')

resnet_3d_history = np.load('resnet50segnet-3d-history.npy', allow_pickle='TRUE').item()
resnet50segnet_4d_amazon_history = np.load('resnet50segnet-4d-history.npy', allow_pickle='TRUE').item()
resnet50segnet_4d_atlantic_history = np.load('resnet50segnet-4d-history-atlantic.npy', allow_pickle='TRUE').item()

# %%
# Metrics of each model on respective datasets

# Score
resnet_3d_score = (score_eval(resnet_3d, validation_images, validation_masks))
resnet_4d_amazon_score = (score_eval2(resnet_4d_amazon, validation_images2, validation_masks2))
resnet_4d_atlantic_score = (score_eval2(resnet_4d_atlantic, validation_images3, validation_masks3))

# Precision and recall
resnet_3d_precision = (precision_eval(resnet_3d, validation_images, validation_masks))
resnet_4d_amazon_precision = (precision_eval(resnet_4d_amazon, validation_images2, validation_masks2))
resnet_4d_atlantic_precision = (precision_eval(resnet_4d_atlantic, validation_images3, validation_masks3))

resnet_3d_recall = (recall_eval(resnet_3d, validation_images, validation_masks))
resnet_4d_amazon_recall = (recall_eval(resnet_4d_amazon, validation_images2, validation_masks2))
resnet_4d_atlantic_recall = (recall_eval(resnet_4d_atlantic, validation_images3, validation_masks3))

# F1-score
resnet_3d_f1_score = (f1_score_eval_basic(resnet_3d_precision, resnet_3d_recall))
resnet_4d_amazon_f1_score = (f1_score_eval_basic(resnet_4d_amazon_precision, resnet_4d_amazon_recall))
resnet_4d_atlantic_f1_score = (f1_score_eval_basic(resnet_4d_atlantic_precision, resnet_4d_atlantic_recall))

# %%
# Metrics of 4-dim Amazon trained model on Atlantic data and vice versa

# Score
resnet_4d_amazon_on_atlantic_score = (score_eval2(resnet_4d_amazon, validation_images3+test_images3, validation_masks3+test_masks3))
resnet_4d_atlantic_on_amazon_score = (score_eval2(resnet_4d_atlantic, validation_images2+test_images2, validation_masks2+test_masks2))

# Precision and recall
resnet_4d_amazon_on_atlantic_precision = (precision_eval(resnet_4d_amazon, validation_images3+test_images3, validation_masks3+test_masks3))
resnet_4d_atlantic_on_amazon_precision = (precision_eval(resnet_4d_atlantic, validation_images2+test_images2, validation_masks2+test_masks2))

resnet_4d_amazon_on_atlantic_recall = (recall_eval(resnet_4d_amazon, validation_images3+test_images3, validation_masks3+test_masks3))
resnet_4d_atlantic_on_amazon_recall = (recall_eval(resnet_4d_atlantic, validation_images2+test_images2, validation_masks2+test_masks2))

# F1-score
resnet_4d_amazon_on_atlantic_f1_score = (f1_score_eval_basic(resnet_4d_amazon_on_atlantic_precision, resnet_4d_amazon_on_atlantic_recall))
resnet_4d_atlantic_on_amazon_f1_score = (f1_score_eval_basic(resnet_4d_atlantic_on_amazon_precision, resnet_4d_atlantic_on_amazon_recall))

# %%
# Print metrics
print('Accuracy | Precision | Recall | F1-score')
print('ResNet 3-dim: ', np.mean(resnet_3d_score), np.mean(resnet_3d_precision), np.mean(resnet_3d_recall), resnet_3d_f1_score)
print('ResNet 3-dim: ', np.std(resnet_3d_score), np.std(resnet_3d_precision), np.std(resnet_3d_recall), resnet_3d_f1_score)
print('----')
print('ResNet 4-dim Amazon: ', np.mean(resnet_4d_amazon_score), np.mean(resnet_4d_amazon_precision), np.mean(resnet_4d_amazon_recall), resnet_4d_amazon_f1_score)
print('ResNet 4-dim Amazon: ', np.std(resnet_4d_amazon_score), np.std(resnet_4d_amazon_precision), np.std(resnet_4d_amazon_recall), resnet_4d_amazon_f1_score)
print('----')
print('ResNet 4-dim Atlantic: ', np.mean(resnet_4d_atlantic_score), np.mean(resnet_4d_atlantic_precision), np.mean(resnet_4d_atlantic_recall), resnet_4d_atlantic_f1_score)
print('ResNet 4-dim Atlantic: ', np.std(resnet_4d_atlantic_score), np.std(resnet_4d_atlantic_precision), np.std(resnet_4d_atlantic_recall), resnet_4d_atlantic_f1_score)
print('----')
print('ResNet 4-dim Amazon on Atlantic: ', np.mean(resnet_4d_amazon_on_atlantic_score), np.mean(resnet_4d_amazon_on_atlantic_precision), np.mean(resnet_4d_amazon_on_atlantic_recall), resnet_4d_amazon_on_atlantic_f1_score)
print('ResNet 4-dim Amazon on Atlantic: ', np.std(resnet_4d_amazon_on_atlantic_score), np.std(resnet_4d_amazon_on_atlantic_precision), np.std(resnet_4d_amazon_on_atlantic_recall), resnet_4d_amazon_on_atlantic_f1_score)
print('----')
print('ResNet 4-dim Atlantic on Amazon: ', np.mean(resnet_4d_atlantic_on_amazon_score), np.mean(resnet_4d_atlantic_on_amazon_precision), np.mean(resnet_4d_atlantic_on_amazon_recall), resnet_4d_atlantic_on_amazon_f1_score)
print('ResNet 4-dim Atlantic on Amazon: ', np.std(resnet_4d_atlantic_on_amazon_score), np.std(resnet_4d_atlantic_on_amazon_precision), np.std(resnet_4d_atlantic_on_amazon_recall), resnet_4d_atlantic_on_amazon_f1_score)

# %% [markdown]
# ### Amazon and Atlantic unseen test datasets

# %%
# Amazon trained model on Amazon test data
# Scores of each model
resnet_4d_score_test = (score_eval2(resnet_4d_amazon, test_images2, test_masks2))

# Precision and recall of each model
resnet_4d_precision_test = (precision_eval(resnet_4d_amazon, test_images2, test_masks2))
resnet_4d_recall_test = (recall_eval(resnet_4d_amazon, test_images2, test_masks2))

# F1-scores of each model
resnet_4d_f1_score_test = (f1_score_eval_basic(resnet_4d_precision_test, resnet_4d_recall_test))

# %%
# Atlantic trained model on Atlantic test data
# Scores of each model
resnet_4d_atlantic_score_test = (score_eval2(resnet_4d_atlantic, test_images3, test_masks3))

# Precision and recall of each model
resnet_4d_atlantic_precision_test = (precision_eval(resnet_4d_atlantic, test_images3, test_masks3))
resnet_4d_atlantic_recall_test = (recall_eval(resnet_4d_atlantic, test_images3, test_masks3))

# F1-scores of each model
resnet_4d_atlantic_f1_score_test = (f1_score_eval_basic(resnet_4d_atlantic_precision_test, resnet_4d_atlantic_recall_test))

# %%
# Print metrics for Amazon on Amazon Test set
print('ResNet score: ', np.mean(resnet_4d_score_test), np.std(resnet_4d_score_test))
print('ResNet precision: ', np.mean(resnet_4d_precision_test), np.std(resnet_4d_precision_test))
print('ResNet recall: ', np.mean(resnet_4d_recall_test), np.std(resnet_4d_recall_test))
print('ResNet F1-score: ', resnet_4d_f1_score_test)

# %%
# Print metrics for Atlantic on Atlantic Test set
print('ResNet score: ', np.mean(resnet_4d_atlantic_score_test), np.std(resnet_4d_atlantic_score_test))
print('ResNet precision: ', np.mean(resnet_4d_atlantic_precision_test), np.std(resnet_4d_atlantic_precision_test))
print('ResNet recall: ', np.mean(resnet_4d_atlantic_recall_test), np.std(resnet_4d_atlantic_recall_test))
print('ResNet F1-score: ', resnet_4d_atlantic_f1_score_test)

# %% [markdown]
# ## FCN32-VGG16

# %%
# Import models
fcn32_3d = load_model('fcn32-3d.keras')
fcn32_4d_amazon = load_model('fcn32-4d.keras')
fcn32_4d_atlantic = load_model('fcn32-4d-atlantic.keras')

fcn32_3d_history = np.load('fcn32-3d-history.npy', allow_pickle='TRUE').item()
fcn32_4d_amazon_history = np.load('fcn32-4d-history.npy', allow_pickle='TRUE').item()
fcn32_4d_atlantic_history = np.load('fcn32-4d-atlantic-history.npy', allow_pickle='TRUE').item()

# %%
# Metrics of each model on respective datasets

# Score
fcn32_3d_score = (score_eval(fcn32_3d, validation_images, validation_masks))
fcn32_4d_amazon_score = (score_eval2(fcn32_4d_amazon, validation_images2, validation_masks2))
fcn32_4d_atlantic_score = (score_eval2(fcn32_4d_atlantic, validation_images3, validation_masks3))

# Precision and recall
fcn32_3d_precision = (precision_eval(fcn32_3d, validation_images, validation_masks))
fcn32_4d_amazon_precision = (precision_eval(fcn32_4d_amazon, validation_images2, validation_masks2))
fcn32_4d_atlantic_precision = (precision_eval(fcn32_4d_atlantic, validation_images3, validation_masks3))

fcn32_3d_recall = (recall_eval(fcn32_3d, validation_images, validation_masks))
fcn32_4d_amazon_recall = (recall_eval(fcn32_4d_amazon, validation_images2, validation_masks2))
fcn32_4d_atlantic_recall = (recall_eval(fcn32_4d_atlantic, validation_images3, validation_masks3))

# F1-score
fcn32_3d_f1_score = (f1_score_eval_basic(fcn32_3d_precision, fcn32_3d_recall))
fcn32_4d_amazon_f1_score = (f1_score_eval_basic(fcn32_4d_amazon_precision, fcn32_4d_amazon_recall))
fcn32_4d_atlantic_f1_score = (f1_score_eval_basic(fcn32_4d_atlantic_precision, fcn32_4d_atlantic_recall))

# %%
# Metrics of 4-dim Amazon trained model on Atlantic data and vice versa

# Score
fcn32_4d_amazon_on_atlantic_score = (score_eval2(fcn32_4d_amazon, validation_images3+test_images3, validation_masks3+test_masks3))
fcn32_4d_atlantic_on_amazon_score = (score_eval2(fcn32_4d_atlantic, validation_images2+test_images2, validation_masks2+test_masks2))

# Precision and recall
fcn32_4d_amazon_on_atlantic_precision = (precision_eval(fcn32_4d_amazon, validation_images3+test_images3, validation_masks3+test_masks3))
fcn32_4d_atlantic_on_amazon_precision = (precision_eval(fcn32_4d_atlantic, validation_images2+test_images2, validation_masks2+test_masks2))

fcn32_4d_amazon_on_atlantic_recall = (recall_eval(fcn32_4d_amazon, validation_images3+test_images3, validation_masks3+test_masks3))
fcn32_4d_atlantic_on_amazon_recall = (recall_eval(fcn32_4d_atlantic, validation_images2+test_images2, validation_masks2+test_masks2))

# F1-score
fcn32_4d_amazon_on_atlantic_f1_score = (f1_score_eval_basic(fcn32_4d_amazon_on_atlantic_precision, fcn32_4d_amazon_on_atlantic_recall))
fcn32_4d_atlantic_on_amazon_f1_score = (f1_score_eval_basic(fcn32_4d_atlantic_on_amazon_precision, fcn32_4d_atlantic_on_amazon_recall))

# %%
# Print metrics
print('Accuracy | Precision | Recall | F1-score')
print('FCN32 3-dim: ', np.mean(fcn32_3d_score), np.mean(fcn32_3d_precision), np.mean(fcn32_3d_recall), fcn32_3d_f1_score)
print('FCN32 3-dim: ', np.std(fcn32_3d_score), np.std(fcn32_3d_precision), np.std(fcn32_3d_recall), fcn32_3d_f1_score)
print('----')
print('FCN32 4-dim Amazon: ', np.mean(fcn32_4d_amazon_score), np.mean(fcn32_4d_amazon_precision), np.mean(fcn32_4d_amazon_recall), fcn32_4d_amazon_f1_score)
print('FCN32 4-dim Amazon: ', np.std(fcn32_4d_amazon_score), np.std(fcn32_4d_amazon_precision), np.std(fcn32_4d_amazon_recall), fcn32_4d_amazon_f1_score)
print('----')
print('FCN32 4-dim Atlantic: ', np.mean(fcn32_4d_atlantic_score), np.mean(fcn32_4d_atlantic_precision), np.mean(fcn32_4d_atlantic_recall), fcn32_4d_atlantic_f1_score)
print('FCN32 4-dim Atlantic: ', np.std(fcn32_4d_atlantic_score), np.std(fcn32_4d_atlantic_precision), np.std(fcn32_4d_atlantic_recall), fcn32_4d_atlantic_f1_score)
print('----')
print('FCN32 4-dim Amazon on Atlantic: ', np.mean(fcn32_4d_amazon_on_atlantic_score), np.mean(fcn32_4d_amazon_on_atlantic_precision), np.mean(fcn32_4d_amazon_on_atlantic_recall), fcn32_4d_amazon_on_atlantic_f1_score)
print('FCN32 4-dim Amazon on Atlantic: ', np.std(fcn32_4d_amazon_on_atlantic_score), np.std(fcn32_4d_amazon_on_atlantic_precision), np.std(fcn32_4d_amazon_on_atlantic_recall), fcn32_4d_amazon_on_atlantic_f1_score)
print('----')
print('FCN32 4-dim Atlantic on Amazon: ', np.mean(fcn32_4d_atlantic_on_amazon_score), np.mean(fcn32_4d_atlantic_on_amazon_precision), np.mean(fcn32_4d_atlantic_on_amazon_recall), fcn32_4d_atlantic_on_amazon_f1_score)
print('FCN32 4-dim Atlantic on Amazon: ', np.std(fcn32_4d_atlantic_on_amazon_score), np.std(fcn32_4d_atlantic_on_amazon_precision), np.std(fcn32_4d_atlantic_on_amazon_recall), fcn32_4d_atlantic_on_amazon_f1_score)

# %% [markdown]
# ### Amazon and Atlantic unseen test datasets

# %%
# Amazon trained model on Amazon test data
# Scores of each model
fcn32_4d_score_test = (score_eval2(fcn32_4d_amazon, test_images2, test_masks2))

# Precision and recall of each model
fcn32_4d_precision_test = (precision_eval(fcn32_4d_amazon, test_images2, test_masks2))
fcn32_4d_recall_test = (recall_eval(fcn32_4d_amazon, test_images2, test_masks2))

# F1-scores of each model
fcn32_4d_f1_score_test = (f1_score_eval_basic(fcn32_4d_precision_test, fcn32_4d_recall_test))

# %%
# Atlantic trained model on Atlantic test data
# Scores of each model
fcn32_4d_atlantic_score_test = (score_eval2(fcn32_4d_atlantic, test_images3, test_masks3))

# Precision and recall of each model
fcn32_4d_atlantic_precision_test = (precision_eval(fcn32_4d_atlantic, test_images3, test_masks3))
fcn32_4d_atlantic_recall_test = (recall_eval(fcn32_4d_atlantic, test_images3, test_masks3))

# F1-scores of each model
fcn32_4d_atlantic_f1_score_test = (f1_score_eval_basic(fcn32_4d_atlantic_precision_test, fcn32_4d_atlantic_recall_test))

# %%
# Print metrics for Amazon on Amazon Test set
print('FCN32 score: ', np.mean(fcn32_4d_score_test), np.std(fcn32_4d_score_test))
print('FCN32 precision: ', np.mean(fcn32_4d_precision_test), np.std(fcn32_4d_precision_test))
print('FCN32 recall: ', np.mean(fcn32_4d_recall_test), np.std(fcn32_4d_recall_test))
print('FCN32 F1-score: ', fcn32_4d_f1_score_test)

# %%
# Print metrics for Atlantic on Atlantic Test set
print('FCN32 score: ', np.mean(fcn32_4d_atlantic_score_test), np.std(fcn32_4d_atlantic_score_test))
print('FCN32 precision: ', np.mean(fcn32_4d_atlantic_precision_test), np.std(fcn32_4d_atlantic_precision_test))
print('FCN32 recall: ', np.mean(fcn32_4d_atlantic_recall_test), np.std(fcn32_4d_atlantic_recall_test))
print('FCN32 F1-score: ', fcn32_4d_atlantic_f1_score_test)

# %% [markdown]
# ## ResUNet

# %%
# Load ResUNet models and history stats
# Import models
resunet_3d = res_unet(512, [64, 128, 256, 512], 3, 3, 1)
resunet_4d_amazon = res_unet(512, [64, 128, 256, 512], 3, 4, 1)
resunet_4d_atlantic = res_unet(512, [64, 128, 256, 512], 3, 4, 1)
resunet_3d.load_weights('resunet-3d.keras')
resunet_4d_amazon.load_weights('resunet-4d.keras')
resunet_4d_atlantic.load_weights('resunet-4d-atlantic.keras')

resunet_3d_history = np.load('resunet-3d-history.npy', allow_pickle='TRUE').item()
resunet_4d_amazon_history = np.load('resunet-4d-history.npy', allow_pickle='TRUE').item()
resunet_4d_atlantic_history = np.load('resunet-4d-atlantic-history.npy', allow_pickle='TRUE').item()

# %%
# Metrics of each model on respective datasets

# Score
resunet_3d_score = (score_eval(resunet_3d, validation_images, validation_masks))
resunet_4d_amazon_score = (score_eval2(resunet_4d_amazon, validation_images2, validation_masks2))
resunet_4d_atlantic_score = (score_eval2(resunet_4d_atlantic, validation_images3, validation_masks3))

# Precision and recall
resunet_3d_precision = (precision_eval(resunet_3d, validation_images, validation_masks))
resunet_4d_amazon_precision = (precision_eval(resunet_4d_amazon, validation_images2, validation_masks2))
resunet_4d_atlantic_precision = (precision_eval(resunet_4d_atlantic, validation_images3, validation_masks3))

resunet_3d_recall = (recall_eval(resunet_3d, validation_images, validation_masks))
resunet_4d_amazon_recall = (recall_eval(resunet_4d_amazon, validation_images2, validation_masks2))
resunet_4d_atlantic_recall = (recall_eval(resunet_4d_atlantic, validation_images3, validation_masks3))

# F1-score
resunet_3d_f1_score = (f1_score_eval_basic(resunet_3d_precision, resnet_3d_recall))
resunet_4d_amazon_f1_score = (f1_score_eval_basic(resunet_4d_amazon_precision, resnet_4d_amazon_recall))
resunet_4d_atlantic_f1_score = (f1_score_eval_basic(resunet_4d_atlantic_precision, resnet_4d_atlantic_recall))

# %%
# Metrics of 4-dim Amazon trained model on Atlantic data and vice versa

# Score
resunet_4d_amazon_on_atlantic_score = (score_eval2(resunet_4d_amazon, validation_images3+test_images3, validation_masks3+test_masks3))
resunet_4d_atlantic_on_amazon_score = (score_eval2(resunet_4d_atlantic, validation_images2+test_images2, validation_masks2+test_masks2))

# Precision and recall
resunet_4d_amazon_on_atlantic_precision = (precision_eval(resunet_4d_amazon, validation_images3+test_images3, validation_masks3+test_masks3))
resunet_4d_atlantic_on_amazon_precision = (precision_eval(resunet_4d_atlantic, validation_images2+test_images2, validation_masks2+test_masks2))

resunet_4d_amazon_on_atlantic_recall = (recall_eval(resunet_4d_amazon, validation_images3+test_images3, validation_masks3+test_masks3))
resunet_4d_atlantic_on_amazon_recall = (recall_eval(resunet_4d_atlantic, validation_images2+test_images2, validation_masks2+test_masks2))

# F1-score
resunet_4d_amazon_on_atlantic_f1_score = (f1_score_eval_basic(resunet_4d_amazon_on_atlantic_precision, resunet_4d_amazon_on_atlantic_recall))
resunet_4d_atlantic_on_amazon_f1_score = (f1_score_eval_basic(resunet_4d_atlantic_on_amazon_precision, resunet_4d_atlantic_on_amazon_recall))

# %%
# Print metrics
print('Accuracy | Precision | Recall | F1-score')
print('ResUNet 3-dim: ', np.mean(resunet_3d_score), np.mean(resunet_3d_precision), np.mean(resunet_3d_recall), resunet_3d_f1_score)
print('ResUNet 3-dim: ', np.std(resunet_3d_score), np.std(resunet_3d_precision), np.std(resunet_3d_recall), resunet_3d_f1_score)
print('----')
print('ResUNet 4-dim Amazon: ', np.mean(resunet_4d_amazon_score), np.mean(resunet_4d_amazon_precision), np.mean(resunet_4d_amazon_recall), resunet_4d_amazon_f1_score)
print('ResUNet 4-dim Amazon: ', np.std(resunet_4d_amazon_score), np.std(resunet_4d_amazon_precision), np.std(resunet_4d_amazon_recall), resunet_4d_amazon_f1_score)
print('----')
print('ResUNet 4-dim Atlantic: ', np.mean(resunet_4d_atlantic_score), np.mean(resunet_4d_atlantic_precision), np.mean(resunet_4d_atlantic_recall), resunet_4d_atlantic_f1_score)
print('ResUNet 4-dim Atlantic: ', np.std(resunet_4d_atlantic_score), np.std(resunet_4d_atlantic_precision), np.std(resunet_4d_atlantic_recall), resunet_4d_atlantic_f1_score)
print('----')
print('ResUNet 4-dim Amazon on Atlantic: ', np.mean(resunet_4d_amazon_on_atlantic_score), np.mean(resunet_4d_amazon_on_atlantic_precision), np.mean(resunet_4d_amazon_on_atlantic_recall), resunet_4d_amazon_on_atlantic_f1_score)
print('ResUNet 4-dim Amazon on Atlantic: ', np.std(resunet_4d_amazon_on_atlantic_score), np.std(resunet_4d_amazon_on_atlantic_precision), np.std(resunet_4d_amazon_on_atlantic_recall), resunet_4d_amazon_on_atlantic_f1_score)
print('----')
print('ResUNet 4-dim Atlantic on Amazon: ', np.mean(resunet_4d_atlantic_on_amazon_score), np.mean(resunet_4d_atlantic_on_amazon_precision), np.mean(resunet_4d_atlantic_on_amazon_recall), resunet_4d_atlantic_on_amazon_f1_score)
print('ResUNet 4-dim Atlantic on Amazon: ', np.std(resunet_4d_atlantic_on_amazon_score), np.std(resunet_4d_atlantic_on_amazon_precision), np.std(resunet_4d_atlantic_on_amazon_recall), resunet_4d_atlantic_on_amazon_f1_score)

# %% [markdown]
# ### Amazon and Atlantic unseen test datasets

# %%
# Amazon trained model on Amazon test data
# Scores of each model
resunet_4d_score_test = (score_eval2(resunet_4d_amazon, test_images2, test_masks2))

# Precision and recall of each model
resunet_4d_precision_test = (precision_eval(resunet_4d_amazon, test_images2, test_masks2))
resunet_4d_recall_test = (recall_eval(resunet_4d_amazon, test_images2, test_masks2))

# F1-scores of each model
resunet_4d_f1_score_test = (f1_score_eval_basic(resunet_4d_precision_test, resunet_4d_recall_test))

# %%
# Atlantic trained model on Atlantic test data
# Scores of each model
resunet_4d_atlantic_score_test = (score_eval2(resunet_4d_atlantic, test_images3, test_masks3))

# Precision and recall of each model
resunet_4d_atlantic_precision_test = (precision_eval(resunet_4d_atlantic, test_images3, test_masks3))
resunet_4d_atlantic_recall_test = (recall_eval(resunet_4d_atlantic, test_images3, test_masks3))

# F1-scores of each model
resunet_4d_atlantic_f1_score_test = (f1_score_eval_basic(resunet_4d_atlantic_precision_test, resunet_4d_atlantic_recall_test))

# %%
# Print metrics for Amazon on Amazon Test set
print('ResUNet score: ', np.mean(resunet_4d_score_test), np.std(resunet_4d_score_test))
print('ResUNet precision: ', np.mean(resunet_4d_precision_test), np.std(resunet_4d_precision_test))
print('ResUNet recall: ', np.mean(resunet_4d_recall_test), np.std(resunet_4d_recall_test))
print('ResUNet F1-score: ', resunet_4d_f1_score_test)

# %%
# Print metrics for Atlantic on Atlantic Test set
print('ResUNet score: ', np.mean(resunet_4d_atlantic_score_test), np.std(resunet_4d_atlantic_score_test))
print('ResUNet precision: ', np.mean(resunet_4d_atlantic_precision_test), np.std(resunet_4d_atlantic_precision_test))
print('ResUNet recall: ', np.mean(resunet_4d_atlantic_recall_test), np.std(resunet_4d_atlantic_recall_test))
print('ResUNet F1-score: ', resunet_4d_atlantic_f1_score_test)

# %% [markdown]
# # Produce metric datasets for export

# %% [markdown]
# ## RGB data

# %%
scores_3d = [unet_score, am_unet_score, resnet_3d_score, fcn32_3d_score, resunet_3d_score]
precision_3d = [unet_precision, am_unet_precision, resnet_3d_precision, fcn32_3d_precision, resunet_3d_precision]
recall_3d = [unet_recall, am_unet_recall, resnet_3d_recall, fcn32_3d_recall, resunet_3d_recall]
f1_scores_3d = [unet_f1_score, am_unet_f1_score, resnet_3d_f1_score, fcn32_3d_f1_score, resunet_3d_f1_score]

import pandas as pd
metrics_3d = {'classifier': ['U-Net', 'Attention U-Net', 'ResNet50-SegNet', 'FCN32-VGG16', 'ResUNet'],
              'accuracy': [np.mean(n) for n in scores_3d],
              'precision': [np.mean(n) for n in precision_3d],
              'recall': [np.mean(n) for n in recall_3d],
              'f1_score': [np.mean(n) for n in f1_scores_3d],
              'accuracy_std': [np.std(n) for n in scores_3d],
              'precision_std': [np.std(n) for n in precision_3d],
              'recall_std': [np.std(n) for n in recall_3d]
              }
metrics_3d = pd.DataFrame(metrics_3d)
metrics_3d.to_csv('metrics_3d.csv')

# %% [markdown]
# ## 4-band Amazon data

# %%
scores_4d = [unet_4d_score, am_unet_4d_score, resnet_4d_amazon_score, fcn32_4d_amazon_score, resunet_4d_amazon_score]
precision_4d = [unet_4d_precision, am_unet_4d_precision, resnet_4d_amazon_precision, fcn32_4d_amazon_precision, resunet_4d_amazon_precision]
recall_4d = [unet_4d_recall, am_unet_4d_recall, resnet_4d_amazon_recall, fcn32_4d_amazon_recall, resunet_4d_amazon_recall]
f1_scores_4d = [unet_4d_f1_score, am_unet_4d_f1_score, resnet_4d_amazon_f1_score, fcn32_4d_amazon_f1_score, resunet_4d_amazon_f1_score]

metrics_4d = {'classifier': ['U-Net', 'Attention U-Net', 'ResNet50-SegNet', 'FCN32-VGG16', 'ResUNet'],
              'accuracy': [np.mean(n) for n in scores_4d],
              'precision': [np.mean(n) for n in precision_4d],
              'recall': [np.mean(n) for n in recall_4d],
              'f1_score': [np.mean(n) for n in f1_scores_4d],
              'accuracy_std': [np.std(n) for n in scores_4d],
              'precision_std': [np.std(n) for n in precision_4d],
              'recall_std': [np.std(n) for n in recall_4d]
              }
metrics_4d = pd.DataFrame(metrics_4d)
metrics_4d.to_csv('metrics_4d_amazon.csv')

# %% [markdown]
# ## 4-band Atlantic Forest data

# %%
scores_4d_atl = [unet_4d_atlantic_score, am_unet_4d_atlantic_score, resnet_4d_atlantic_score, fcn32_4d_atlantic_score, resunet_4d_atlantic_score]
precision_4d_atl = [unet_4d_atlantic_precision, am_unet_4d_atlantic_precision, resnet_4d_atlantic_precision, fcn32_4d_atlantic_precision, resunet_4d_atlantic_precision]
recall_4d_atl = [unet_4d_atlantic_recall, am_unet_4d_atlantic_recall, resnet_4d_atlantic_recall, fcn32_4d_atlantic_recall, resunet_4d_atlantic_recall]
f1_scores_4d_atl = [unet_4d_atlantic_f1_score, am_unet_4d_atlantic_f1_score, resnet_4d_atlantic_f1_score, fcn32_4d_atlantic_f1_score, resunet_4d_atlantic_f1_score]

metrics_4d_atl = {'classifier': ['U-Net', 'Attention U-Net', 'ResNet50-SegNet', 'FCN32-VGG16', 'ResUNet'],
              'accuracy': [np.mean(n) for n in scores_4d_atl],
              'precision': [np.mean(n) for n in precision_4d_atl],
              'recall': [np.mean(n) for n in recall_4d_atl],
              'f1_score': [np.mean(n) for n in f1_scores_4d_atl],
              'accuracy_std': [np.std(n) for n in scores_4d_atl],
              'precision_std': [np.std(n) for n in precision_4d_atl],
              'recall_std': [np.std(n) for n in recall_4d_atl]
              }
metrics_4d_atl = pd.DataFrame(metrics_4d_atl)
metrics_4d_atl.to_csv('metrics_4d_atlantic_forest.csv')

# %% [markdown]
# ## Test set data

# %%
scores_4d_test = [unet_4d_score_test, am_unet_4d_score_test, resnet_4d_score_test, fcn32_4d_score_test, resunet_4d_score_test]
precision_4d_test = [unet_4d_precision_test, am_unet_4d_precision_test, resnet_4d_precision_test, fcn32_4d_precision_test, resunet_4d_precision_test]
recall_4d_test = [unet_4d_recall_test, am_unet_4d_recall_test, resnet_4d_recall_test, fcn32_4d_recall_test, resunet_4d_recall_test]
f1_scores_4d_test = [unet_4d_f1_score_test, am_unet_4d_f1_score_test, resnet_4d_f1_score_test, fcn32_4d_f1_score_test, resunet_4d_f1_score_test]

metrics_4d_test = {'classifier': ['U-Net', 'Attention U-Net', 'ResNet50-SegNet', 'FCN32-VGG16', 'ResUNet'],
              'accuracy': [np.mean(n) for n in scores_4d_test],
              'precision': [np.mean(n) for n in precision_4d_test],
              'recall': [np.mean(n) for n in recall_4d_test],
              'f1_score': [np.mean(n) for n in f1_scores_4d_test],
              'accuracy_std': [np.std(n) for n in scores_4d_test],
              'precision_std': [np.std(n) for n in precision_4d_test],
              'recall_std': [np.std(n) for n in recall_4d_test]
              }
metrics_4d_test = pd.DataFrame(metrics_4d_test)
metrics_4d_test.to_csv('metrics_4d_amazon_test.csv')

# %%
scores_4d_atl_test = [unet_4d_atlantic_score_test, am_unet_4d_atlantic_score_test, resnet_4d_atlantic_score_test, fcn32_4d_atlantic_score_test, resunet_4d_atlantic_score_test]
precision_4d_atl_test = [unet_4d_atlantic_precision_test, am_unet_4d_atlantic_precision_test, resnet_4d_atlantic_precision_test, fcn32_4d_atlantic_precision_test, resunet_4d_atlantic_precision_test]
recall_4d_atl_test = [unet_4d_atlantic_recall_test, am_unet_4d_atlantic_recall_test, resnet_4d_atlantic_recall_test, fcn32_4d_atlantic_recall_test, resunet_4d_atlantic_recall_test]
f1_scores_4d_atl_test = [unet_4d_atlantic_f1_score_test, am_unet_4d_atlantic_f1_score_test, resnet_4d_atlantic_f1_score_test, fcn32_4d_atlantic_f1_score_test, resunet_4d_atlantic_f1_score_test]

metrics_4d_atl_test = {'classifier': ['U-Net', 'Attention U-Net', 'ResNet50-SegNet', 'FCN32-VGG16', 'ResUNet'],
              'accuracy': [np.mean(n) for n in scores_4d_atl_test],
              'precision': [np.mean(n) for n in precision_4d_atl_test],
              'recall': [np.mean(n) for n in recall_4d_atl_test],
              'f1_score': [np.mean(n) for n in f1_scores_4d_atl_test],
              'accuracy_std': [np.std(n) for n in scores_4d_atl_test],
              'precision_std': [np.std(n) for n in precision_4d_atl_test],
              'recall_std': [np.std(n) for n in recall_4d_atl_test]
              }
metrics_4d_atl_test = pd.DataFrame(metrics_4d_atl_test)
metrics_4d_atl_test.to_csv('metrics_4d_atlantic_forest_test.csv')

# %% [markdown]
# ## Testing on opposite dataset (e.g. train on Amazon, test on Atlantic)

# %%
scores_amazon_on_atlantic = [unet_amazon_on_atlantic_score, am_unet_amazon_on_atlantic_score, resnet_4d_amazon_on_atlantic_score, fcn32_4d_amazon_on_atlantic_score, resunet_4d_amazon_on_atlantic_score]
precision_amazon_on_atlantic = [unet_amazon_on_atlantic_precision, am_unet_amazon_on_atlantic_precision, resnet_4d_amazon_on_atlantic_precision, fcn32_4d_amazon_on_atlantic_precision, resunet_4d_amazon_on_atlantic_precision]
recall_amazon_on_atlantic = [unet_amazon_on_atlantic_recall, am_unet_amazon_on_atlantic_recall, resnet_4d_amazon_on_atlantic_recall, fcn32_4d_amazon_on_atlantic_recall, resunet_4d_amazon_on_atlantic_recall]
f1_scores_amazon_on_atlantic = [unet_amazon_on_atlantic_f1_score, am_unet_amazon_on_atlantic_f1_score, resnet_4d_amazon_on_atlantic_f1_score, fcn32_4d_amazon_on_atlantic_f1_score, resunet_4d_amazon_on_atlantic_f1_score]

metrics_4d_amazon_on_atlantic = {'classifier': ['U-Net', 'Attention U-Net', 'ResNet50-SegNet', 'FCN32-VGG16', 'ResUNet'],
              'accuracy': [np.mean(n) for n in scores_amazon_on_atlantic],
              'precision': [np.mean(n) for n in precision_amazon_on_atlantic],
              'recall': [np.mean(n) for n in recall_amazon_on_atlantic],
              'f1_score': [np.mean(n) for n in f1_scores_amazon_on_atlantic],
              'accuracy_std': [np.std(n) for n in scores_amazon_on_atlantic],
              'precision_std': [np.std(n) for n in precision_amazon_on_atlantic],
              'recall_std': [np.std(n) for n in recall_amazon_on_atlantic]
              }
metrics_4d_amazon_on_atlantic = pd.DataFrame(metrics_4d_amazon_on_atlantic)
metrics_4d_amazon_on_atlantic.to_csv('metrics_4d_amazon_on_atlantic.csv')

# %%
scores_atlantic_on_amazon = [unet_atlantic_on_amazon_score, am_unet_atlantic_on_amazon_score, resnet_4d_atlantic_on_amazon_score, fcn32_4d_atlantic_on_amazon_score, resunet_4d_atlantic_on_amazon_score]
precision_atlantic_on_amazon = [unet_atlantic_on_amazon_precision, am_unet_atlantic_on_amazon_precision, resnet_4d_atlantic_on_amazon_precision, fcn32_4d_atlantic_on_amazon_precision, resunet_4d_atlantic_on_amazon_precision]
recall_atlantic_on_amazon = [unet_atlantic_on_amazon_recall, am_unet_atlantic_on_amazon_recall, resnet_4d_atlantic_on_amazon_recall, fcn32_4d_atlantic_on_amazon_recall, resunet_4d_atlantic_on_amazon_recall]
f1_scores_atlantic_on_amazon = [unet_atlantic_on_amazon_f1_score, am_unet_atlantic_on_amazon_f1_score, resnet_4d_atlantic_on_amazon_f1_score, fcn32_4d_atlantic_on_amazon_f1_score, resunet_4d_atlantic_on_amazon_f1_score]

metrics_4d_atlantic_on_amazon = {'classifier': ['U-Net', 'Attention U-Net', 'ResNet50-SegNet', 'FCN32-VGG16', 'ResUNet'],
              'accuracy': [np.mean(n) for n in scores_atlantic_on_amazon],
              'precision': [np.mean(n) for n in precision_atlantic_on_amazon],
              'recall': [np.mean(n) for n in recall_atlantic_on_amazon],
              'f1_score': [np.mean(n) for n in f1_scores_atlantic_on_amazon],
              'accuracy_std': [np.std(n) for n in scores_atlantic_on_amazon],
              'precision_std': [np.std(n) for n in precision_atlantic_on_amazon],
              'recall_std': [np.std(n) for n in recall_atlantic_on_amazon]
              }
metrics_4d_atlantic_on_amazon = pd.DataFrame(metrics_4d_atlantic_on_amazon)
metrics_4d_atlantic_on_amazon.to_csv('metrics_4d_atlantic_on_amazon.csv')
